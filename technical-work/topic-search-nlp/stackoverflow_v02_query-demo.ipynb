# %% [markdown]
# # Stack Overflow Topic Search
#
# Created: 15 Dec 2021
# Last edited: 20 Dec 2021

# %% [markdown]
# ## Setup to use this notebook
#
# 1. Set up your Python environment.
#
# ```
# # create a new conda env called "topic"
# conda create --name topic
# conda activate topic
#
# # install packages
# conda install -c anaconda pyyaml pandas nltk gensim
# conda install -c conda-forge jupyterlab jira wordcloud matplotlib spacy
# pip install stackapi
# ```
#
# 2. Request access to the teams Stack Overflow by registering a new app on Stack Apps.
#
#   Follow the instructions on [Stack Overflow for Teams API](https://stackoverflow.help/en/articles/4385859-stack-overflow-for-teams-api). Use `stackexchange.com` for the OAuth domain ([source](https://stackapps.com/a/7858)) and for the application website (where users go to read about the application).
#
#
# 3. Call `jupyter notebook` in the terminal to open the Jupyter home page and select this notebook.
#
# ## References
# * Stack Exchange's [API reference docs](https://api.stackexchange.com/docs/)

# %%
import json
import pickle
import re
import requests

import gensim
import spacy
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# Out:
# /Users/victorialim/miniconda3/envs/topic/lib/python3.8/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
# do this one time only
#import nltk
#nltk.download('stopwords')
#spacy.cli.download("en_core_web_sm")

# %%
BASE_URL = "https://api.stackexchange.com/2.3"
TEAM_NAME = "imply"
APP_KEY = "j3Szw*w)dq4OdYMDepWyKQ(("
ACCESS_TOKEN = "YOUR_TOKEN_HERE"

headers = {
  'X-API-Access-Token': ACCESS_TOKEN,
}

# %% [markdown]
# ## Run a test request to check the connection

# %%
url = f"{BASE_URL}/questions?order=desc&sort=activity&site=stackoverflow&team=stackoverflow.com%2fc%2f{TEAM_NAME}&key={APP_KEY}"
response = requests.request("GET", url, headers=headers)
pretty_json = json.loads(response.text)
print(json.dumps(pretty_json, indent=2))
# Out:
# {
#   "items": [
#     {
#       "tags": [
#         "eng-platform",
#         "platform"
#       ],
#       "owner": {
#         "account_id": 17961736,
#         "reputation": 726,
#         "user_id": 32,
#         "user_type": "registered",
#         "profile_image": "https://stackoverflow.com/c/imply/images/s/a4d95b45-3857-45d9-b0d9-49025ada6234.png?s=256&g=1",
#         "display_name": "Siva Mannem",
#         "link": "https://stackoverflow.com/c/imply/users/32/siva-mannem"
#       },
#       "is_answered": true,
#       "view_count": 24,
#       "accepted_answer_id": 4414,
#       "answer_count": 1,
#       "score": 0,
#       "last_activity_date": 1641495845,
#       "creation_date": 1641439269,
#       "last_edit_date": 1641491294,
#       "question_id": 4404,
#       "link": "https://stackoverflow.com/c/imply/questions/4404/validationerror-the-instance-i-0809ef9f26e7f09b7-is-not-part-of-auto-scaling-gr",
#       "title": "ValidationError: The instance i-0809ef9f26e7f09b7 is not part of Auto Scaling group"
#     },
#     {
#       "tags": [
#         "eng-apps"
#       ],
#       "owner": {
#         "account_id": 21810242,
#         "reputation": 23,
#         "user_id": 132,
#         "user_type": "registered",
#         "profile_image": "https://www.gravatar.com/avatar/81da52cd6f0df2a6b0e189b2715737d8?s=256&d=identicon&r=PG",
#         "display_name": "Thomas Zino",
#         "link": "https://stackoverflow.com/c/imply/users/132/thomas-zino"
#       },
#       "is_answered": false,
#       "view_count": 6,
#       "answer_count": 1,
#       "score": 0,
#       "last_activity_date": 1641495065,
#       "creation_date": 1641494121,
#       "question_id": 4412,
#       "link": "https://stackoverflow.com/c/imply/questions/4412/modify-pivot-login-behavior",
#       "title": "Modify Pivot login behavior"
#     },
#     {
#       "tags": [
#         "eng-druid",
#         "druid",
#         "druidsql"
#       ],
#       "owner": {
#         "account_id": 22201773,
#         "reputation": 7,
#         "user_id": 137,
#         "user_type": "registered",
#         "profile_image": "https://www.gravatar.com/avatar/f14744942668ecfaafa2e514ca632165?s=256&d=identicon&r=PG&f=1",
#         "display_name": "Senthil Valli",
#         "link": "https://stackoverflow.com/c/imply/users/137/senthil-valli"
#       },
#       "is_answered": true,
#       "view_count": 17,
#       "accepted_answer_id": 4411,
#       "answer_count": 1,
#       "score": 0,
#       "last_activity_date": 1641493735,
#       "creation_date": 1641450513,
#       "question_id": 4405,
#       "link": "https://stackoverflow.com/c/imply/questions/4405/quantile-computation-using-sketches",
#       "title": "Quantile computation using Sketches"
#     },
#     {
#       "tags": [
#         "eng-druid"
#       ],
#       "owner": {
#         "account_id": 14477507,
#         "reputation": 389,
#         "user_id": 69,
#         "user_type": "registered",
#         "profile_image": "https://lh3.googleusercontent.com/-DgZtWib7mGo/AAAAAAAAAAI/AAAAAAAAAA4/T8jylh3viho/photo.jpg?sz=256",
#         "display_name": "Ben Krug",
#         "link": "https://stackoverflow.com/c/imply/users/69/ben-krug"
#       },
#       "is_answered": true,
#       "view_count": 12,
#       "accepted_answer_id": 4410,
#       "answer_count": 1,
#       "score": 0,
#       "last_activity_date": 1641493005,
#       "creation_date": 1641491758,
#       "question_id": 4408,
#       "link": "https://stackoverflow.com/c/imply/questions/4408/which-conditions-can-result-in-incomplete-query-results",
#       "title": "Which conditions can result in incomplete query results?"
#     },
#     {
#       "tags": [
#         "eng-platform",
#         "kubernetes"
#       ],
#       "owner": {
#         "account_id": 23138516,
#         "reputation": 1,
#         "user_id": 170,
#         "user_type": "registered",
#         "profile_image": "https://www.gravatar.com/avatar/75d39f79f90ae8a5bf39c9551e79b262?s=256&d=identicon&r=PG",
#         "display_name": "Aravind Reddy Damma",
#         "link": "https://stackoverflow.com/c/imply/users/170/aravind-reddy-damma"
#       },
#       "is_answered": false,
#       "view_count": 11,
#       "answer_count": 0,
#       "score": 0,
#       "last_activity_date": 1641492951,
#       "creation_date": 1641492951,
#       "question_id": 4409,
#       "link": "https://stackoverflow.com/c/imply/questions/4409/zookeeper-upgrade-with-manager-and-agent",
#       "title": "zookeeper upgrade with manager and agent"
#     },
#     {
#       "tags": [
#         "eng-druid",
#         "eng-apps"
#       ],
#       "owner": {
#         "account_id": 21810242,
#         "reputation": 23,
#         "user_id": 132,
#         "user_type": "registered",
#         "profile_image": "https://www.gravatar.com/avatar/81da52cd6f0df2a6b0e189b2715737d8?s=256&d=identicon&r=PG",
#         "display_name": "Thomas Zino",
#         "link": "https://stackoverflow.com/c/imply/users/132/thomas-zino"
#       },
#       "is_answered": false,
#       "view_count": 10,
#       "answer_count": 1,
#       "score": 0,
#       "last_activity_date": 1641492295,
#       "creation_date": 1641488542,
#       "last_edit_date": 1641492295,
#       "question_id": 4406,
#       "link": "https://stackoverflow.com/c/imply/questions/4406/unable-to-find-imply-license-on-2021-11-1",
#       "title": "Unable to find Imply License on 2021.11.1"
#     },
#     {
#       "tags": [
#         "eng-platform"
#       ],
#       "owner": {
#         "account_id": 21810242,
#         "reputation": 23,
#         "user_id": 132,
#         "user_type": "registered",
#         "profile_image": "https://www.gravatar.com/avatar/81da52cd6f0df2a6b0e189b2715737d8?s=256&d=identicon&r=PG",
#         "display_name": "Thomas Zino",
#         "link": "https://stackoverflow.com/c/imply/users/132/thomas-zino"
#       },
#       "is_answered": false,
#       "view_count": 10,
#       "answer_count": 1,
#       "score": 0,
#       "last_activity_date": 1641408987,
#       "creation_date": 1641407196,
#       "last_edit_date": 1641408591,
#       "question_id": 4402,
#       "link": "https://stackoverflow.com/c/imply/questions/4402/imply-helm-chart-zookeeper-dependency-not-publicly-accessible",
#       "title": "Imply Helm chart ZooKeeper dependency not publicly accessible"
#     },
#     {
#       "tags": [
#         "eng-druid"
#       ],
#       "owner": {
#         "account_id": 14477507,
#         "reputation": 389,
#         "user_id": 69,
#         "user_type": "registered",
#         "profile_image": "https://lh3.googleusercontent.com/-DgZtWib7mGo/AAAAAAAAAAI/AAAAAAAAAA4/T8jylh3viho/photo.jpg?sz=256",
#         "display_name": "Ben Krug",
#         "link": "https://stackoverflow.com/c/imply/users/69/ben-krug"
#       },
#       "is_answered": true,
#       "view_count": 17,
#       "accepted_answer_id": 4401,
#       "answer_count": 1,
#       "score": 0,
#       "last_activity_date": 1641392600,
#       "creation_date": 1640338921,
#       "question_id": 4390,
#       "link": "https://stackoverflow.com/c/imply/questions/4390/if-i-have-usedefaultvaluefornull-false-can-i-ingest-and-get-it-persisted-as",
#       "title": "if I have useDefaultValueForNull=false, can I ingest &#39;&#39; and get it persisted as &#39;&#39;?"
#     },
#     {
#       "tags": [
#         "eng-druid"
#       ],
#       "owner": {
#         "account_id": 2152955,
#         "reputation": 300,
#         "user_id": 74,
#         "user_type": "registered",
#         "profile_image": "https://www.gravatar.com/avatar/97756482241b084d10f1d7869c61c20a?s=256&d=identicon&r=PG",
#         "display_name": "Jove Kuang",
#         "link": "https://stackoverflow.com/c/imply/users/74/jove-kuang"
#       },
#       "is_answered": true,
#       "view_count": 15,
#       "accepted_answer_id": 4400,
#       "answer_count": 1,
#       "score": 0,
#       "last_activity_date": 1641367202,
#       "creation_date": 1641362712,
#       "last_edit_date": 1641366981,
#       "question_id": 4399,
#       "link": "https://stackoverflow.com/c/imply/questions/4399/best-way-to-work-with-a-column-containing-an-array-of-json-objets",
#       "title": "Best way to work with a column containing an array of JSON objets"
#     },
#     {
#       "tags": [
#         "eng-druid"
#       ],
#       "owner": {
#         "account_id": 14477507,
#         "reputation": 389,
#         "user_id": 69,
#         "user_type": "registered",
#         "profile_image": "https://lh3.googleusercontent.com/-DgZtWib7mGo/AAAAAAAAAAI/AAAAAAAAAA4/T8jylh3viho/photo.jpg?sz=256",
#         "display_name": "Ben Krug",
#         "link": "https://stackoverflow.com/c/imply/users/69/ben-krug"
#       },
#       "is_answered": true,
#       "view_count": 11,
#       "accepted_answer_id": 4398,
#       "answer_count": 1,
#       "score": 0,
#       "last_activity_date": 1641321954,
#       "creation_date": 1641320944,
#       "question_id": 4397,
#       "link": "https://stackoverflow.com/c/imply/questions/4397/can-customers-replace-log4j-2-16-w-2-17-to-avoid-latest-as-of-01-04-2022-cve",
#       "title": "Can customers replace log4j 2.16 w/2.17 to avoid latest (as of 01-04-2022) CVE?"
#     },
#     {
#       "tags": [
#         "eng-druid"
#       ],
#       "owner": {
#         "account_id": 6951686,
#         "reputation": 123,
#         "user_id": 75,
#         "user_type": "registered",
#         "profile_image": "https://i.stack.imgur.com/JU6Bo.jpg?s=256&g=1",
#         "display_name": "Hellmar Becker",
#         "link": "https://stackoverflow.com/c/imply/users/75/hellmar-becker"
#       },
#       "is_answered": true,
#       "view_count": 9,
#       "accepted_answer_id": 4396,
#       "answer_count": 1,
#       "score": 0,
#       "last_activity_date": 1641284684,
#       "creation_date": 1640946493,
#       "question_id": 4393,
#       "link": "https://stackoverflow.com/c/imply/questions/4393/custom-aggregator-how-to-use-the-finalize-part",
#       "title": "Custom aggregator - how to use the finalize part?"
#     },
#     {
#       "tags": [
#         "eng-druid",
#         "clarity"
#       ],
#       "owner": {
#         "account_id": 22962950,
#         "reputation": 5,
#         "user_id": 165,
#         "user_type": "registered",
#         "profile_image": "https://www.gravatar.com/avatar/679a07b0d0866740a22bf2b739fd70d8?s=256&d=identicon&r=PG",
#         "display_name": "Anil Makarand Mantravadi",
#         "link": "https://stackoverflow.com/c/imply/users/165/anil-makarand-mantravadi"
#       },
#       "is_answered": false,
#       "view_count": 35,
#       "answer_count": 1,
#       "score": 0,
#       "last_activity_date": 1641252209,
#       "creation_date": 1639679295,
#       "last_edit_date": 1641252209,
#       "question_id": 4377,
#       "link": "https://stackoverflow.com/c/imply/questions/4377/number-of-segments-scanned-is-zero-in-clarity",
#       "title": "Number of Segments scanned is zero in clarity"
#     },
#     {
#       "tags": [
#         "eng-druid"
#       ],
#       "owner": {
#         "account_id": 6951686,
#         "reputation": 123,
#         "user_id": 75,
#         "user_type": "registered",
#         "profile_image": "https://i.stack.imgur.com/JU6Bo.jpg?s=256&g=1",
#         "display_name": "Hellmar Becker",
#         "link": "https://stackoverflow.com/c/imply/users/75/hellmar-becker"
#       },
#       "is_answered": false,
#       "view_count": 16,
#       "answer_count": 2,
#       "score": 0,
#       "last_activity_date": 1641250407,
#       "creation_date": 1640885758,
#       "question_id": 4391,
#       "link": "https://stackoverflow.com/c/imply/questions/4391/custom-expression-aggregator-how-to-write-it-correctly",
#       "title": "Custom expression aggregator - how to write it correctly?"
#     },
#     {
#       "tags": [
#         "eng-platform"
#       ],
#       "owner": {
#         "account_id": 2152955,
#         "reputation": 300,
#         "user_id": 74,
#         "user_type": "registered",
#         "profile_image": "https://www.gravatar.com/avatar/97756482241b084d10f1d7869c61c20a?s=256&d=identicon&r=PG",
#         "display_name": "Jove Kuang",
#         "link": "https://stackoverflow.com/c/imply/users/74/jove-kuang"
#       },
#       "is_answered": false,
#       "view_count": 17,
#       "answer_count": 1,
#       "score": 0,
#       "last_activity_date": 1640200375,
#       "creation_date": 1640195582,
#       "question_id": 4388,
#       "link": "https://stackoverflow.com/c/imply/questions/4388/how-do-i-enable-https-for-imply-manager-and-pivot-in-k8s-installation",
#       "title": "How do I enable https for Imply Manager and Pivot in K8s installation?"
#     },
#     {
#       "tags": [
#         "eng-apps"
#       ],
#       "owner": {
#         "account_id": 2152955,
#         "reputation": 300,
#         "user_id": 74,
#         "user_type": "registered",
#         "profile_image": "https://www.gravatar.com/avatar/97756482241b084d10f1d7869c61c20a?s=256&d=identicon&r=PG",
#         "display_name": "Jove Kuang",
#         "link": "https://stackoverflow.com/c/imply/users/74/jove-kuang"
#       },
#       "is_answered": false,
#       "view_count": 6,
#       "answer_count": 0,
#       "score": 0,
#       "last_activity_date": 1640123279,
#       "creation_date": 1640123279,
#       "question_id": 4387,
#       "link": "https://stackoverflow.com/c/imply/questions/4387/whats-the-best-way-to-implement-data-access-policies-for-sql-interface-in-pivot",
#       "title": "What&#39;s the best way to implement data access policies for SQL interface in Pivot?"
#     },
#     {
#       "tags": [
#         "eng-druid"
#       ],
#       "owner": {
#         "account_id": 22666875,
#         "reputation": 1,
#         "user_id": 153,
#         "user_type": "registered",
#         "profile_image": "https://www.gravatar.com/avatar/737c3afca2fa0408bdb5e93a1d99c020?s=256&d=identicon&r=PG&f=1",
#         "display_name": "Tejas Parbat",
#         "link": "https://stackoverflow.com/c/imply/users/153/tejas-parbat"
#       },
#       "is_answered": false,
#       "view_count": 12,
#       "answer_count": 1,
#       "score": 0,
#       "last_activity_date": 1640081703,
#       "creation_date": 1640079207,
#       "question_id": 4385,
#       "link": "https://stackoverflow.com/c/imply/questions/4385/can-we-export-clarity-metrics-to-internal-time-series-db",
#       "title": "Can we export Clarity Metrics to internal time series DB"
#     },
#     {
#       "tags": [
#         "eng-druid",
#         "product",
#         "on-call-druid"
#       ],
#       "owner": {
#         "account_id": 22666875,
#         "reputation": 1,
#         "user_id": 153,
#         "user_type": "registered",
#         "profile_image": "https://www.gravatar.com/avatar/737c3afca2fa0408bdb5e93a1d99c020?s=256&d=identicon&r=PG&f=1",
#         "display_name": "Tejas Parbat",
#         "link": "https://stackoverflow.com/c/imply/users/153/tejas-parbat"
#       },
#       "is_answered": false,
#       "view_count": 15,
#       "answer_count": 0,
#       "score": 0,
#       "last_activity_date": 1640070488,
#       "creation_date": 1640070488,
#       "question_id": 4384,
#       "link": "https://stackoverflow.com/c/imply/questions/4384/customer-would-like-upgrade-log4j-jars-to-2-16-0-insated-of-patched-jars",
#       "title": "Customer would like upgrade log4j jars to 2.16.0 insated of patched jars"
#     },
#     {
#       "tags": [
#         "k8s"
#       ],
#       "owner": {
#         "account_id": 22547216,
#         "reputation": 26,
#         "user_id": 147,
#         "user_type": "registered",
#         "profile_image": "https://www.gravatar.com/avatar/7e505c8f20fa5de0a44212f4f66554ab?s=256&d=identicon&r=PG&f=1",
#         "display_name": "Zeke Dean",
#         "link": "https://stackoverflow.com/c/imply/users/147/zeke-dean"
#       },
#       "is_answered": false,
#       "view_count": 3,
#       "answer_count": 0,
#       "score": 0,
#       "last_activity_date": 1639844420,
#       "creation_date": 1639844420,
#       "question_id": 4383,
#       "link": "https://stackoverflow.com/c/imply/questions/4383/how-to-set-up-host-networking-on-k8s",
#       "title": "how to set up host networking on k8s"
#     },
#     {
#       "tags": [
#         "eng-apps",
#         "pivot",
#         "product"
#       ],
#       "owner": {
#         "account_id": 17949670,
#         "reputation": 4407,
#         "user_id": 20,
#         "user_type": "registered",
#         "profile_image": "https://stackoverflow.com/c/imply/images/s/40ba0b8b-2b8a-4f9f-90c9-7fe176f56d46.png?s=256&g=1",
#         "display_name": "vaibhaV",
#         "link": "https://stackoverflow.com/c/imply/users/20/vaibhav"
#       },
#       "is_answered": false,
#       "view_count": 5,
#       "answer_count": 0,
#       "score": 0,
#       "last_activity_date": 1639810318,
#       "creation_date": 1639463544,
#       "last_edit_date": 1639810318,
#       "question_id": 4369,
#       "link": "https://stackoverflow.com/c/imply/questions/4369/pivot-visualisation-is-it-possible-to-have-one-row-per-record-instead-of-the-ca",
#       "title": "Pivot visualisation: Is it possible to have One row per record instead of the cascade of x number of dimensions selected"
#     },
#     {
#       "tags": [
#         "eng-platform"
#       ],
#       "owner": {
#         "account_id": 14477507,
#         "reputation": 389,
#         "user_id": 69,
#         "user_type": "registered",
#         "profile_image": "https://lh3.googleusercontent.com/-DgZtWib7mGo/AAAAAAAAAAI/AAAAAAAAAA4/T8jylh3viho/photo.jpg?sz=256",
#         "display_name": "Ben Krug",
#         "link": "https://stackoverflow.com/c/imply/users/69/ben-krug"
#       },
#       "is_answered": true,
#       "view_count": 10,
#       "accepted_answer_id": 4382,
#       "answer_count": 1,
#       "score": 0,
#       "last_activity_date": 1639781021,
#       "creation_date": 1639772796,
#       "last_edit_date": 1639780749,
#       "question_id": 4380,
#       "link": "https://stackoverflow.com/c/imply/questions/4380/compatibilities-and-tags-for-manager-and-imply-druid",
#       "title": "compatibilities and tags for Manager and Imply/druid"
#     },
#     {
#       "tags": [
#         "eng-druid"
#       ],
#       "owner": {
#         "account_id": 12260254,
#         "reputation": 259,
#         "user_id": 86,
#         "user_type": "registered",
#         "profile_image": "https://www.gravatar.com/avatar/56ee8428198683d9cb0af6fc55b01b83?s=256&d=identicon&r=PG",
#         "display_name": "Anil Gupta",
#         "link": "https://stackoverflow.com/c/imply/users/86/anil-gupta"
#       },
#       "is_answered": false,
#       "view_count": 5,
#       "answer_count": 0,
#       "score": 0,
#       "last_activity_date": 1639772865,
#       "creation_date": 1639772865,
#       "question_id": 4381,
#       "link": "https://stackoverflow.com/c/imply/questions/4381/lookups-loaded-during-native-batch-ingestion",
#       "title": "Lookups loaded during native batch ingestion"
#     },
#     {
#       "tags": [
#         "eng-druid"
#       ],
#       "owner": {
#         "account_id": 2152955,
#         "reputation": 300,
#         "user_id": 74,
#         "user_type": "registered",
#         "profile_image": "https://www.gravatar.com/avatar/97756482241b084d10f1d7869c61c20a?s=256&d=identicon&r=PG",
#         "display_name": "Jove Kuang",
#         "link": "https://stackoverflow.com/c/imply/users/74/jove-kuang"
#       },
#       "is_answered": false,
#       "view_count": 9,
#       "answer_count": 1,
#       "score": 0,
#       "last_activity_date": 1639702127,
#       "creation_date": 1639702080,
#       "question_id": 4378,
#       "link": "https://stackoverflow.com/c/imply/questions/4378/how-to-set-up-indexed-table-joins",
#       "title": "How to set up Indexed table joins?"
#     },
#     {
#       "tags": [
#         "onprem-manager"
#       ],
#       "owner": {
#         "account_id": 18909268,
#         "reputation": 3,
#         "user_id": 76,
#         "user_type": "registered",
#         "profile_image": "https://lh3.googleusercontent.com/a-/AOh14Giv_ojvkvtDIW69p173LiTp0NG0DesqBHxzPL8h=k-s256",
#         "display_name": "Jag Dhillon",
#         "link": "https://stackoverflow.com/c/imply/users/76/jag-dhillon"
#       },
#       "is_answered": true,
#       "view_count": 10,
#       "accepted_answer_id": 4376,
#       "answer_count": 1,
#       "score": 0,
#       "last_activity_date": 1639627859,
#       "creation_date": 1639528333,
#       "question_id": 4374,
#       "link": "https://stackoverflow.com/c/imply/questions/4374/query-scheduler-prioritzation-durationthreshold-not-working-bad-config",
#       "title": "Query.Scheduler.prioritzation.durationThreshold not working. Bad config"
#     },
#     {
#       "tags": [
#         "clarity"
#       ],
#       "owner": {
#         "account_id": 22962950,
#         "reputation": 5,
#         "user_id": 165,
#         "user_type": "registered",
#         "profile_image": "https://www.gravatar.com/avatar/679a07b0d0866740a22bf2b739fd70d8?s=256&d=identicon&r=PG",
#         "display_name": "Anil Makarand Mantravadi",
#         "link": "https://stackoverflow.com/c/imply/users/165/anil-makarand-mantravadi"
#       },
#       "is_answered": true,
#       "view_count": 27,
#       "answer_count": 1,
#       "score": 0,
#       "last_activity_date": 1639598631,
#       "creation_date": 1639520307,
#       "question_id": 4373,
#       "link": "https://stackoverflow.com/c/imply/questions/4373/clarity-metrics-sent-to-internal-dashboard",
#       "title": "Clarity metrics sent to internal Dashboard"
#     },
#     {
#       "tags": [
#         "eng-platform"
#       ],
#       "owner": {
#         "account_id": 21810242,
#         "reputation": 23,
#         "user_id": 132,
#         "user_type": "registered",
#         "profile_image": "https://www.gravatar.com/avatar/81da52cd6f0df2a6b0e189b2715737d8?s=256&d=identicon&r=PG",
#         "display_name": "Thomas Zino",
#         "link": "https://stackoverflow.com/c/imply/users/132/thomas-zino"
#       },
#       "is_answered": false,
#       "view_count": 11,
#       "answer_count": 1,
#       "score": 0,
#       "last_activity_date": 1639514519,
#       "creation_date": 1639513505,
#       "last_edit_date": 1639514316,
#       "question_id": 4371,
#       "link": "https://stackoverflow.com/c/imply/questions/4371/are-there-any-plans-for-larger-master-nodes-types-to-become-available",
#       "title": "Are there any plans for larger master nodes types to become available?"
#     },
#     {
#       "tags": [
#         "eng-druid"
#       ],
#       "owner": {
#         "account_id": 14477507,
#         "reputation": 389,
#         "user_id": 69,
#         "user_type": "registered",
#         "profile_image": "https://lh3.googleusercontent.com/-DgZtWib7mGo/AAAAAAAAAAI/AAAAAAAAAA4/T8jylh3viho/photo.jpg?sz=256",
#         "display_name": "Ben Krug",
#         "link": "https://stackoverflow.com/c/imply/users/69/ben-krug"
#       },
#       "is_answered": true,
#       "view_count": 20,
#       "accepted_answer_id": 4370,
#       "answer_count": 2,
#       "score": 0,
#       "last_activity_date": 1639499839,
#       "creation_date": 1638554515,
#       "question_id": 4337,
#       "link": "https://stackoverflow.com/c/imply/questions/4337/ingest-transform-timestamp-from-java-epoch-input",
#       "title": "ingest (transform) timestamp from java epoch input"
#     },
#     {
#       "tags": [
#         "eng-platform",
#         "imply-cloud"
#       ],
#       "owner": {
#         "account_id": 18017329,
#         "reputation": 85,
#         "user_id": 52,
#         "user_type": "registered",
#         "profile_image": "https://www.gravatar.com/avatar/7a3e8bca5f3e4809b36947e5b92c3d46?s=256&d=identicon&r=PG",
#         "display_name": "Jyoti Shekhar",
#         "link": "https://stackoverflow.com/c/imply/users/52/jyoti-shekhar"
#       },
#       "is_answered": true,
#       "view_count": 20,
#       "accepted_answer_id": 4368,
#       "answer_count": 1,
#       "score": 0,
#       "last_activity_date": 1639427330,
#       "creation_date": 1638561876,
#       "last_edit_date": 1638812608,
#       "question_id": 4338,
#       "link": "https://stackoverflow.com/c/imply/questions/4338/imply-cloud-and-aws-dedicated-hosts",
#       "title": "Imply Cloud and AWS dedicated hosts"
#     },
#     {
#       "tags": [
#         "eng-platform"
#       ],
#       "owner": {
#         "account_id": 17962080,
#         "reputation": 747,
#         "user_id": 35,
#         "user_type": "registered",
#         "profile_image": "https://lh3.googleusercontent.com/a-/AOh14GjVG74pSv6imayUc4tL-oI_0jJ3ZLiJKY8LFGqY=k-s256",
#         "display_name": "Gaurav Bhatnagar",
#         "link": "https://stackoverflow.com/c/imply/users/35/gaurav-bhatnagar"
#       },
#       "is_answered": false,
#       "view_count": 12,
#       "answer_count": 1,
#       "score": 0,
#       "last_activity_date": 1639423944,
#       "creation_date": 1638907502,
#       "last_edit_date": 1638916309,
#       "question_id": 4347,
#       "link": "https://stackoverflow.com/c/imply/questions/4347/how-can-we-enable-extension-imply-view-manager-in-imply-cloud",
#       "title": "How can we enable extension Imply View manager in Imply cloud"
#     },
#     {
#       "tags": [
#         "eng-apps"
#       ],
#       "owner": {
#         "account_id": 20902103,
#         "reputation": 43,
#         "user_id": 116,
#         "user_type": "registered",
#         "profile_image": "https://www.gravatar.com/avatar/71de5e641e25e9b482eba3f8af3589f2?s=256&d=identicon&r=PG",
#         "display_name": "Prashant Chauhan",
#         "link": "https://stackoverflow.com/c/imply/users/116/prashant-chauhan"
#       },
#       "is_answered": false,
#       "view_count": 12,
#       "answer_count": 0,
#       "score": 0,
#       "last_activity_date": 1639155830,
#       "creation_date": 1639155830,
#       "question_id": 4366,
#       "link": "https://stackoverflow.com/c/imply/questions/4366/text-overlapping-in-pivot-scheduled-reports",
#       "title": "text overlapping in pivot scheduled reports"
#     },
#     {
#       "tags": [
#         "eng-druid"
#       ],
#       "owner": {
#         "account_id": 6951686,
#         "reputation": 123,
#         "user_id": 75,
#         "user_type": "registered",
#         "profile_image": "https://i.stack.imgur.com/JU6Bo.jpg?s=256&g=1",
#         "display_name": "Hellmar Becker",
#         "link": "https://stackoverflow.com/c/imply/users/75/hellmar-becker"
#       },
#       "is_answered": true,
#       "view_count": 24,
#       "answer_count": 2,
#       "score": 0,
#       "last_activity_date": 1639148081,
#       "creation_date": 1639066613,
#       "question_id": 4361,
#       "link": "https://stackoverflow.com/c/imply/questions/4361/async-sql-endpoint-gives-me-a-405-error",
#       "title": "Async sql endpoint gives me a 405 error"
#     }
#   ],
#   "has_more": true,
#   "quota_max": 10000,
#   "quota_remaining": 9999
# }

# %% [markdown]
# ## View a single search result
#
# The `search/excerpts` API searches questions and answers on the site. This search is more limited than the web interface search. For example, searching "time_floor" as of 12/20/18 returns 3 results via the API and 14 via the web UI. It looks like the API does not capture results when "time_floor" is in a code block or code-formatted text.
#
# "time_parse" is another query to view the differences easily.

# %%
SEARCH_TERM = "query"

# %%
url = f"{BASE_URL}/search/excerpts?order=desc&sort=activity&body={SEARCH_TERM}&site=stackoverflow&team=stackoverflow.com%2fc%2f{TEAM_NAME}&key={APP_KEY}"
response = requests.request("GET", url, headers=headers)
#print(response.text)

data = response.json()
data["items"][0]
# Out:
# {'tags': ['eng-platform', 'platform'],
#  'question_score': 0,
#  'is_accepted': False,
#  'has_accepted_answer': True,
#  'answer_count': 1,
#  'is_answered': True,
#  'question_id': 4404,
#  'item_type': 'question',
#  'score': 0,
#  'last_activity_date': 1641495845,
#  'creation_date': 1641439269,
#  'body': 'One of our customers in us-east-1 is facing this issue when trying to change query node from c5.2xlarge to c5.4xlarge\nValidationError: The instance i-0809ef9f26e7f09b7 is not part of Auto Scaling group imply-9a68f050-c237-4e5a-ae9e-deafa976acbb-Query-KW58RH01X8XL-AutoScalingGroup-BOWXOKKZD7WX.\nThey also have following overrides\n\nHow can we fix this issue ?\nThank you so much\n',
#  'excerpt': 'One of our customers in us-east-1 is facing this issue when trying to change <span class="highlight">query</span> node from c5.2xlarge to c5.4xlarge\nValidationError: The instance i-0809ef9f26e7f09b7 is not part of Auto Scaling group &hellip; imply-9a68f050-c237-4e5a-ae9e-deafa976acbb-<span class="highlight">Query</span>-KW58RH01X8XL-AutoScalingGroup-BOWXOKKZD7WX. &hellip; ',
#  'title': 'ValidationError: The instance i-0809ef9f26e7f09b7 is not part of Auto Scaling group'}

# %% [markdown]
# ## Collect search results in a list
#
# NOTE: There is a bug in this cell that causes the `while` loop to evaluate infinitely. I'm not sure why the `keep_going` variable isn't properly set to False when `data["has_more"]` is False. As a workaround, use `custom_page_limit` to truncate the loop at a certain page count to prevent the notebook from running forever. (This is also why I have to remove duplicates in the second cell of this section.)

# %%
result_bodies = []
custom_page_limit = 50 # 30 results per page, use web UI to estimate page count

search_terms = ["query", "queries", "querying", "queried"]

for st in search_terms:

    page = 0
    keep_going = True
    url = f"{BASE_URL}/search/excerpts?order=desc&sort=activity&body={st}&site=stackoverflow&team=stackoverflow.com%2fc%2f{TEAM_NAME}&key={APP_KEY}#page={page}"
    print(f"searching: {st}")

    while keep_going and page < custom_page_limit:

        # increment page number of results
        page += 1
        if page%10 == 0:
            print(f"On page {page}")

        # make request
        response = requests.request("GET", url, headers=headers)
        data = response.json()

        # extract results, mydata is a list of dicts
        mydata = data["items"]
        for mydict in mydata:
            result_bodies.append(mydict["body"])

        keep_going = data["has_more"]
# Out:
# searching: query
# On page 10
# On page 20
# On page 30
# On page 40
# On page 50
# searching: queries
# On page 10
# On page 20
# On page 30
# On page 40
# On page 50
# searching: querying
# On page 10
# On page 20
# On page 30
# On page 40
# On page 50
# searching: queried

# %%
# remove duplicates
print(len(result_bodies))
result_bodies = list(set(result_bodies))
print(len(result_bodies))
# Out:
# 4515
# 92

# %%
# save result to, or read results from disk

#pickle.dump( result_bodies, open( "save.pickle", "wb" ) )

result_bodies = pickle.load( open( "save.pickle", "rb" ) )

# %%
result_bodies
# Out:
# ['Is it possibleto allow Users to only Access one Dashboard and the preconfigured Filters.\nSo this would mean that the user can not do any further Drilldown and also does not have access to the Values for Filters.\nIt would be great to have a way of only sharing the Data which is queried by the Dashboard and not allow anything else.\nWe are aware of the embedding Functionality in Pivot, however the user can easily circumvent this restriction by just visiting the normal Pivot UI.\nWe are also aware of the Filter Tokens, however since some of the Dashboards are very &quot;short lived&quot; (eg. only used during an Incident in the Network) this does not seems like a very easy to implement Solution.\nIs there some way of achieving this in Pivot or is this planned to be implemented?\n',
#  'Customer is in AWS cloud using imply cloud. while trying to access public load balancer endpoint to query it is giving a timeout exception. The same LB is used to work earlier. Tried to get some info using the verbose mode, seems it is failing at certificate validation.\ncurl -v -v -X &#39;POST&#39; -H &#39;Content-Type:application/json&#39; -d @query.sql&#160;https://imply-9a6-elbexter-1qqtjvie7symn-1403340306.us-east-1.elb.amazonaws.com:9088/druid/v2/sql&#160;-u admin:mumble --cacert 9a68f050-c237-4e5a-ae9e-deafa976acbb.crt\nNote: Unnecessary use of -X or --request, POST is already inferred.\n* Trying 3.223.17.199...\n* TCP_NODELAY set\n* Connection failed\n* connect to 3.223.17.199 port 9088 failed: Operation timed out\n* Trying 54.175.255.40...\n* TCP_NODELAY set\n* Connection failed\n* connect to 54.175.255.40 port 9088 failed: Operation timed out\n* Failed to connect to imply-9a6-elbexter-1qqtjvie7symn-1403340306.us-east-1.elb.amazonaws.com port 9088: Operation timed out\n* Closing connection 0\ncurl: (7) Failed to connect to imply-9a6-elbexter-1qqtjvie7symn-1403340306.us-east-1.elb.amazonaws.com port 9088: Operation timed out\nAlso from the same vpc in aws using the internal elb:\n* Trying 10.4.21.126...\n* TCP_NODELAY set\n* Expire in 149997 ms for 3 (transfer 0x55b806e26fb0)\n* Expire in 200 ms for 4 (transfer 0x55b806e26fb0)\n* connect to 10.4.21.126 port 9088 failed: Connection timed out\n* Trying 10.4.19.186...\n* TCP_NODELAY set\n* Expire in 134221 ms for 3 (transfer 0x55b806e26fb0)\n* connect to 10.4.19.186 port 9088 failed: Connection timed out\n* Failed to connect to internal-imply-9a6-elbinter-1a79ld347q4do-816246490.us-east-1.elb.amazonaws.com port 9088: Connection timed out\n* Closing connection 1\ncurl: (7) Failed to connect to internal-imply-9a6-elbinter-1a79ld347q4do-816246490.us-east-1.elb.amazonaws.com port 9088: Connection timed out\nWhat other info can we ask to debug the issue?\n',
#  'Some things to look at:\n\nScan isn&#39;t cacheable, regardless of your configuration, so if you&#39;re looking at cache hit rates it&#39;s best to focus on the topN queries. I&#39;m not sure if this is mentioned in the docs, but if it&#39;s not, then it should be.\n\nTo leverage the per-segment query cache, a query must be almost 100% identical to a prior query, with the only allowed difference being that the time filter might be slightly different. It&#39;s possible the queries that come in are too different. This isn&#39;t common when people use dashboards —&#160;those tend to generate a lot of very similar queries —&#160;but it can happen when querying is all ad-hoc.\n\nIf queries reference lookups that change often, then they won&#39;t be able to leverage cache very well, because whenever a lookup is updated the cache is invalidated.\n\nInstead of cache hit rate metrics (which aren&#39;t able to be broken down), try looking at the &quot;segments scanned&quot; and &quot;segments scanned + cache&quot; metrics in the Compute view in Clarity. These can be broken down by various dimensions to see if some kinds of queries have higher hit rates than others. Some potentially interesting dimensions: query type, datasource, num dimensions, num metrics, num complex metrics, identity, Pivot view, etc. You might see some patterns here. Maybe cache hit rates are high for some kinds of queries and low for others.\n\nRecall that the cache hit rates are all for the per-segment query cache, but, there are other kinds of caching. Segment data (not query results) is also cached in memory using the OS page cache. That doesn&#39;t show up in cache hit rate metrics.\n\n\n',
#  'Customer query:\n&quot;when we add filters on a datacube on multiple dimensions, from my understanding, they are using &#39;AND&#39;, however, we would like to see if either of the dimension filter applies. Is that a possibility?\nAlso, in imply dashboards, when we have global filters and then trying to overwrite it in a widget, we dont see the overwrite happening. Is there a way to overcome that?&quot;\nImply version :Imply v3.3.13.3 (Pivot v0.13.24).\nIs this valid request or can we achieve this ? please suggest\n',
#  'Parquet is a very efficient columnar format when used as input to a query engine such as Drill, Trino/Presto, Impala, Athena, etc. In general, just like a Druid segment, if your Parquet file has 20 columns, and you need only 10, then only 10 columns will be read. In addition to Tijo&#39;s like, general information is here: https://parquet.apache.org/ and here: https://github.com/apache/parquet-format\nCan you clarify the pipeline? Is the Parquet file itself pushed to Kafka? If so, then the Kafka client will probably see the file as a blob of bytes and transfer all the bytes of the file, even if you only read half the columns.\n',
#  'This is expected.  It is a side-effect of Druid&#39;s semi-schema-less nature.  The only difference internally between multi-value dimensions and single-value dimensions is that multi-value dimensions happen to have some rows with multiple values in them.  Now, when things are combined together into the same segment, the question of &quot;well, why can&#39;t you notice that it was an MVD and act like the single value is an MVD?&quot; seems to make sense.  It&#39;s better to think of this in terms of distributed data and the fact that Druid doesn&#39;t force the same schema to exist across segments.\nI.e. Imagine a world where, up until November of 2021,the column in question only ever had a single value, in which case it wasn&#39;t an MVD.  Now, starting from November, it happens to start having extra values and becomes an MVD.  For this case, the data before November didn&#39;t actually have an MVD in it.\nIf it is important for it to always be an array, it&#39;s important for the query itself to provide that knowledge of the schema (this is common for any sort of schemaless-system, when schema is required, it has to be built by the query).  We can do this by running the query with\n\nNote, however, there can be performance implications to this, so we should understand why someone wants to do this before just suggesting that they do it.\n',
#  'We looked at this one live a bit during office hours on Friday and found a couple of things:\n\nThere are nearly 300 million rows per day, and nearly 4 billion total rows in the table. The dashboard in question needs 10+ queries in order to render. The cluster has 48 processors on the data servers. So, with a day of data showing (the default), that&#39;s 3 billion rows that need to be processed by those 10 queries, which is about 62 million rows per processor. A lot of the queries are calculating uniques on strings, which is expensive. You might find it tough to process more than a few million rows per second per processor with that kind of query. So the math does indicate that this dashboard should take at least a few seconds to load, maybe up to 10.\n\nIndependently of the above processor-bin-packing math, there&#39;s also another situation: this datasource is doing streaming ingest into a single task. That tasks seems to be keeping up fine with ingestion, but it can become a query performance bottleneck for any queries that hit the realtime data. So it would be good to increase the number of tasks.\n\nA bunch of the queries are doing approx distinct counts on the  column, which is a string. That&#39;s a pretty slow operation. It would be better to load this as a sketch and then do approx distinct counts on the sketch. I bet that would speed up the row/processor scan rates substantially for those queries.\n\n\n',
#  'If you want segments to be marked as unused but still don&#39;t want them to be removed from metadata and deep storage, can we try to remove the data sources from &quot;Kill Data sources whitelist&quot; so that only the data sources mentioned in the &quot;Kill Data sources whitelist&quot; will be removed from metadata and deep storage by scheduled kill tasks. This way we can mark them unused(so that they won&#39;t be available for querying by data nodes) and also they will still remain in deep storage.\nDoes this help?\n',
#  'A customer has a reindexing job that uses stringLast on one field.  This produces output like\n\nApparently this is by design (see this issue), the left-hand side being the timestamp, and the rhs being the value.  (I&#39;ll file a docs jira to mention this.  I think it&#39;s fairly unexpected.)\nIt seems we can&#39;t do a transform or anything on this during the ingestion, iiuc.  (Transforms can be done on reading rows, but not on aggregated rows, it seems?  - Based on my attempts and reading.)  Is there a way to extract just the string, without a second reindexing?\nTo clarify (hopefully), I can extract the string if I do another re-indexing, with an expression transform.  But we don&#39;t seem to be able to do it all at once - stringLast, and extract the rhs.  Expression transforms work on input, not aggregated values (iiuc), and post-aggregations are for queries, not ingestions.\nIs my understanding correct, that this can&#39;t be done in a one-step reindexing?\n',
#  'If you run a topN against a query datasource, is the inner query materialized first?  Or do the topN thresholds push down to the inner query somehow?\nA customer has a SQL query that translates to a topN on an inner groupBy.  Running the inner groupBy returns 1760 rows.  topN thresholds are 5000.  When they run the whole query, results are different each time.  If the threshold is 5000, and the inner groupBy query consistently returns 1760 rows, why are the end results not consistent from run to run?\nThis is the SQL query:\nWITH MAU AS\n( SELECT lookup(lookup(game_id, &#39;game_id_studio_id&#39;), &#39;studio_id_org_id&#39;) as &quot;ORG&quot;, &quot;game_id&quot; as &quot;ID&quot;, COUNT(DISTINCT &quot;user_unique&quot;) AS &quot;MAU&quot;\nFROM &quot;live_dashboards_lean&quot;\nWHERE (&quot;__time&quot; between TIMESTAMP &#39;2021-09-01 00:00:00.00&#39; AND TIMESTAMP &#39;2021-10-01 00:00:00.00&#39;) and lookup(lookup(game_id, &#39;game_id_studio_id&#39;), &#39;studio_id_org_id&#39;) in (&#39;65126&#39;)\nGROUP BY 1,2)\nSELECT\n&quot;ORG&quot;, SUM(&quot;MAU&quot;) as MAU, COUNT(&quot;ID&quot;) as Nb_Games,\nCASE\nWhen SUM(&quot;MAU&quot;)&gt;20000000 Then &#39;1.Tier1&#39;\nWhen SUM(&quot;MAU&quot;)&gt;2000000 Then &#39;2.Tier2&#39;\nWhen SUM(&quot;MAU&quot;)&gt;100000 Then &#39;3.Mid sized&#39;\nELSE &#39;4.Small&#39;\nEND,\n&#39;paying&#39; as Paying\nFROM MAU\ngroup by 1\norder by 2\nRunning the inner SELECT returns 1760 unchanging rows.  Running the entire query gives different results each time.  Here&#39;s the explain plan (in S.O. unformat, sorry):\n\n',
#  'This is for the cloud customer. When we navigate to the Druid console -&gt; Data source page, we do not see any data. They have 34 data sources and can be queried in SYS tables to obtain all the results. In the Browser console, we do see the below\n\n\n\n\n\n\n\n\n\n\n\n\nThere are around 87530 data sources out of which only 34 are active and the rest are stale.\n\nThe druid_rules table had 17391 records which I have removed for the stale data sources. Currently, there are less than 100 records in the &quot;druid_rules&quot; table.\nQuestion: What might be causing this issue as I do not see any issue in API calls from the Browser capture?\n',
#  'Interesting idea, but not today.\nThere is an undocumented context parameter  that, if set to true, will skip the in-memory row store portion of MM querying. The on-disk data will still be queried. This lessens the load somewhat, at the cost of not reflecting the very latest data in queries.\nHowever, this parameter is undocumented, with the usual caveats that apply there:\n\nEnabling the parameter might cause unexpected errors due to lack of full testing.\nThe parameter&#39;s behavior may change, or it may be removed completely, without warning in a future release.\n\n',
#  'What should be the ideal segment granularity for the data source being accessed regularly?\nIn order to support queries that span large intervals customer would like to enable remote cache to allow segment level caching if the same data source is queried repeatedly for intervals ranging between 7-10 days.\nCan they utilize TTL in this?\n',
#  'There are a couple things to consider.\n\nWill re-indexing or compaction be done? -  Locking occurs at the segment level, having a larger granularity will cause more data to be locked.\nHow will data be queried? - If you&#39;re querying one hour of data at a time it is better to have a one-hour segment granularity, so you do not need to read unnecessary data.\nIs this a realtime source, with late-arriving data.  Having a small segment granularity means it is more likely that you will have new segments created due to late-arriving data.\n\nSo, what is &quot;better&quot; depends on the situation.  If all things are equal, and the query is covering the entire time period, it shouldn&#39;t make any query performance difference if the query spans multiple intervals or one interval with multiple shards.\n',
#  'There is a single tuning parameter for CorssTab: &quot;loadBatchSize&quot; it lives in Data Cube Options (Advanced tab) and controls how many cells get loaded at a time. The default is 80, setting it lower (like 5) might help but honestly I don&#39;t think it is worth your time to even try. The chances of success are tiny.\nIn Pivot 2.0 (alpha) which is coming out in the 2020.04 monthly release the loading has been greatly improved. In fact I would expect it to be the same speed as the table in the regular Pivot view. Note that the Table in Pivot 2.0 is functionally equivalent to the CrossTab view. This would be a much better bet.\nIn general the primary reason for the Pivot 2.0 view Alpha is to make sure we totally nail things like this, so if it DOES NOT work for some reason. I want to hear about it ASAP.\nThere are no current plans to port the more advanced Pivot 2.0 querying engine back to CorssTab at this time.\n',
#  'Customer has a use-case  where they want to store multiple values in a single row for a particular dimension.So they choose multi-value dimension.Cardinality of the multi-value dimension can reach several millions per segment for a time range of 5 minutes, as the segment granularity is 5 minutes.\nQuestions:\nIn order to reduce the cardinality of multi-dimension column, splitting of single multi-dimension column into two multi-dimension columns helps?\nDoes splitting into two multi-dimension columns increase the query performance?\nDoes combined cardinality of these two columns is going to remain the same in a segment?\nIf users try to combine these two multi-value dimension columns through queries, will it make any performance difference between a single column and two columns?\n',
#  'can you try the below? If this is not working, please share the full stack trace from the exception. We might have to fix the JDBC queries that we generate.\n\n',
#  'We had a scenario today with a customer, there was no data coming in via their kafka and dat source in question had a small retention period. This caused datasource to be marked as &quot;unused&quot; causing query failures and some amount of panic. Is there a config to not cause data source to be unused?\nCustomer would like to keep the data source active for queries and give out a message something like e.g. - “0 rows of data available in data source for the time period queried”\n',
#  'We saw that the repo for node.js druid SDK here https://github.com/7eggs/node-druid-query has been archived already. What&#39;s the best way to query Druid using node.js?\n',
#  'When we conduct cluster reviews for customers or even when trying to improve the performance of queries, I noticed a few things that are missing from Clarity and it would be very helpful to have Druid emit those metrics and to have Clarity show them:\n\nDimensions used in the query - ATM, TopN is the only query type that provides it, while groupBy queries provide only  (see https://druid.apache.org/docs/latest/operations/metrics.html#broker). Not sure what’s the reason behind this limitation, because you use dimensions for filtering in most/all queries, and you also you dimensions in groupBy queries (for the group by itself),\n\nMetrics used in the query - not reported at all, only  and  are reported.\n\nThe recency of the data scanned by the query - Druid provides the time interval used by each query (confusingly named  in Clarity), but no information about how far back this time interval is. For example, a  can be , which means the query is scanning a 5-minute time chunk. However, there’s no way to know if those are 5 minutes of realtime data (i.e data that’s still in the Peons), or 5 minutes from a week ago (meaning it’s historical data).\n\n\nIf we’d have this info, we would have been able to tune query performance more easily, e.g determine which dimension to use for secondary partitioning, understand if we should focus on tuning Peons or Historicals (based on the recency of the data scanned by queries), etc.\nThe way we do it now, is somewhat hacky and far from complete.\nFor example, Tijo wrote a script that parses a broker log (that you previously downloaded to your laptop), and produces a csv with a row per query, which contains the query type and the recency of the data scanned by the query. Then we use Excel or alike to aggregate that csv and find how many queries were querying the last day, 2 days, 3 days, etc. (or last hour, last 2 hours, etc. - you get the picture).\nWhile this script is very useful, we’ll certainly prefer to have this info, as well as the rest of the info I mentioned above, automatically accessible in Clarity.\nThis info will probably be useful for SaaS as well, since it was mentioned the SaaS product will learn the query pattern over time and optimize the system based on that.\nI might end up submitting a feature request as well, but I’d love to hear more thoughts about this topic.\nThanks!\n',
#  'You can set splitLimits in the datacube advance properties as below - (eg - I have updated 100 to 200)\n\n\nDoc Link -\nhttps://docs.imply.io/latest/managing-data-cubes/#querying-options\n',
#  '~~This isn&#39;t currently possible, but it seems like a good feature request, Thomas!~~\nEdit: I was wrong, I was thinking of this in terms of data cube options.\nThere are actually two ways you can limit the maximum time range on a data cube:\n\nIn Pivot SQL, you can create a data cube from a SQL query. Using Druid&#39;s SQL time functions, you could add a where clause to limit the amount of data in a data cube.\n\nThe &quot;subset filter&quot; function in Pivot works very similarly to a where clause. Subset filters currently use Plywood, but we&#39;ll be updating that very soon to use SQL expressions. It should also be possible to add a time filter this way.\n\n\n',
#  'A prospect on Google Cloud wants sub-second performance for queries that go up to 30 days.  They also want to be able to run queries that span 5 years of data, but they don&#39;t care how long those queries take to finish.  They ingest 300-400 GB of parquet/day (not sure about rollup).  5 years about that would be about 1.4 PB after replication.\nUntil true cold tier is available, the only affordable way I can think of doing this is to introduce a second tier with persistent disk space (similar to EBS in AWS).\nWhat is the maximum amount of data that can be served by a single historical node before it falls over, ideally in terms of GB/TB, but otherwise in terms of # of segments, # of rows, etc.\n',
#  'Team -\nour client has asked if we provide any KPIs for imply components. Do we have any general ranges for healthy service components (would this even be realistic?).\nSee original client query below:\n\nHow do we monitor the health and KPIs for every Druid component (coordinator, overlord, middleManager, peons, historicals, etc.)?\nWe would like to understand what metrics and values would mark each component as healthy / unhealthy, and what are the thresholds we can use for alerting on unhealthy conditions. If we had another Druid incident, we would like to have this information to be 1 click away and avoid having to look for the health of each component as we debug the incident.\n\n',
#  'I am working with Funimation, who is planning to deploy a 2-tier production cluster in Imply Cloud.  They were thinking of adding a 3rd tier of t2-small with no data in order to have extra ingestion/compaction capacity.  The idea is that, if they have an ingest job for which they want to allocate more capacity than is available on their primary tiers, this 3rd tier can do the work.\nIs this a sensible approach?  Would it enable them to allocate more capacity towards querying on their primary 2 tiers?\nPlease note...they don&#39;t want to just increase capacity on a primary tier since they would then exceed their licensed vcpus.\nThanks, Anil\n',
#  'Answers to most of these questions can be found here: https://druid.apache.org/docs/latest/querying/topnquery.html. As described in the doc, topN is best used when you have confidence that the results are uniformly in the top; for example if running a query to determine the most visited web page over a period of time, if a particular site ID is in the top 10 for some metric for every hour of every day, then it will probably be accurate in the topN over multiple days. By default, we retrieve the top 1000 results per segment, and then merge, to retrieve the top N results. This 1000 limit can be controlled via the config property . Note that the results of topN are only approximate if the dimension that you are running the query over has more than  unique dimension values, otherwise the results are exact. Note, all of this infomation is in the document linked.\n',
#  'It is not possible today to ingest a lookup using an ingestion spec. You will have to use the special way for them as described in the docs: https://druid.apache.org/docs/latest/querying/lookups.html.\nI agree, it&#39;d be nice to ingest lookup as regular tables, and why not, to have regular tables sometimes act as lookup. But these would be feature requests.\n',
#  'Try running the same query with  in the query context and that should generate a group by query instead of TopN and should give accurate results.\n',
#  'I started writing a lot of stuff but then deleted the whole thing to not throw you on the wrong track. The overhead of storing 5-year data can come in two forms\n\nThe raw amount of data / #rows - It would matter mostly when the data is being queried. But you already said that they don&#39;t care about the time it takes to run the query. You would need to tweak certain settings to make sure that those queries do not fail since we have many timeouts in place. There are some tips here - https://support.imply.io/hc/en-us/articles/360034310953-Tuning-Druid-for-Large-Result-Sets.  It would also affect the time taken in rolling upgrade since a historical has to download a huge amount of data to the local disk.\n\nThe number of segments - This is a more important parameter. Since the metadata that we keep in brokers, coordinator, etc is in proportion to the number of segments. The segment size itself won&#39;t affect the size of this metadata. The number of columns can but that I suppose is static across segments. You said that they have 1.4 PB data. If we have each segment sized to 1 GB, then it&#39;s roughly 1.4 million segments. That is high but not something we have seen before. Twitter has millions of segments and they are able to manage. On historical, in particular, you may run into the file descriptor limit and max_map_count limit so those numbers would have to be increased.\n\n\nThere could be more things I have not thought about. By the way, this customer looks like a good fit for cold-tier. I will be very much interested in learning what are they trying to do.\nUpdate - You would also need to tier the brokers. Twitter does that too based on a cluster review report I have (https://docs.google.com/document/d/1r0c1nV9VEyFx1y_b4_biDPCpDs3-rWokhXGmXzXwiTw/edit). Though broker tiering will be tricky if they want to use SQL instead of native queries. I can chat more offline about this if you want.\n',
#  'I think Eric is resisting taking your question at face value because he suspects there is a better big-picture solution than trying to optimize for this spiky workload. I share that feeling.\nMy thought is that we should understand what the purpose is of the every-30-min raft of queries is, and see if we can suggest an alternative. Eric raised the possibility that their purpose may be to cache data somewhere so a UI can be served off that cached data. If so, we should consider having the UI query Druid directly. That&#39;d be more in line with how our product is designed to be used.\nIf I take your question at face value, though, I&#39;d say the best approach is to size the cluster such that it can handle peak load and accept that it will be idle most of the time. (But! To be clear! I don&#39;t think this is the right way to answer it with the customer. I would keep digging into what the purpose of the queries is.)\n',
#  'With growing use of SQL, I expect we&#39;ll see more GROUP BY queries being used.  Customers often have failures, have to spill to disk, etc.  Would it make sense to revisit our recommendations for basic cluster tuning and suggest larger heap sizes for GROUP BY use cases?  (Would it be on historicals and brokers?)\n(Is this a docs question?)\n',
#  'I don&#39;t think this is related to Not able to install plywood package at all.\nPlywood is a JavaScript library that simplifies building interactive visualizations and applications for large data sets. Plywood acts as a middle-layer between data visualizations and data stores.\nThat said, they can probably write Javascript to query druid via REST API end points. Here&#39;s an example of how to write code in Javascript that queries REST API end points https://stackoverflow.com/questions/36975619/how-to-call-a-rest-web-service-api-from-javascript. That said, they can also look at the Javascript SDK https://github.com/dru-id/js-sdk.\n',
#  'Im working with a prospect in the FS space who has a requirement to ingest and query at nano time intervals. Due to the nature of the data some use cases explicitly require being able to distinguish at nanosecond.\nIs their a way to enable nano second query support for:\nIngestion - Although nano is supported i believe it truncates to milisecond for __time\nQuerying - being able to query using nanosecond. If I am able to store nanosecond as a long their is still a need to be able to query at nano second elegantly\n',
#  'There isn&#39;t a great way to do it, specifically because of this part of the ask:\n\nThe question was more into how they can calculate the CPU count here\n\nIf the number of CPUs was fixed and known, it would be easy to compute the CPU time: just take the average CPU utilization (which is in Clarity) for the period in question and multiply that by the number of CPUs.\nIt gets more complicated when the number of CPUs varies. I don&#39;t think there&#39;s a good way to answer this question with the Clarity UI. You might be able to solve it by querying the data directly or by downloading it and munging it offline. (You can&#39;t do this download from the Clarity UI, though. You&#39;d need direct access to the metrics-ext Druid cluster.)\nMaybe you can get most of the way there by doing the thing I mentioned above, in a piecewise manner (i.e.: multiply average CPU utilization by known CPU count for time periods where you know how many CPUs there are).\nAn addendum: if there is a recurring need for this, I think we actually could add a total CPU time metric to Clarity by emitting the stats as incremental time rather than utilization percentages, and by emitting them in a way that enables deduping of CPUs (one issue with the current way the data is emitted is that if there are two procs on the same machine, the stats for the same CPU are emitted twice. That doesn&#39;t matter when tracking average utilization -- so you don&#39;t notice it today -- but you&#39;d notice it if you were trying to do sums).\n',
#  'A community member (Nielsen Digital contractor) has encountered an interesting scenario regarding Load / Drop rules that uncovers a potential state of segments that is not covered in The Happy Path.  A similar scenario was also encountered in a POC at IronSource in 2020 and has been an on-and-off recurrent scenario in community channels.\nIs this understanding of the functionality of Load / Drop rules correct?\nIs there an alternative configuration that would meet requirements for this scenario?\n\nConsider this configuration:\n\nThere are 10 data sources\n\nThe  Load Forever rule has been removed\n\nA set of rules have been assigned to one of the datasources as follows:\n\nPeriod Load Rule - P1M --&gt; Hot Tier - repl 1\n\nPeriod Load Rule - P1Y --&gt; Default Tier - repl 2\n\n\n\n\nIn this configuration, no rules can be found that match segments that are for periods older than 1 year.  This warning is logged by the coordinator:\n\nExperiments show that data in these segments remains in the Segment Cache on historicals, and is advertised and is therefore queryable.  Their  status in the metadata database is unchanged.\nThe feedback has been that this is counter-intuitive: the configuration implies that only data newer than 1 year is queryable yet the data remains advertised without a cluster stop,  in each segment cache, and a restart.  Furthermore, older data continues to accumulate in historicals and thus for query.\nSince the docs state:\n\nIf a Load rule is used to retain only data from a certain interval or period, it must be accompanied by a Drop rule\n\nThe configuration below was proposed:\n\nPeriod Load Rule - P1M --&gt; Hot Tier\n\nPeriod Load Rule - P1Y --&gt; Default Tier\n\nDrop Forever\n\n\nThis has the desired effect of causing the coordinator to remove data from historicals.\n\nAll segments that match this rule are dropped from the cluster.\n\nHowever, experiments show the Drop rule marks these as &quot;unused&quot;.\nDocumentation states:\n\n[After publishing] metadata records have a boolean flag named&#160;, which controls whether the segment is intended to be queryable or not.\n\nThe unused flag has effects other than just keeping segments away from the historicals:\n\nThe unused segments are now candidates for Kill tasks (automated or manual) [see also https://druid.apache.org/docs/0.20.2/operations/rule-configuration.html#permanently-deleting-data\\]\n\nExtending Period Load Rule #2 past 1 year requires an extra step of marking all segments as used since &quot;when the Coordinator finds a segment that is published and used, but unavailable, it chooses a Historical process to load that segment and instructs that Historical to do so.&quot; [see also https://druid.apache.org/docs/0.20.2/operations/rule-configuration.html#reloading-dropped-data\\]\n\nThe order in which the operator sets rules is important - for example, if the default Load Forever is removed before this new configuration, the coordinator may mark some segments as unused before the new rules apply\n\n\nIn essence, there appears to be functional / documentation incongruity between the two use cases for rules.  One which is &quot;marking for deletion&quot; (ie, putting data in the recycle bin ready for Kill) and the second being &quot;marking as unqueryable&quot; (ie, a segment should not be made available for querying on a historical).\n',
#  'The limits are canned but can be customized via the  option in the advanced data cube options: https://docs.imply.io/latest/managing-data-cubes/#querying-options\n',
#  'IHAC who has very spiky workloads on their cluster. During business hours, their custom app will send a huge amount of queries into the cluster every 30 minutes but then the cluster is largely idle for 29 minutes out of the 30 minutes window.\nWhat are some of the things we can suggest to optimize the cluster with this workload pattern?\nWhat they are doing now is to simply put a 9 second timeout so that they proactively failing any queries that run longer than 9 seconds.\nIn addition, I suggest perhaps they can size the cluster (i.e. scale up) to accommodate that 1 minutes worth of traffics every 30 minutes. If cost is an issue, then they can look into scaling down the cluster during non business hours (9pm to 8am). But I am not sure what else to suggest to balance between cost and performance for spiky workload like this.\n',
#  'Short answer: it doesn&#39;t do anything during ingestion time and, if you don&#39;t specify it at query time, it doesn&#39;t affect your queries.\nLong answer:\nFirst off we should talk about what &quot;finalize&quot; means in the context of aggregation.\nAll aggregators have an &quot;intermediate&quot; type and a &quot;finalized&quot; type. For simple aggregators, like sum, min, max, etc, the intermediate and finalized types are the same (a single number). For theta sketches, the intermediate type is a theta sketch itself and the finalized type is a double representing the estimate of how many unique things are represented by that sketch.\nWhen things are finalized or not depends on the situation:\n\nIn ingestion, aggregations are not finalized.\nIn native queries, Druid finalizes all aggregations automatically for the outermost query but does not finalize aggregations for subqueries.\nIn SQL queries, aggregations are always finalized, regardless of whether they are in an outermost query or a subquery.\n\nFor theta sketches specifically (not all aggregators support this) setting  to  disables finalization. So if you put this in a query, you will get the actual sketch back, and you can use it directly if you want or feed it into some other system.\nSince &quot;not finalizing&quot; is the default for ingestion, specifying  at ingestion time doesn&#39;t change anything. It also doesn&#39;t affect how queries would work, unless you also specify  at query time. If you do that then you will get sketches back in queries instead of estimates.\n\nHow does it relate to the finalize query context parameter?\n\nFor a query,  does the same thing as , except it only applies to that one aggregator instead of all of them.\n',
#  'The customer has mention time diff calculation in the spec, but the expression&#39;s value is different than the value he is getting by doing the same calculation on the data stream (querying via druid).\nThis is the explain plan:\n{\n&quot;queryType&quot;: &quot;scan&quot;,\n&quot;dataSource&quot;: {\n&quot;type&quot;: &quot;table&quot;,\n&quot;name&quot;: &quot;CsvOutcomes&quot;\n},\n&quot;intervals&quot;: {\n&quot;type&quot;: &quot;intervals&quot;,\n&quot;intervals&quot;: [\n&quot;2021-10-02T13:00:36.000Z/146140482-04-24T15:36:27.903Z&quot;\n]\n},\n&quot;virtualColumns&quot;: [\n{\n&quot;type&quot;: &quot;expression&quot;,\n&quot;name&quot;: &quot;v0&quot;,\n&quot;expression&quot;: &quot;div((\\&quot;__time\\&quot; - timestamp_parse(\\&quot;request_date_time\\&quot;,null,&#39;UTC&#39;)),3600000)&quot;,\n&quot;outputType&quot;: &quot;LONG&quot;\n}\n],\n&quot;resultFormat&quot;: &quot;compactedList&quot;,\n&quot;batchSize&quot;: 20480,\n&quot;limit&quot;: 101,\n&quot;order&quot;: &quot;none&quot;,\n&quot;filter&quot;: null,\n&quot;columns&quot;: [\n&quot;__time&quot;,\n&quot;outcome_date_time&quot;,\n&quot;request_date_time&quot;,\n&quot;time_from_request&quot;,\n&quot;v0&quot;\n],\n&quot;legacy&quot;: false,\n&quot;context&quot;: {\n&quot;sqlOuterLimit&quot;: 101,\n&quot;sqlQueryId&quot;: &quot;a5af6863-6033-45ac-a946-dde47b88a3d7&quot;\n},\n&quot;descending&quot;: false,\n&quot;granularity&quot;: {\n&quot;type&quot;: &quot;all&quot;\n}\n}\n',
#  'The given queries will work for a single reservation as the number of events in a single reservation are not going to be too large.  If these queries end up nested down into something that eventually groups by reservationId and tries to do an aggregation across that, depending on scale factors, sadness might occur.\nCan we confirm that your customer is trying to build a view/load a page that is only talking about a single reservation and not trying to do analysis across all reservations?\nIf they are trying to do analysis that includes doing these aggregations across all reservations, more conversation might be required.\n',
#  'Please refer to the documentation of `count(distinct expr)` function here https://docs.imply.io/latest/druid/querying/sql/#aggregation-functions\n\nYou will have to add this flag `useGroupingSetForExactDistinct` and set it to `true` in query context to enable multiple exact distinct. This step is required in addition to disabling *useApproximateCountDistinct*\n',
#  'Pretty sure the answer is no, based on docs, but can a JDBC lookup query druid, or only MySQL or postgresql?  It would be cool if we could load a lookup based on a SQL query to druid itself.  (Eg, to load the latest value for a metric for each dimension.)\n',
#  'Very long IN clauses take a long time to plan.  (https://github.com/apache/druid/issues/7904)\nIf we have, eg,\n\nif you use\n\nyou&#39;ll likely get the same results much more quickly.\n(Or, for integer fields, you can cast to char, eg,\n\n)\nIs the fact that this query works and returns the same results as  a quirk of the current implementation, or is it expected and supported query behavior?\n',
#  'The number of segments scanned is zero for some queries in clarity.\nFound an article related to the issue - https://support.imply.io/hc/en-us/articles/360015272314-Why-am-I-getting-0-segments-s\\[%E2%80%A6\\]hin-Clarity-on-some-of-my-queries-that-I-run-on-Imply-Cloud-\nQuestions:\nAs per the article, query ID goes through a selection process - Is it a SQL query ID or native query ID?\nWhat is the percentage of the queries which do get full information?\nCan the percentage be changed?\nIs this dependent on load, or is this a fixed percentage?\n',
#  'The customer wants following clarity metrics to be sent to the internal Dashboard.\n1. Total Number of users connected to the system ( Pivot, other BI Tools and Ingestions/ETL)\n2. TP98, TP95 and TP90 reports.\n3. Total Number of queries ran on a daily basis and how many of them failed with what errors.\nWhat are all possible ways and how can we achieve it?\n',
#  'You have to attach the ingestion spec too. If I were to take a wild guess, it would be that there is ingestion time roll-up because of which  is always double the value they see at the query time.\nUpdate -\nLooked at the spec offline and they are indeed using  aggregation on the  column. Using  aggregation should fix the problem.\nFurther update -\n@Prashant - in response to your question in comments, adding my reply here\n@PrashantChauhan&#160;- doubleMax is one aggregator but we could have used any aggregation that picks one value out of the items being aggregated. e.g. lets say that you have two dimensions `A`, `B` and a metric that is equivalent to `len(A) - len(B)`.\nNow when you have the following input rows\n\nif you aggregate the above data with doubeSum aggregation on metric, you get&#160;\n\nThis is of course wrong and to fix it, you will have to use an aggregation method that keeps one value such as any, max, min, etc. Hope this explanation helps.\n',
#  '\nOn  &quot;Česk&#233; Budějovice&quot; is actually one value but druid treats it as multi-value.:\n\n--  are the  and  values of  in the segment, More details on different keys output definition can be found here SegmentMetadata queries, Hence  should be the max value for the column  in the segments queried.\n\nOn Dimensions, whether they are MVD or not\n\nI ran a sample ingestion with  but this doesn&#39;t reproduce the scenario you mentioned above hence ran below test:\nSample data:\n\nResult of SegmentMetadata query for \n\nPoints\n[a]: If you have a multivalue data (eg : druid will consider : for the  for the segment metadata query ran.\n[b]: if :,It means the column is multivalue-type rather than singlevalue-type like  instead of ,Rows might still just have 1 value or no values.\n[c]: if : then every rows for the dimension has one value , thats what  I saw in when in ingest .\nDuring indexing, the druid will try to set it  if it detects that all rows are the single value which is common so most columns, it&#39;s .\n',
#  'IHAC who wants to ingest data from Big Query using incremental queries (once a day.)\nThey are familiar with dbt and AirFlow and looking for a simple way to get set up:\n\nI couldn&#39;t find dbt support for Druid.&#160;https://docs.getdbt.com/docs/available-adapters&#160;we need an incremental strategy to ingest data. We need your support for that.&#160; We are planning to export 7-14 day&#160; csv data to GCS bucket daily and trigger a druid job to ingest that data with insert overwrite strategy (delete matching dates and insert new dates)\n\nHas anybody come across a similar scenario? It&#39;s fairly simple but I wouldn&#39;t want to reinvent the wheel if there is something I can reuse.\n',
#  'According to this blog post from 4 years ago, there&#39;s no fault tolerance in the Druid query execution path. This means developers who write codes to query Druid will need to deal with retries in their own code upon query failures. Is that correct?\nAs a reference, Snowflake seems to offer automated query retries so that developers don&#39;t need to build this retry logic into their own code.\n',
#  'IHAC who has been running OSS Druid in production. One of the major issues they run into that they want to know we can help solve is a hot spot issue where only 10% of their data nodes are being hit by queries.\nThis is because they have 5 trillion rows (400TB) spanning across 2 years worth of data. However, most of their queries are querying the most recent 90 days worth of data, which located on 10% of the data nodes.\nHow can this issue be avoided? e.g. perhaps is there a data distribution strategy where Druid distribute data across let say 100 data nodes not by a hash of sorts so that the most recent 90 days worth of data (out of 2 years) will be spread across 100% of the data nodes instead of just 10% of them?\n',
#  'That log doesn&#39;t look much like a broker log given all of the stuff about kafka stream processors and such, but it still maybe tells us something.\nThis is just a shot in the dark but... do you know if they are querying the broker directly for JDBC, or querying the router? JDBC has stateful connections, so the same broker host should be used for the connection, and I&#39;m not sure if there is any sort of redirect in place. The router will ensure that the JDBC requests always go to the correct broker for a given connection.\nThe  in the more detailed exception makes me wonder if they are perhaps querying the broker directly, and maybe querying a different broker for some of part of the back of forth of requests that happens between the client and the broker when using a JDBC prepared statement. This could happen if the broker is behind a load balancer for example, and might explain why the query still ends up working if the requests end up going to the same broker that does have the correct connection state.\nIf they are actually querying the router then there might be something else going on, but this is my best guess right now.\n',
#  'The smallest public subnet supported by GCP is a /29 which has 8 ips per subnet * 3 az&#39;s = 24 ips. I personally would not want to use anything less than a /28 per subnet * 3 az&#39;s = 48 ips\nAs for counting the actual pods/instances, public IP usage depends on whether they deploy the public ingress.\nFor private IPS, from a test cluster, we use 3 for the k8s system pods, 3 for the manager zk instances, 1 for the manager, and then a basic cluster has 3 for the cluster zk instances, 3 for the cluster master instances, 1 for the clsuter data instance, and 1 for the cluster query instance, for a total of 15\n',
#  'There are two situations that query results would be non-deterministic.\n\nIf the variance is an aggregated measure and the variance is small (&lt; 1.0) then they are probably aggregating a float or double.  Floating-point calculations can vary slightly. If exact calculations are required, use  type.  If you need decimal values, you can store in multiply by the factor you need.   For instance, for US currency, instead of storing a value as $1.50 you would store it as 150 and divide by 100 at query time.\nThe underlying data is changing.  While most frequently this means real-time data arriving, it could also be historical nodes failing or other changes in the environment that lead to less then 100% of segments being queried.\n\n',
#  'Is it possible to intersect/union theta sketches from multiple tables?  The use case is that I have multiple &quot;data feeds&quot; and I want to get a distinct count of the hvid_sketch after union/intersecting the data feeds.  The queries will always be filtered on the datafeed.  Datafeed is a more important partition than time.  As such, I&#39;m wondering if it&#39;s better to have each datafeed in its own table.\nMy current pattern has all data in a single table\n\nIs there a possibility, or is it desirable, to use one table per datafeed since date is not a very important partition?  Each per-datafeed table would have 1M-300M records.\nIf so, what would the SQL look like?\nThanks, Anil\n',
#  'How do we monitor the health and KPIs for every Druid component (coordinator, overlord, middleManager, peons, historicals, etc.)?\n\nAs mentioned above, using status API is your best bet if you want additional monitoring. The service will either be online or offline. There is nothing in terms of status where service is in a degraded state.\n\nFor each of the use cases, you need to monitor the metrics that you care about. More on this later.\n\n\nWe would like to understand what metrics and values would mark each component as healthy / unhealthy, and what are the thresholds we can use for alerting on unhealthy conditions.\n\nThe threshold is whether service is up or not.\n\nIf we had another Druid incident, we would like to have this information to be 1 click away and avoid having to look for the health of each component as we debug the incident.\nWhat to monitor beyond service status:\n\nFor ingestion &amp; storage\n\nYou want to monitor storage utilization, this depends on how comfortable you are running your cluster close to the limit.\n\nYou want to monitor ingestion latency, events rejected and batch job failures if there is any. Those are usually an indicator of something is wrong.\n\n\n\nFor balancing\n\nYou can check load status https://docs.imply.io/latest/monitoring/#druid-status-apis This will tell you if segments are loaded and being served.\n\n\nFor query\n\nYou want to monitor query latency, failure rate and wait time. Those will tell you if the cluster is serving your load well.\n\n\n\nAll those are available as part of clarity setup today.\n',
# ...
#  'Why do they suddenly get a bunch of queries every 30 minutes?  Do they have 30 minute meetings and every time someone exits a meeting they have to load a dashboard which does a bunch of queries?  Or, is it some programmatic thing that is doing queries, caching those results for 30 minutes and actually servicing the end-user UI from that cache?\nIt is important to know why the batch of queries comes in so regularly and what the purpose of those queries is in order to suggest a proper optimization.\n',
#  'When we set  as -50 under datacube option, and when we view the data in the datacube, then queries getting submitted in the background is having   as -49.\n\nDuring testing, I noticed that if we set  as 0 then submitted queries will have  as 1 and if we set  as 10  the. submitted queries will have  as 11. (  is getting incremented by 1 )\nI also noticed that we are seeing this issue for &#160;and&#160;&#160;queries, but not for &#160;queries.\nI have tested this on on Imply Version 2021.09\n',
#  'We get this question from time to time.\nWhen loading a new datasource, or recovering from a multiple hardware failure, datasources can show only a fraction of the segments loaded and queryable.\nThe questions are:\n\nWhat happens during this state?\nAre the data sources still queryable?\nIs there anything returned in the payload to denote that not all the data has been queried?\nIs there any way to make queries fail if datasources aren&#39;t fully available?\n\n',
#  'I want to use  aggregator in a Pivot data cube. So I created this custom aggregation in the Pivot advanced section\n\nAnd in pivot data cube added a new measure  to refer this. However its not working and giving the below UI\n\nI checked the monitor queries and I see the native json query is getting created correctly as below\n\nWhen I run this native query in druid console it works however it shows those decimals in the pivot screen. How do I fix this?\n',
#  'Querying and storing data into S3 sounds like an option but customer will face possible issues with query timeouts. If the dataset is not very large then query and storing data into S3 will be a quicker to implement option. This is a less invasive operation but not suitable for large dataset.\nYour other option is more invasive because it will require metadata extraction, copy segments over to the next cluster but it will be more efficient for large dataset.\n',
#  'I am trying to submit an async SQL query but I get a 405 status and no query running:\n\nWhat am I doing wrong?\nThis is using Imply 2021.11 on GKE enhanced, and I am using  instead of a properly set up ingress. (due to customer constraints)\n',
#  'In Clarity we can break down queries by dimensions. This provides insight on which dimensions are queried more frequently. When breaking down by dimensions we also see null. I like to understand in what situations a query will have null as dimension value. This is unclear. Attached screenshot shows the breakdown of null dimension value by query types for reference.\n\n',
#  'As I understand it, we don&#39;t get the druid api user id into Clarity today.&#160;Are we somehow planning to fix this in the future?&#160;(My customer, Xandr, doesn&#39;t have the ability to enforce the use of sqlQueryId&#39;s for tagging queries.).\n',
#  'I want to store sensor event data rolled up and aggregated by hour.  However, it needs to be queried and displayed from the perspective of a user in any time zone.  Events can originate from any time zone and should also be able to be queried/viewed from the perspective of any time zone.\nIs 15 minutes the maximum granularity I can use to accomplish this goal given that there are :30 and :45 offsets?  We can probably safely ignore the :45 offsets.  But, viewing data from the perspective of the :30 offsets (in particular, India) is required.  How does Druid handle queries using a specific timezone?\nExample: let&#39;s say you have sensors streaming event data from buildings in 2 different timezones (India GMT+5:30 and Perth GMT+7).  The user viewing this data is in a third timezone (Atlanta GMT-4).  The user wants to display the average value of the sensors by hour using their time zone (Atlanta GMT-4).\nSuper simple example:\n\n',
#  'In general, the preferred approach here would be to have one table with all of the dimensions and theta sketches for those.  You would then filter and merge (union) those sketches at query time to produce the absolute best (minimal error) result.\nIf they don&#39;t like that approach for cost reasons, two things:\n\nI wonder what the cost differential really is\nThat cost differential is necessarily trading off error rates and there are just physical limitations\n\nFor getting in the door with them, it might be most interesting to understand what the analysis they are doing is (i.e. what are they forecasting?) and see if there is something we can do with them.  The &quot;Frequency Capping&quot; stuff might be interesting?\n',
#  'Ah, the phrasing in the docs is misleading. What it&#39;s trying to say is that: if all you want to do with a particular column is approximate-count-distinct it, then we recommend enabling rollup and using an ingestion-time sketching approach. This usually improves storage footprint and cost, especially if rollup enables a reduction in row count. It also means you wouldn&#39;t use the  aggregator at query time; instead you&#39;d use the appropriate sketch aggregator, like  or .\nThe doc shortens all of this to &quot;use hyperUnique instead of cardinality&quot; but IMO that is too shorthand to really make sense.\nAnother point: we actually don&#39;t recommend using either  or  anymore for new use cases, since they use the builtin HLL functionality. The DataSketches versions are more accurate, and in some cases faster, so we recommend those instead. If you&#39;re using Pivot SQL then you can get the DataSketches implementation using .\nThe recommendation to use DataSketches is mentioned at https://druid.apache.org/docs/latest/querying/aggregations.html#cardinality-hyperunique, but is not mentioned in the doc you linked.\n',
#  'Plywood\nIn a Plywood data cube, if you have a measure with a formula like  then plywood will pick whatever algorithm is appropriate for the &quot;user&quot; column. What does plywood know if the user column you ask? Well in the Advanced tab of the data cube you can see the column type definitions:\n\nSo if the column is defined as , , or  it will use the appropriate algorithm: , ,  respectively so you would want to make sure it is marked as  in your case. Note that if the type is not specified then it is assumed to be  and  is used.\nPivotSQL\nIn a PivotSQL data cube there are less &#39;smarts&#39; and things are more straightforward:\nYou just type the function you want to use in the formula:\n\nYou can use any function that you see in https://druid.apache.org/docs/latest/querying/sql.html now or in the future!\n',
#  'That issue is effectively talking about how resources are allocated and handed out to queries.  The most important part of knowing if it is fixed is understanding how and why someone is running into it.  It should, generally speaking, be possible to protect a cluster from ever getting into that state.\nIf we have a customer that is saying that they believe that they are getting into that state, it would be very good to have an understanding of why they believe that.  What are the symptoms, what does the cluster look like in Clarity, etc.\n',
#  'This looks like a query planning bug. You can see more details about the failure in the broker log. You might need to enable debug logging to see the trace.\nFor advanced troubleshooting - you might want to watch the video in https://implydata.atlassian.net/wiki/spaces/ENG/pages/1089142834/Querying+Calcite+Rules+and+Planning that shows how to debug what&#39;s going on. Alternatively, please file a REQ ticket for this so the team can triage and fix if this is in fact a bug. (From your description, it sure sounds like a regression)\n',
#  'I have the following query in a POC\n\nthis computes a theta sketch on 2 events in two separate sources and does an intersect after the join. Running the above query gives an error\nI can see the following in broker log\nexception&quot;:&quot;org.apache.calcite.plan.RelOptPlanner$CannotPlanException: There are not enough rules to produce a node with desired properties: convention=DRUID, sort=[].\\nMissing conversion is LogicalSort\nThe following query works but takes a long time as it first joins and then aggregates. Why does the query above not work? I wanted to aggregate and join as it will reduce the amount of data to be joined\n\nthe following query works (it is the same intersect query on a single source)\n\n',
#  'I did see this pattern with couple of other customers in the past 2 plus years where the customer added additional tier not to store segments but only to add additional worker slots for their ingestions.\nThey added load rules for their existing data sources to send the segments to only existing and old tiers but not to this new tier which was created only for ingestion tasks.\nFor your question on querying capacity, I would say RELATIVELY yes because the same ingestion jobs running on this new tier would have taken the resources(like cpu) on those existing tiers.\n',
#  'Can you use the defaultLimitSpec for this?\nhttps://docs.imply.io/latest/druid/querying/limitspec/#defaultlimitspec\n',
#  'This is configurable in the Clarity emitter: https://docs.imply.io/latest/monitoring/#clarity-emitter-configurations\nBy default, the following is sampled:\nsampledMetricsList: [&quot;query/wait/time&quot;, &quot;query/segment/time&quot;, &quot;query/segmentAndCache/time&quot;]\nsampledNodeTypesList: [&quot;druid/historical&quot;, &quot;druid/peon&quot;, &quot;druid/realtime&quot;]\n[EDIT] Tijo also provided this list which we are checking:\nThese are the metrics which are not sampled: (thanks Tijo!)\nquery/time\nquery/node/ttfb\nquery/node/time\nquery/node/bytes\nquery/cpu/time\nquery/bytes\n',
#  'A very cost-conscious client would like to downsize their environment. The biggest roadblock is the number of tasks they have running - about 13-16 at a time, mostly streaming ingestion, for each of their 2 data nodes.\nHowever, only 4-5 of these ingestions are sizeable; most of them are very small and do not ingest a lot.\nThe client has m5d.4xlarges at the moment. Those come with 6 worker slots by default; basic cluster tuning suggests that a middlemanager can have up to (# of CPUs - 1) task slots. They have 16.\nSince the client has a lot of very small ingestions, what are the risks of worker capacity exceeding the number of cores? The basic cluster tuning page suggests that this will lead to CPU contention; is this still the case if none of the ingestions requires a lot of CPU?\nBasic cluster tuning offers a lot more calculations/suggestions for memory than for CPU; are there are any CPU/core-related guidelines to be aware of?\nTiering &amp; laning can be used to prioritize resources, including CPU, for queries; are there any options that would let the client do something similar for their streaming ingestions without adding resources?\n',
#  'Queries are timing out when ran from tableau, pivot, druid. Tentative data size is around 200gb, query nodes configs are 60gb RAM 8cores.\nBroker log Error traces :-\n2021-09-15T11:43:26,890 WARN [qtp588389652-138[dataSourceMetadata_[wiki-data]_02038e1f-c79a-4f65-a3ae-437e6b45d16a]] org.apache.druid.server.QueryLifecycle - Exception while processing queryId [02038e1f-c79a-4f65-a3ae-437e6b45d16a] (org.apache.druid.query.QueryCapacityExceededException: Too many concurrent queries, total query capacity of 39 exceeded. Please try your query again later.)\nBroker properties are :- jvm.config.xms=-Xms22g\njvm.config.xmx=-Xmx22g\njvm.config.xmx.MaxDirectMemorySize=-XX:MaxDirectMemorySize=50g\ndruid.processing.buffer.sizeBytes=1500000000\ndruid.processing.numThreads=2\ndruid.broker.http.numConnections=20\ndruid.processing.numMergeBuffers=25\n#druid.processing.numMergeBuffers=25\ndruid.server.http.numThreads=40\ndruid.query.groupBy.maxOnDiskStorage=1000000000\ndruid.query.groupBy.maxMergingDictionarySize=1073741824\ndruid.query.groupBy.numParallelCombineThreads=2\ndruid.sql.avatica.maxConnections=500\nI tried tuning the parameters like druid.processing.numThreads, druid.broker.http.numConnections  but restart failed with query does not available message.\nI wanted to confirm if this issue happening because of fewer resources? When their long-running query is in the process, other queries are also slowing down.\nAsked them to change the property druid.server.http.numThreads=80\nafter the changes query is still timing out.\nBroker log :-  WARN [sql[729c4385-9d68-47b8-86e5-6b4bbb8e5298]] org.apache.druid.server.QueryLifecycle - Exception while processing queryId [55cb6a5c-0c60-4167-a58f-bc90be41a8db] (org.apache.druid.query.QueryTimeoutException: Sequence iterator timed out waiting for data)\nWARN [HttpClient-Netty-Worker-0] org.apache.druid.java.util.http.client.NettyHttpClient - [POST http://apslp0836.uhc.com:8083/druid/v2/\\] Exception thrown while processing message, closing channel.\norg.apache.druid.query.QueryTimeoutException: Query[55cb6a5c-0c60-4167-a58f-bc90be41a8db] url[http://apslp0836.uhc.com:8083/druid/v2/] timed out.\n\n',
#  'Imply version : 2021.04\nOne of our customers is facing bit strange issue where OLD version is NOT getting overshadowed even after manually making used=false in metadata for OLD version.\nOLD version is dropped from the historical nodes and ONLY NEW version is present in the historical node.\nThe query for 06/01/2021 and 06/02/2021 is  NOT returning any data as BOTH versions are NOT overshadowed even though used=false for older versions.\nCoordinator, broker and historicals are restarted. It did not help.\nThe historical on which segments are loaded is stopped, segments are marked unused, then segments are marked as used and NEW version segments got loaded into new historical and when queried , the broker sent the query to this new historical but still data is not returned .\nThis is happening only for 06/01/2021 and 06/02/2021. The days before 06/01/2021 are good and the days after 06/02/2021 are good and the query is returning data.\nThey usually run re-indexing job every day for some previous day to change segment granularity from HOUR to DAY and query granularity from 1 minute to 15 minutes.\nQuestions :\n1 - In what cases , does druid refuse to overshadow OLD version segment even though used=false for that OLD version segment ?\n2 - Why does query returns NO Data even though there is ONLY new version segment in historical node and broker is sending the query to that historical node correctly ?\n']

# %%
# define stop words to ignore
custom_words = ["query", "use", "quot", "datum", "druid", "time", "segment", "may", "want", "one", "run", "see"]
ENGLISH_STOP_WORDS = set( stopwords.words('english') ).union(custom_words)


def remove_URL(sample):
    """Remove URLs from a sample string
    https://gist.github.com/MrEliptik/b3f16179aa2f530781ef8ca9a16499af"""
    return re.sub(r"http\S+", "", sample)

def tokenize(sentence):
    gen = gensim.utils.simple_preprocess(sentence, deacc=True)
    return ' '.join(gen)

def remove_stopwords(text):
    text_list = text.split()
    filtered_sentence = [w for w in text_list if not w in ENGLISH_STOP_WORDS]
    return ' '.join(filtered_sentence)

def lemmatize(nlp, text):
    # remove URLs
    text = remove_URL(text)
    
    # parse sentence using spacy
    # https://spacy.io/usage/spacy-101#pipelines
    doc = nlp(text) 
  
    # convert words into their simplest form (singular, present form, etc.)
    lemma = []
    for token in doc:
        if (token.lemma_ not in ['-PRON-']):
            lemma.append(token.lemma_)
    
    # lowercase, tokenize, rejoin
    token_text = tokenize(' '.join(lemma))
    
    # remove stopwords
    go_text = remove_stopwords(token_text)
          
    return go_text

# %%
# convert words to basic forms by lemmatizing
nlp = spacy.load("en_core_web_sm", disable=['ner'])
result_bodies = [lemmatize(nlp, x) for x in result_bodies]

# aggregate all records into one large string
large_string = ' '.join(result_bodies)
print(large_string[:100])
# Out:
# possibleto allow user access dashboard preconfigure filters would mean user drilldown also access va

# %% [markdown]
# ## Visualize term frequencies

# %%
# apply stop words and run wordcloud on term frequency
word_cloud = WordCloud(
    background_color="white",
    max_words=5000, 
    width=900, 
    height=700, 
    contour_width=3, 
    contour_color='steelblue'
)

# display our wordcloud across all records
plt.figure(figsize=(10,10))
word_cloud.generate(large_string)
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# apply stop words and run wordcloud on term frequency
word_cloud = WordCloud(
    background_color="white",
    max_words=5000, 
    width=900, 
    height=700, 
    contour_width=3, 
    contour_color='steelblue',
    stopwords=ENGLISH_STOP_WORDS.union(["value", "broker", "would", "like", "also", "get", "way", 
                                        "need", "customer", "issue", "ingestion", "dimension", "column", 
                                        "historical", "try", "load", "pivot", "set", "result", "table", 
                                        "case", "question", "look", "thing", "day", "type", "cluster",
                                        "new", "work", "fail", "user", "cpu", "data", "source", 
                                        "well", "good", "node", "sql", "imply", "number", "minute"
                                       ]),
)

# display our wordcloud across all records
plt.figure(figsize=(10,10))
word_cloud.generate(large_string)
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Determine most frequent bigrams

# %%
# https://www.nltk.org/howto/collocations.html
# tokenize string then analyze bigrams
tokens = gensim.utils.simple_preprocess(large_string, deacc=True)
pairs = nltk.bigrams(tokens)

# construct a BigramCollocationFinder for all bigrams in the given sequence
# it's a tool for the finding and ranking bigram collocations
finder = nltk.collocations.BigramCollocationFinder.from_words(pairs)

# ignore all bigrams which occur less than three times in the corpus
finder.apply_freq_filter(3)

# list top ten bigram collocations, as measured using Pointwise Mutual Information
bigram_measures = nltk.collocations.BigramAssocMeasures()
words = finder.nbest(bigram_measures.pmi, 10)

d = sorted(finder.ngram_fd.items(), key=lambda t: (-t[1], t[0]))[:20]
d
# Out:
# [((('multi', 'value'), ('value', 'dimension')), 6),
#  ((('cache', 'hit'), ('hit', 'rate')), 5),
#  ((('period', 'load'), ('load', 'rule')), 5),
#  ((('amazonaws', 'com'), ('com', 'port')), 4),
#  ((('basic', 'cluster'), ('cluster', 'tuning')), 4),
#  ((('connect', 'port'), ('port', 'fail')), 4),
#  ((('east', 'elb'), ('elb', 'amazonaws')), 4),
#  ((('elb', 'amazonaws'), ('amazonaws', 'com')), 4),
#  ((('load', 'rule'), ('rule', 'gt')), 4),
#  ((('multi', 'dimension'), ('dimension', 'column')), 4),
#  ((('try', 'tcp_nodelay'), ('tcp_nodelay', 'set')), 4),
#  ((('us', 'east'), ('east', 'elb')), 4),
#  ((('connection', 'fail'), ('fail', 'connect')), 3),
#  ((('million', 'row'), ('row', 'per')), 3),
#  ((('number', 'row'), ('row', 'per')), 3),
#  ((('sum', 'mau'), ('mau', 'gt')), 3)]

# %%
# visualize the bigram frequencies

wordlabels = list(zip(*reversed(d)))[0]
frequency = list(zip(*reversed(d)))[1]
x_pos = range(len(wordlabels)) 

plt.figure(figsize=(5,10))
plt.barh(x_pos, frequency, align='center')
plt.yticks(x_pos, wordlabels) 

plt.title('Most Frequently Occurring Bigrams')
plt.ylabel('Bigram')
plt.xlabel('# of Occurences')
# Out:
# Text(0.5, 0, '# of Occurences')
