# %% [markdown]
# # Stack Overflow Topic Search
#
# Created: 15 Dec 2021
# Last edited: 16 Dec 2021

# %% [markdown]
# ## Setup to use this notebook
#
# 1. Set up your Python environment.
#
# ```
# # create a new conda env called "topic"
# conda create --name topic
# conda activate topic
#
# # install packages
# conda install -c anaconda pyyaml pandas nltk gensim
# conda install -c conda-forge jupyterlab jira wordcloud matplotlib spacy
# pip install stackapi
# ```
#
# 2. Request access to the teams Stack Overflow by registering a new app on Stack Apps.
#
#   Follow the instructions on [Stack Overflow for Teams API](https://stackoverflow.help/en/articles/4385859-stack-overflow-for-teams-api). Use `stackexchange.com` for the OAuth domain ([source](https://stackapps.com/a/7858)) and for the application website (where users go to read about the application).
#
# ## References
# * Stack Exchange's [API reference docs](https://api.stackexchange.com/docs/)

# %%
import json
import pickle
import re
import requests

import gensim
import spacy
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# do this one time only
#import nltk
#nltk.download('stopwords')
#spacy.cli.download("en_core_web_sm")

# %%
BASE_URL = "https://api.stackexchange.com/2.3"
TEAM_NAME = "imply"
APP_KEY = "xxx"
ACCESS_TOKEN = "xxx"

headers = {
  'X-API-Access-Token': ACCESS_TOKEN,
}

# %% [markdown]
# ## Run a test request to check the connection

# %%
url = f"{BASE_URL}/questions?order=desc&sort=activity&site=stackoverflow&team=stackoverflow.com%2fc%2f{TEAM_NAME}&key={APP_KEY}"
response = requests.request("GET", url, headers=headers)
pretty_json = json.loads(response.text)
print(json.dumps(pretty_json, indent=2))

# %% [markdown]
# ## View a single search result

# %%
url = f"{BASE_URL}/search/excerpts?order=desc&sort=activity&body=sql&site=stackoverflow&team=stackoverflow.com%2fc%2f{TEAM_NAME}&key={APP_KEY}"
response = requests.request("GET", url, headers=headers)
#print(response.text)

data = response.json()
print(data["has_more"])
data["items"][0]["body"]
# Out:
# True
# 'The number of segments scanned is zero for some queries in clarity.\nFound an article related to the issue - https://support.imply.io/hc/en-us/articles/360015272314-Why-am-I-getting-0-segments-s\\[%E2%80%A6\\]hin-Clarity-on-some-of-my-queries-that-I-run-on-Imply-Cloud-\nQuestions:\nAs per the article, query ID goes through a selection process - Is it a SQL query ID or native query ID?\nWhat is the percentage of the queries which do get full information?\nCan the percentage be changed?\nIs this dependent on load, or is this a fixed percentage?\n'

# %% [markdown]
# ## Collect search results in a list

# %%
page = 0
#custom_page_limit = 10

url = f"{BASE_URL}/search/excerpts?order=desc&sort=activity&body=sql&site=stackoverflow&team=stackoverflow.com%2fc%2f{TEAM_NAME}&key={APP_KEY}#page={page}"

result_bodies = []

"""
WARNING: I don't think this while is properly triggered, need to fix
"""

keep_going = True
while keep_going:
#    if page == custom_page_limit:
#        break
    
    # increment page number of results
    page += 1
    if page%10 == 0:
        print(f"On page {page}")
    
    # make request
    response = requests.request("GET", url, headers=headers)
    data = response.json()
    
    # extract results, mydata is a list of dicts
    mydata = data["items"]
    for mydict in mydata:
        result_bodies.append(mydict["body"])
    
    keep_going = data["has_more"]
# Out:
# On page 10
# On page 20
# On page 30
# On page 40
# On page 50
# On page 60
# On page 70
# On page 80
# On page 90
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /var/folders/s1/fglgkfxd3cv8xfvw1yx_qhnw0000gn/T/ipykernel_63681/1043490416.py in <module>
#      18     # make request
#      19     response = requests.request("GET", url, headers=headers)
# ---> 20     data = response.json()
#      21
#      22     # extract results, mydata is a list of dicts
#
# ~/miniconda3/envs/topic/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# ~/miniconda3/envs/topic/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/miniconda3/envs/topic/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/miniconda3/envs/topic/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
print(page)
len(result_bodies)
# Out:
# 33215
# 996420

# %%
# save result to, or read results from disk

#pickle.dump( result_bodies, open( "save.pickle", "wb" ) )

full_result_bodies = pickle.load( open( "save.pickle", "rb" ) )

# %%
#for i, x in enumerate(result_bodies):
#    print(i, x)

# truncate the result_bodies from the messed up while loop
result_bodies = full_result_bodies[:30]
result_bodies
# Out:
# ['The number of segments scanned is zero for some queries in clarity.\nFound an article related to the issue - https://support.imply.io/hc/en-us/articles/360015272314-Why-am-I-getting-0-segments-s\\[%E2%80%A6\\]hin-Clarity-on-some-of-my-queries-that-I-run-on-Imply-Cloud-\nQuestions:\nAs per the article, query ID goes through a selection process - Is it a SQL query ID or native query ID?\nWhat is the percentage of the queries which do get full information?\nCan the percentage be changed?\nIs this dependent on load, or is this a fixed percentage?\n',
#  'I am trying to submit an async SQL query but I get a 405 status and no query running:\n\nWhat am I doing wrong?\nThis is using Imply 2021.11 on GKE enhanced, and I am using  instead of a properly set up ingress. (due to customer constraints)\n',
#  'Just to add what Vaibhav said, you can go through  https://github.com/implydata/druid/blob/master/imply-sql-async/README.md which has all the configs which need to be set.\n',
#  'In case this helps , I was just trying to test this feature locally for the 1st time and went through the following in context to this issue -\n(1) If I blindly  post the query as yours (without any async specific configuration) then I get the same error as above (i.e )\n\n(2) Then I read the following doc - https://docs.imply.io/2021.11/druid/querying/sql-async-download/ and set the  in the Brokers run time -\nThis helped me in resolving  but I encountered a \n\n(3) Further while looking at the broker log for the above error I find there was an  error saying -\n\n(4) Then I defined the  in the broker&#39;s runtime properties - Post that I was able to POST async queries -\n\nAsync specific configurations needs to placed in case they are already not configured ( by default - They are not ) before using this feature.\n',
#  '~~This isn&#39;t currently possible, but it seems like a good feature request, Thomas!~~\nEdit: I was wrong, I was thinking of this in terms of data cube options.\nThere are actually two ways you can limit the maximum time range on a data cube:\n\nIn Pivot SQL, you can create a data cube from a SQL query. Using Druid&#39;s SQL time functions, you could add a where clause to limit the amount of data in a data cube.\n\nThe &quot;subset filter&quot; function in Pivot works very similarly to a where clause. Subset filters currently use Plywood, but we&#39;ll be updating that very soon to use SQL expressions. It should also be possible to add a time filter this way.\n\n\n',
#  'Actually, there is a way  in druid where u can get the results in CSV. I saw this question a long time back but and I had used this during my initial days in imply, but had short memory :(.\nYou can use the  as csv. Ref the doc\nYou could extract the data using the curl command\ncurl  -k -XPOST -H&#39;Content-Type: application/json&#39; -uadmin&#160;https://&lt;internal lb &gt;:9088/druid/v2/sql/&#160;-d @query.json &gt; output.csv\nquery.json file :\n{\n&quot;query&quot; : &quot;SELECT COUNT(*) FROM data_source WHERE __time &gt;= TIMESTAMP &#39;2000-01-01 00:00:00&#39; AND __time &lt; TIMESTAMP &#39;2000-01-02 00:00:00&#39;&quot;,\n&quot;resultFormat&quot; : &quot;csv&quot;,\n&quot;context&quot; : {\n&quot;priority&quot; : -10\n}\n}\n',
#  'Customer is in AWS cloud using imply cloud. while trying to access public load balancer endpoint to query it is giving a timeout exception. The same LB is used to work earlier. Tried to get some info using the verbose mode, seems it is failing at certificate validation.\ncurl -v -v -X &#39;POST&#39; -H &#39;Content-Type:application/json&#39; -d @query.sql&#160;https://imply-9a6-elbexter-1qqtjvie7symn-1403340306.us-east-1.elb.amazonaws.com:9088/druid/v2/sql&#160;-u admin:mumble --cacert 9a68f050-c237-4e5a-ae9e-deafa976acbb.crt\nNote: Unnecessary use of -X or --request, POST is already inferred.\n* Trying 3.223.17.199...\n* TCP_NODELAY set\n* Connection failed\n* connect to 3.223.17.199 port 9088 failed: Operation timed out\n* Trying 54.175.255.40...\n* TCP_NODELAY set\n* Connection failed\n* connect to 54.175.255.40 port 9088 failed: Operation timed out\n* Failed to connect to imply-9a6-elbexter-1qqtjvie7symn-1403340306.us-east-1.elb.amazonaws.com port 9088: Operation timed out\n* Closing connection 0\ncurl: (7) Failed to connect to imply-9a6-elbexter-1qqtjvie7symn-1403340306.us-east-1.elb.amazonaws.com port 9088: Operation timed out\nAlso from the same vpc in aws using the internal elb:\n* Trying 10.4.21.126...\n* TCP_NODELAY set\n* Expire in 149997 ms for 3 (transfer 0x55b806e26fb0)\n* Expire in 200 ms for 4 (transfer 0x55b806e26fb0)\n* connect to 10.4.21.126 port 9088 failed: Connection timed out\n* Trying 10.4.19.186...\n* TCP_NODELAY set\n* Expire in 134221 ms for 3 (transfer 0x55b806e26fb0)\n* connect to 10.4.19.186 port 9088 failed: Connection timed out\n* Failed to connect to internal-imply-9a6-elbinter-1a79ld347q4do-816246490.us-east-1.elb.amazonaws.com port 9088: Connection timed out\n* Closing connection 1\ncurl: (7) Failed to connect to internal-imply-9a6-elbinter-1a79ld347q4do-816246490.us-east-1.elb.amazonaws.com port 9088: Connection timed out\nWhat other info can we ask to debug the issue?\n',
#  'NaN can be ingested into a double field.  We can find them in SQL using CAST(myNum AS CHAR) = &#39;NaN&#39;.\nHow can I write an ingestion filter to exclude rows where myNum is NaN?  A &quot;not&quot; filter for &quot;value&quot;: &quot;NaN&quot; doesn&#39;t work.  Can I transform with CAST then filter out if the result is &#39;NaN&#39;? (I&#39;m not sure how to transform then filter out based on the result.)  Is there a better way?\n',
#  'Pretty sure the answer is no, based on docs, but can a JDBC lookup query druid, or only MySQL or postgresql?  It would be cool if we could load a lookup based on a SQL query to druid itself.  (Eg, to load the latest value for a metric for each dimension.)\n',
#  'If you run a topN against a query datasource, is the inner query materialized first?  Or do the topN thresholds push down to the inner query somehow?\nA customer has a SQL query that translates to a topN on an inner groupBy.  Running the inner groupBy returns 1760 rows.  topN thresholds are 5000.  When they run the whole query, results are different each time.  If the threshold is 5000, and the inner groupBy query consistently returns 1760 rows, why are the end results not consistent from run to run?\nThis is the SQL query:\nWITH MAU AS\n( SELECT lookup(lookup(game_id, &#39;game_id_studio_id&#39;), &#39;studio_id_org_id&#39;) as &quot;ORG&quot;, &quot;game_id&quot; as &quot;ID&quot;, COUNT(DISTINCT &quot;user_unique&quot;) AS &quot;MAU&quot;\nFROM &quot;live_dashboards_lean&quot;\nWHERE (&quot;__time&quot; between TIMESTAMP &#39;2021-09-01 00:00:00.00&#39; AND TIMESTAMP &#39;2021-10-01 00:00:00.00&#39;) and lookup(lookup(game_id, &#39;game_id_studio_id&#39;), &#39;studio_id_org_id&#39;) in (&#39;65126&#39;)\nGROUP BY 1,2)\nSELECT\n&quot;ORG&quot;, SUM(&quot;MAU&quot;) as MAU, COUNT(&quot;ID&quot;) as Nb_Games,\nCASE\nWhen SUM(&quot;MAU&quot;)&gt;20000000 Then &#39;1.Tier1&#39;\nWhen SUM(&quot;MAU&quot;)&gt;2000000 Then &#39;2.Tier2&#39;\nWhen SUM(&quot;MAU&quot;)&gt;100000 Then &#39;3.Mid sized&#39;\nELSE &#39;4.Small&#39;\nEND,\n&#39;paying&#39; as Paying\nFROM MAU\ngroup by 1\norder by 2\nRunning the inner SELECT returns 1760 unchanging rows.  Running the entire query gives different results each time.  Here&#39;s the explain plan (in S.O. unformat, sorry):\n\n',
#  'You can create a formula based dimension where you can use AND , OR type expressions across dimensions. Below is a quick example in a SQL data cube.\n\nWRT: Your second question, If there&#39;s an internal filter inside a given widget then it will be overwritten by the global filter.\n',
#  'Cluster creation in GKE, where the sql instance is created via TerraForm.\nImply manager displays message saying\nMySQL: SQLInvalidAuthorizationSpecException: (conn=2957) Access denied for user &#39;imply&#39;@&#39;10.128.69.69&#39; (using password: YES) Current charset is UTF-8. If password has been set using other charset, consider using option &#39;passwordCharacterEncoding&#39; (ref: 9b03963a-203e-4375-ba13-b4c9a05565cf)\nMysql version is 5.7.\nis it that mysql 5.7 doesn&#39;t supports ?\nAs per this https://stackoverflow.com/questions/54188309/mariadb-connection-client-access-denied-for-user-using-password-no-on-mysql/54190598\nfrom mysql8 we are supposed to change the encoding type.\n',
#  'It would be able to read from JDBC using the SQL input source: https://druid.apache.org/docs/latest/ingestion/native-batch.html#sql-input-source\n',
#  'In Druid, do we have a function(in Plywood or SQL) that would calculate the rate of increase of a dimension over a time period?\nFor Example, if we have data as below and after applying the rate function, it would return\nData:\n\nAfter applying the function:\n\nIn Imply docs, I see that we have a function called  , But from the function definition, I see that it is calculating the average of values overtime a period instead of the difference between values.\nhttps://docs.imply.io/latest/measures/#rates\nKindly let us know if we have a function in druid to achieve this use case?\n',
#  'Imagine I am a hotel chain, and I want to query on a specific reservation id.\nThe history of the reservation might be as follows:\n2021-01-01; queen room, 3 nights, $120\n2021-01-05; queen room, 4 nights, $120\n2021-01-08; king room, 3 nights, $150\nI want to query the latest state of the reservation and understand how the room rate changed.  Basically, I want to get this:\n2021-01-08; king room, 3 nights, $150, $30\n{where $30 is the change in the nightly room rate}\nCan I achieve this using Druid SQL?  If not, will it be possible when we implement Window functions?\n',
#  'See stringLast Aggregator - Result should be directly the rhs value for an answer.  (If you ingest with stringLast, use stringLast (native) or LATEST (SQL) to extract the rhs value.\n',
#  'Short answer: it doesn&#39;t do anything during ingestion time and, if you don&#39;t specify it at query time, it doesn&#39;t affect your queries.\nLong answer:\nFirst off we should talk about what &quot;finalize&quot; means in the context of aggregation.\nAll aggregators have an &quot;intermediate&quot; type and a &quot;finalized&quot; type. For simple aggregators, like sum, min, max, etc, the intermediate and finalized types are the same (a single number). For theta sketches, the intermediate type is a theta sketch itself and the finalized type is a double representing the estimate of how many unique things are represented by that sketch.\nWhen things are finalized or not depends on the situation:\n\nIn ingestion, aggregations are not finalized.\nIn native queries, Druid finalizes all aggregations automatically for the outermost query but does not finalize aggregations for subqueries.\nIn SQL queries, aggregations are always finalized, regardless of whether they are in an outermost query or a subquery.\n\nFor theta sketches specifically (not all aggregators support this) setting  to  disables finalization. So if you put this in a query, you will get the actual sketch back, and you can use it directly if you want or feed it into some other system.\nSince &quot;not finalizing&quot; is the default for ingestion, specifying  at ingestion time doesn&#39;t change anything. It also doesn&#39;t affect how queries would work, unless you also specify  at query time. If you do that then you will get sketches back in queries instead of estimates.\n\nHow does it relate to the finalize query context parameter?\n\nFor a query,  does the same thing as , except it only applies to that one aggregator instead of all of them.\n',
#  'With growing use of SQL, I expect we&#39;ll see more GROUP BY queries being used.  Customers often have failures, have to spill to disk, etc.  Would it make sense to revisit our recommendations for basic cluster tuning and suggest larger heap sizes for GROUP BY use cases?  (Would it be on historicals and brokers?)\n(Is this a docs question?)\n',
#  'I am trying to set up a simple example of python druid connecting to demo-dev cluster\nThe Druid SQL I am trying to create in pydruid is below\n\nQuery Explain\n\nMy Code is below\n\nError message I am seeing\n\nThis is a code code issue as I have already opened up the security groups on AWS to allow access from my machine\n\n',
#  'IHAC who is using druid Dynamic parameters in a JDBC statement but the query fails while JDBC prepare statement is executed.\nI tried reproducing this issue with simplified query and seems I am able to reproduce it, below are the excerpt -\nImply 2021.08- Tried running the SQL statement vai JDBC code and it fails with\n\nJDBC statement-\n\nSnippet from Broker log-\n\n(1) I tried the same query via HTTP post and it works fine .\nEDIT: Eg below query via HTTP POST works fine\n\n(2) Also when i put  directly  in the place of placeholde (?) , it works fine.\nQuestion -\nDoes it sound like a BUG and I should create a JIRA or Am I making any mistake here ?\n',
#  'Queries are timing out when ran from tableau, pivot, druid. Tentative data size is around 200gb, query nodes configs are 60gb RAM 8cores.\nBroker log Error traces :-\n2021-09-15T11:43:26,890 WARN [qtp588389652-138[dataSourceMetadata_[wiki-data]_02038e1f-c79a-4f65-a3ae-437e6b45d16a]] org.apache.druid.server.QueryLifecycle - Exception while processing queryId [02038e1f-c79a-4f65-a3ae-437e6b45d16a] (org.apache.druid.query.QueryCapacityExceededException: Too many concurrent queries, total query capacity of 39 exceeded. Please try your query again later.)\nBroker properties are :- jvm.config.xms=-Xms22g\njvm.config.xmx=-Xmx22g\njvm.config.xmx.MaxDirectMemorySize=-XX:MaxDirectMemorySize=50g\ndruid.processing.buffer.sizeBytes=1500000000\ndruid.processing.numThreads=2\ndruid.broker.http.numConnections=20\ndruid.processing.numMergeBuffers=25\n#druid.processing.numMergeBuffers=25\ndruid.server.http.numThreads=40\ndruid.query.groupBy.maxOnDiskStorage=1000000000\ndruid.query.groupBy.maxMergingDictionarySize=1073741824\ndruid.query.groupBy.numParallelCombineThreads=2\ndruid.sql.avatica.maxConnections=500\nI tried tuning the parameters like druid.processing.numThreads, druid.broker.http.numConnections  but restart failed with query does not available message.\nI wanted to confirm if this issue happening because of fewer resources? When their long-running query is in the process, other queries are also slowing down.\nAsked them to change the property druid.server.http.numThreads=80\nafter the changes query is still timing out.\nBroker log :-  WARN [sql[729c4385-9d68-47b8-86e5-6b4bbb8e5298]] org.apache.druid.server.QueryLifecycle - Exception while processing queryId [55cb6a5c-0c60-4167-a58f-bc90be41a8db] (org.apache.druid.query.QueryTimeoutException: Sequence iterator timed out waiting for data)\nWARN [HttpClient-Netty-Worker-0] org.apache.druid.java.util.http.client.NettyHttpClient - [POST http://apslp0836.uhc.com:8083/druid/v2/\\] Exception thrown while processing message, closing channel.\norg.apache.druid.query.QueryTimeoutException: Query[55cb6a5c-0c60-4167-a58f-bc90be41a8db] url[http://apslp0836.uhc.com:8083/druid/v2/] timed out.\n\n',
#  'I started writing a lot of stuff but then deleted the whole thing to not throw you on the wrong track. The overhead of storing 5-year data can come in two forms\n\nThe raw amount of data / #rows - It would matter mostly when the data is being queried. But you already said that they don&#39;t care about the time it takes to run the query. You would need to tweak certain settings to make sure that those queries do not fail since we have many timeouts in place. There are some tips here - https://support.imply.io/hc/en-us/articles/360034310953-Tuning-Druid-for-Large-Result-Sets.  It would also affect the time taken in rolling upgrade since a historical has to download a huge amount of data to the local disk.\n\nThe number of segments - This is a more important parameter. Since the metadata that we keep in brokers, coordinator, etc is in proportion to the number of segments. The segment size itself won&#39;t affect the size of this metadata. The number of columns can but that I suppose is static across segments. You said that they have 1.4 PB data. If we have each segment sized to 1 GB, then it&#39;s roughly 1.4 million segments. That is high but not something we have seen before. Twitter has millions of segments and they are able to manage. On historical, in particular, you may run into the file descriptor limit and max_map_count limit so those numbers would have to be increased.\n\n\nThere could be more things I have not thought about. By the way, this customer looks like a good fit for cold-tier. I will be very much interested in learning what are they trying to do.\nUpdate - You would also need to tier the brokers. Twitter does that too based on a cluster review report I have (https://docs.google.com/document/d/1r0c1nV9VEyFx1y_b4_biDPCpDs3-rWokhXGmXzXwiTw/edit). Though broker tiering will be tricky if they want to use SQL instead of native queries. I can chat more offline about this if you want.\n',
#  'Anil, I think this question was in relation to a specific POC and that POC is making progress with all of the data feeds in a single table, correct?  IIRC, the datafeeds all have the same schema, in which case it does actually make sense to keep them in the same table (even if time is not the most &quot;natural&quot; initial partition point).\nTechnically speaking, if two sketches were built on top of the same set of ids, you can merge them.  In terms of SQL, I can imagine SQL that would do that query cross-table, but I am unclear on whether we will plan and execute that query.\n',
#  'Is it possible to intersect/union theta sketches from multiple tables?  The use case is that I have multiple &quot;data feeds&quot; and I want to get a distinct count of the hvid_sketch after union/intersecting the data feeds.  The queries will always be filtered on the datafeed.  Datafeed is a more important partition than time.  As such, I&#39;m wondering if it&#39;s better to have each datafeed in its own table.\nMy current pattern has all data in a single table\n\nIs there a possibility, or is it desirable, to use one table per datafeed since date is not a very important partition?  Each per-datafeed table would have 1M-300M records.\nIf so, what would the SQL look like?\nThanks, Anil\n',
#  'Recently discovered the  keyword which greatly simplifies this query:\n\nIf the docs team is watching here: the  keyword does not seem to show in the SQL area where I would expect it.\n',
#  'See: https://cloud.google.com/sql/docs/mysql/private-ip\nGoogle Cloud service can be peered to use private networking. This is different than how it works in AWS as it&#39;s not actually running in the VPC but able to be securely accessed from the VPC without public access.\n',
#  'IHAC who wants to write a Pivot measure (SQL) to aggregate data (sum) but only for the last day of the selected period.\nSpeaking blond something like:\nSUM(t.&quot;Sales&quot;) FILTER (WHERE t.&quot;__time&quot; = MAX(t.&quot;__time&quot;))\nExample:\n\nCustomer select 30 days June 15th - July 16th\n\nThe query we are looking for is calculating SUM(t.&quot;Sales&quot;) only for July 16th\n\nAlle other measures should be calculated for June 15th - July 16th\n\n\n',
#  'Ah, the phrasing in the docs is misleading. What it&#39;s trying to say is that: if all you want to do with a particular column is approximate-count-distinct it, then we recommend enabling rollup and using an ingestion-time sketching approach. This usually improves storage footprint and cost, especially if rollup enables a reduction in row count. It also means you wouldn&#39;t use the  aggregator at query time; instead you&#39;d use the appropriate sketch aggregator, like  or .\nThe doc shortens all of this to &quot;use hyperUnique instead of cardinality&quot; but IMO that is too shorthand to really make sense.\nAnother point: we actually don&#39;t recommend using either  or  anymore for new use cases, since they use the builtin HLL functionality. The DataSketches versions are more accurate, and in some cases faster, so we recommend those instead. If you&#39;re using Pivot SQL then you can get the DataSketches implementation using .\nThe recommendation to use DataSketches is mentioned at https://druid.apache.org/docs/latest/querying/aggregations.html#cardinality-hyperunique, but is not mentioned in the doc you linked.\n',
#  'IHAC who is intrested in defiening the exact disctinct count metric in pivot.\n\nBased on what I learned so far -\n[1] In plywood style pivot - Its not possible.\n[2] In Pivot 2.0 , It could be achieved using druid SQL functions ( by defining a measure using pivot sql) along with setting up or  , \nI read below references-\nHow can I create 2 metrics in Pivot, 1 exact distinct count and 1 approximate distinct count?\nCould you please cofirm if my undersatnding is correct or kindly correct me,\n',
#  'Currently if a datasource has no rows then it is not queryable through SQL. That can happen if all data for the datasource has been dropped.\nThe main reason things are like this is that datasources have no defined schema. The SQL layer needs a schema for query validation, which it builds up from the data that actually is loaded into the datasource. If no data exists, then there is no way for us to build up a schema, and so you can’t query it with SQL.\nOne approach to get the behavior you want is to use native queries. Unlike SQL, they don’t validate schema, and so they will work fine in datasources that have no data. They will just return no rows.\nBtw: The only way to prevent the datasource from becoming unused and completely empty is to avoid dropping the last bit of data in the datasource. If data comes in very irregularly then this means you’d want to have a longer duration drop rule, or maybe even not have a drop rule at all.\nBtw #2: in terms of future dev work, a way to break this chain with SQL is to actually have a defined schema. In SaaS we will have this at the table level and I’d like to use it for SQL queries too. This would enable SQL queries to function as you expect on a table with no data in it.\n']

# %%
# define stop words to ignore
custom_words = ["sql", "query", "use", "time", "druid", "imply", "quot", "datum", "try", "run", "want", "function", "fail", "pivot", "table"]
ENGLISH_STOP_WORDS = set( stopwords.words('english') ).union(custom_words)


def remove_URL(sample):
    """Remove URLs from a sample string
    https://gist.github.com/MrEliptik/b3f16179aa2f530781ef8ca9a16499af"""
    return re.sub(r"http\S+", "", sample)

def tokenize(sentence):
    gen = gensim.utils.simple_preprocess(sentence, deacc=True)
    return ' '.join(gen)

def remove_stopwords(text):
    text_list = text.split()
    filtered_sentence = [w for w in text_list if not w in ENGLISH_STOP_WORDS]
    return ' '.join(filtered_sentence)

def lemmatize(nlp, text):
    # remove URLs
    text = remove_URL(text)
    
    # parse sentence using spacy
    # https://spacy.io/usage/spacy-101#pipelines
    doc = nlp(text) 
  
    # convert words into their simplest form (singular, present form, etc.)
    lemma = []
    for token in doc:
        if (token.lemma_ not in ['-PRON-']):
            lemma.append(token.lemma_)
    
    # lowercase, tokenize, rejoin
    token_text = tokenize(' '.join(lemma))
    
    # remove stopwords
    go_text = remove_stopwords(token_text)
          
    return go_text

# %%
# convert words to basic forms by lemmatizing
nlp = spacy.load("en_core_web_sm", disable=['ner'])
result_bodies = [lemmatize(nlp, x) for x in result_bodies]

# aggregate all records into one large string
large_string = ' '.join(result_bodies)
print(large_string[:100])
# Out:
# number segment scan zero clarity find article relate issue question per article go selection process

# %% [markdown]
# ## Visualize term frequencies

# %%
# apply stop words and run wordcloud on term frequency
word_cloud = WordCloud(
    background_color="white",
    max_words=5000, 
    width=900, 
    height=700, 
    contour_width=3, 
    contour_color='steelblue'
)

# display our wordcloud across all records
plt.figure(figsize=(10,10))
word_cloud.generate(large_string)
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# apply stop words and run wordcloud on term frequency
word_cloud = WordCloud(
    background_color="white",
    max_words=5000, 
    width=900, 
    height=700, 
    contour_width=3, 
    contour_color='steelblue',
    stopwords=ENGLISH_STOP_WORDS.union(["case", "doc", "filter", "process", "get", "would", "like", "also", "type", "broker", "count", "instead", "finalize", "see", "post", "way", "set"]),
)

# display our wordcloud across all records
plt.figure(figsize=(10,10))
word_cloud.generate(large_string)
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Determine most frequent bigrams

# %%
# https://www.nltk.org/howto/collocations.html
# tokenize string then analyze bigrams
tokens = gensim.utils.simple_preprocess(large_string, deacc=True)
pairs = nltk.bigrams(tokens)

# construct a BigramCollocationFinder for all bigrams in the given sequence
# it's a tool for the finding and ranking bigram collocations
finder = nltk.collocations.BigramCollocationFinder.from_words(pairs)

# ignore all bigrams which occur less than three times in the corpus
finder.apply_freq_filter(3)

# list top ten bigram collocations, as measured using Pointwise Mutual Information
bigram_measures = nltk.collocations.BigramAssocMeasures()
words = finder.nbest(bigram_measures.pmi, 10)

d = sorted(finder.ngram_fd.items(), key=lambda t: (-t[1], t[0]))[:20]
d
# Out:
# [((('amazonaws', 'com'), ('com', 'port')), 4),
#  ((('east', 'elb'), ('elb', 'amazonaws')), 4),
#  ((('elb', 'amazonaws'), ('amazonaws', 'com')), 4),
#  ((('sum', 'mau'), ('mau', 'gt')), 3)]

# %%
# visualize the bigram frequencies

wordlabels = list(zip(*reversed(d)))[0]
frequency = list(zip(*reversed(d)))[1]
x_pos = range(len(wordlabels)) 

plt.figure(figsize=(5,10))
plt.barh(x_pos, frequency, align='center')
plt.yticks(x_pos, wordlabels) 

plt.title('Most Frequently Occurring Bigrams')
plt.ylabel('Bigram')
plt.xlabel('# of Occurences')
# Out:
# Text(0.5, 0, '# of Occurences')
