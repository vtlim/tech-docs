# %% [markdown]
# # Big data file formats
#
# Version: 27 Sep 2022
#
# Sandbox to play around and convert data to various formats:
# * Avro
# * ORC
# * Parquet
# * Protobuf
#
# This Python environment was set up using conda with the following commands:
# ```
# conda create -n formats
# conda activate formats
# conda install -c conda-forge pyarrow
# #conda install -c conda-forge python-avro
# conda install -c conda-forge pandavro
# conda install -c anaconda protobuf
# conda install -c anaconda jupyter
# conda install -c anaconda pandas
# ```

# %% [markdown]
# ## Parquet
#
# Uses Apache Arrow
#
# https://arrow.apache.org/docs/python/parquet.html

# %%
import pandas as pd

from pyarrow import json as pj
import pyarrow as pa
import pyarrow.parquet as pq

# %%
fn = 'kttm-2019-08-22-small-mod.json.gz'
table = pj.read_json(fn)
table
table.to_pandas()
# Out:
#                        timestamp          city        country    session  \
# 0       2019-08-22T00:00:00.212Z  Christchurch    New Zealand  S97953932
# 1       2019-08-22T00:00:00.327Z      Portland  United States  S59897315
# 2       2019-08-22T00:00:00.387Z      Istanbul         Turkey  S16418954
# 3       2019-08-22T00:00:00.740Z      Brasília         Brazil  S32580935
# 4       2019-08-22T00:00:01.035Z      Arichuna      Venezuela  S57539178
# ...                          ...           ...            ...        ...
# 274855  2019-08-22T23:59:57.573Z    Sugar Land  United States  S29804301
# 274856  2019-08-22T23:59:57.886Z    Washington  United States  S22531821
# 274857  2019-08-22T23:59:58.347Z                United States  S25042020
# 274858  2019-08-22T23:59:59.120Z  Banora Point      Australia  S45081833
# 274859  2019-08-22T23:59:59.949Z                United States  S25042020
#
#         session_length
# 0                  337
# 1                37269
# 2                20591
# 3                18700
# 4                20125
# ...                ...
# 274855           71153
# 274856           10668
# 274857           65133
# 274858          258788
# 274859           66801
#
# [274860 rows x 5 columns]

# %%
pq.write_table(table, 'kttm-2019-08-22-small-mod.parquet')

# %% [markdown]
# ## ORC
#
# Uses Apache Arrow
#
# https://arrow.apache.org/docs/python/orc.html

# %%
from pyarrow import orc

# %%
orc.write_table(table, 'kttm-2019-08-22-small-mod.orc')

# %% [markdown]
# ## Avro
#
# https://www.perfectlyrandom.org/2019/11/29/handling-avro-files-in-python/
# Seems complicated.
#
# https://github.com/ynqa/pandavro

# %%
import avro

# %%
import pandavro as pdx

# %%
df = table.to_pandas()

# %%
OUTPUT_PATH = 'kttm-2019-08-22-small-mod.avro'
pdx.to_avro(OUTPUT_PATH, df)
saved = pdx.read_avro(OUTPUT_PATH)
print(saved)
# Out:
#                        timestamp          city        country    session  \
# 0       2019-08-22T00:00:00.212Z  Christchurch    New Zealand  S97953932
# 1       2019-08-22T00:00:00.327Z      Portland  United States  S59897315
# 2       2019-08-22T00:00:00.387Z      Istanbul         Turkey  S16418954
# 3       2019-08-22T00:00:00.740Z      Brasília         Brazil  S32580935
# 4       2019-08-22T00:00:01.035Z      Arichuna      Venezuela  S57539178
# ...                          ...           ...            ...        ...
# 274855  2019-08-22T23:59:57.573Z    Sugar Land  United States  S29804301
# 274856  2019-08-22T23:59:57.886Z    Washington  United States  S22531821
# 274857  2019-08-22T23:59:58.347Z                United States  S25042020
# 274858  2019-08-22T23:59:59.120Z  Banora Point      Australia  S45081833
# 274859  2019-08-22T23:59:59.949Z                United States  S25042020
#
#         session_length
# 0                  337
# 1                37269
# 2                20591
# 3                18700
# 4                20125
# ...                ...
# 274855           71153
# 274856           10668
# 274857           65133
# 274858          258788
# 274859           66801
#
# [274860 rows x 5 columns]

# %% [markdown]
# ## Protobuf
#
# https://developers.google.com/protocol-buffers/docs/overview#work
#
# https://druid.apache.org/docs/latest/development/extensions-core/protobuf.html

# %%
import json

from google.protobuf.json_format import Parse, ParseDict

# %%
import gzip

# %%
data = []
with gzip.open(fn, 'r') as fin:
    #data = json.loads(fin.read().decode('utf-8'))
    
    contents = fin.read().decode('utf-8')

    #data = [json.loads(str(item)) for item in contents.strip().split('\n')]
    
    for line in contents.strip().split('\n'):
        try:
            data.append(json.loads(line))
        except:
            continue

# https://stackoverflow.com/questions/39450065/python-3-read-write-compressed-json-objects-from-to-gzip-file
# https://stackoverflow.com/questions/21533894/how-to-read-line-delimited-json-from-large-file-line-by-line
# https://stackoverflow.com/questions/51300674/converting-json-into-newline-delimited-json-in-python

# %%
data
# Out:
# [{'timestamp': '2019-08-22T00:00:00.212Z',
#   'city': 'Christchurch',
#   'country': 'New Zealand',
#   'session': 'S97953932',
#   'session_length': 337},
#  {'timestamp': '2019-08-22T00:00:00.327Z',
#   'city': 'Portland',
#   'country': 'United States',
#   'session': 'S59897315',
#   'session_length': 37269},
#  {'timestamp': '2019-08-22T00:00:00.387Z',
#   'city': 'Istanbul',
#   'country': 'Turkey',
#   'session': 'S16418954',
#   'session_length': 20591},
#  {'timestamp': '2019-08-22T00:00:00.740Z',
#   'city': 'Brasília',
#   'country': 'Brazil',
#   'session': 'S32580935',
#   'session_length': 18700},
#  {'timestamp': '2019-08-22T00:00:01.035Z',
#   'city': 'Arichuna',
#   'country': 'Venezuela',
#   'session': 'S57539178',
#   'session_length': 20125},
#  {'timestamp': '2019-08-22T00:00:01.486Z',
#   'city': 'San Jose',
#   'country': 'United States',
#   'session': 'S18064314',
#   'session_length': 10385},
#  {'timestamp': '2019-08-22T00:00:01.512Z',
#   'city': 'Oklahoma City',
#   'country': 'United States',
#   'session': 'S60897860',
#   'session_length': 135136},
#  {'timestamp': '2019-08-22T00:00:02.061Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S06906980',
#   'session_length': 9861},
#  {'timestamp': '2019-08-22T00:00:02.102Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S28958034',
#   'session_length': 30425},
#  {'timestamp': '2019-08-22T00:00:02.239Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S06906980',
#   'session_length': 9863},
#  {'timestamp': '2019-08-22T00:00:02.685Z',
#   'city': 'Brantford',
#   'country': 'Canada',
#   'session': 'S17003332',
#   'session_length': 88386},
#  {'timestamp': '2019-08-22T00:00:03.614Z',
#   'city': 'San Jose',
#   'country': 'United States',
#   'session': 'S18064314',
#   'session_length': 12522},
#  {'timestamp': '2019-08-22T00:00:03.958Z',
#   'city': 'Chapel Hill',
#   'country': 'United States',
#   'session': 'S05734766',
#   'session_length': 45887},
#  {'timestamp': '2019-08-22T00:00:04.356Z',
#   'city': 'Oklahoma City',
#   'country': 'United States',
#   'session': 'S60897860',
#   'session_length': 137994},
#  {'timestamp': '2019-08-22T00:00:04.764Z',
#   'city': 'San Pablo City',
#   'country': 'Philippines',
#   'session': 'S44091049',
#   'session_length': 387},
#  {'timestamp': '2019-08-22T00:00:04.800Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S06906980',
#   'session_length': 12604},
#  {'timestamp': '2019-08-22T00:00:05.187Z',
#   'city': 'Carrollton',
#   'country': 'United States',
#   'session': 'S45331791',
#   'session_length': 515759},
#  {'timestamp': '2019-08-22T00:00:05.199Z',
#   'city': 'Arichuna',
#   'country': 'Venezuela',
#   'session': 'S57539178',
#   'session_length': 24248},
#  {'timestamp': '2019-08-22T00:00:05.506Z',
#   'city': 'Istanbul',
#   'country': 'Turkey',
#   'session': 'S16418954',
#   'session_length': 25696},
#  {'timestamp': '2019-08-22T00:00:05.589Z',
#   'city': 'Mount Waverley',
#   'country': 'Australia',
#   'session': 'S11588035',
#   'session_length': 58},
#  {'timestamp': '2019-08-22T00:00:05.882Z',
#   'city': 'Brasília',
#   'country': 'Brazil',
#   'session': 'S32580935',
#   'session_length': 24259},
#  {'timestamp': '2019-08-22T00:00:06.026Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S28958034',
#   'session_length': 34377},
#  {'timestamp': '2019-08-22T00:00:06.403Z',
#   'city': 'Torrance',
#   'country': 'United States',
#   'session': 'S97755065',
#   'session_length': 63006},
#  {'timestamp': '2019-08-22T00:00:07.285Z',
#   'city': 'Brantford',
#   'country': 'Canada',
#   'session': 'S17003332',
#   'session_length': 92981},
#  {'timestamp': '2019-08-22T00:00:07.907Z',
#   'city': 'Istanbul',
#   'country': 'Turkey',
#   'session': 'S16418954',
#   'session_length': 28104},
#  {'timestamp': '2019-08-22T00:00:08.070Z',
#   'city': 'San Jose',
#   'country': 'United States',
#   'session': 'S18064314',
#   'session_length': 16966},
#  {'timestamp': '2019-08-22T00:00:08.478Z',
#   'city': 'Portland',
#   'country': 'United States',
#   'session': 'S59897315',
#   'session_length': 45484},
#  {'timestamp': '2019-08-22T00:00:08.925Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S06906980',
#   'session_length': 16735},
#  {'timestamp': '2019-08-22T00:00:09.788Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S28958034',
#   'session_length': 38027},
#  {'timestamp': '2019-08-22T00:00:09.800Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S63218039',
#   'session_length': 365},
#  {'timestamp': '2019-08-22T00:00:10.801Z',
#   'city': 'Mount Waverley',
#   'country': 'Australia',
#   'session': 'S10738553',
#   'session_length': 392},
#  {'timestamp': '2019-08-22T00:00:10.995Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S63218039',
#   'session_length': 1702},
#  {'timestamp': '2019-08-22T00:00:11.032Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S63218039',
#   'session_length': 1709},
#  {'timestamp': '2019-08-22T00:00:11.536Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S28958034',
#   'session_length': 39854},
#  {'timestamp': '2019-08-22T00:00:12.081Z',
#   'city': 'Istanbul',
#   'country': 'Turkey',
#   'session': 'S16418954',
#   'session_length': 32281},
#  {'timestamp': '2019-08-22T00:00:13.005Z',
#   'city': 'Arichuna',
#   'country': 'Venezuela',
#   'session': 'S57539178',
#   'session_length': 32111},
#  {'timestamp': '2019-08-22T00:00:13.423Z',
#   'city': 'San Jose',
#   'country': 'United States',
#   'session': 'S18064314',
#   'session_length': 22326},
#  {'timestamp': '2019-08-22T00:00:15.112Z',
#   'city': 'Barberton',
#   'country': 'United States',
#   'session': 'S34787754',
#   'session_length': 12831},
#  {'timestamp': '2019-08-22T00:00:15.207Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S73360451',
#   'session_length': 58736},
#  {'timestamp': '2019-08-22T00:00:15.492Z',
#   'city': 'Barberton',
#   'country': 'United States',
#   'session': 'S34787754',
#   'session_length': 12939},
#  {'timestamp': '2019-08-22T00:00:15.562Z',
#   'city': 'Barberton',
#   'country': 'United States',
#   'session': 'S34787754',
#   'session_length': 16135},
#  {'timestamp': '2019-08-22T00:00:15.592Z',
#   'city': 'Long Beach',
#   'country': 'United States',
#   'session': 'S56643533',
#   'session_length': 415},
#  {'timestamp': '2019-08-22T00:00:15.844Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S06906980',
#   'session_length': 23652},
#  {'timestamp': '2019-08-22T00:00:15.910Z',
#   'city': 'Istanbul',
#   'country': 'Turkey',
#   'session': 'S16418954',
#   'session_length': 35193},
#  {'timestamp': '2019-08-22T00:00:16.181Z',
#   'city': 'Scarborough',
#   'country': 'Canada',
#   'session': 'S39721953',
#   'session_length': 926264},
#  {'timestamp': '2019-08-22T00:00:16.324Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S63218039',
#   'session_length': 7022},
#  {'timestamp': '2019-08-22T00:00:16.526Z',
#   'city': 'Brantford',
#   'country': 'Canada',
#   'session': 'S80907914',
#   'session_length': 139},
#  {'timestamp': '2019-08-22T00:00:17.256Z',
#   'city': 'San Jose',
#   'country': 'United States',
#   'session': 'S18064314',
#   'session_length': 26167},
#  {'timestamp': '2019-08-22T00:00:17.456Z',
#   'city': 'Napier City',
#   'country': 'New Zealand',
#   'session': 'S17814409',
#   'session_length': 809388},
#  {'timestamp': '2019-08-22T00:00:17.820Z',
#   'city': 'Brantford',
#   'country': 'Canada',
#   'session': 'S80907914',
#   'session_length': 1389},
#  {'timestamp': '2019-08-22T00:00:17.968Z',
#   'city': 'Brantford',
#   'country': 'Canada',
#   'session': 'S80907914',
#   'session_length': 1392},
#  {'timestamp': '2019-08-22T00:00:18.358Z',
#   'city': 'Barberton',
#   'country': 'United States',
#   'session': 'S34787754',
#   'session_length': 20493},
#  {'timestamp': '2019-08-22T00:00:19.665Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S28958034',
#   'session_length': 47989},
#  {'timestamp': '2019-08-22T00:00:19.774Z',
#   'city': 'Scarborough',
#   'country': 'Canada',
#   'session': 'S39721953',
#   'session_length': 929855},
#  {'timestamp': '2019-08-22T00:00:19.945Z',
#   'city': 'Portland',
#   'country': 'United States',
#   'session': 'S59897315',
#   'session_length': 56955},
#  {'timestamp': '2019-08-22T00:00:19.962Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S06906980',
#   'session_length': 27770},
#  {'timestamp': '2019-08-22T00:00:20.104Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S31120098',
#   'session_length': 114},
#  {'timestamp': '2019-08-22T00:00:20.262Z',
#   'city': 'San Jose',
#   'country': 'United States',
#   'session': 'S18064314',
#   'session_length': 29125},
#  {'timestamp': '2019-08-22T00:00:20.476Z',
#   'city': 'Torrance',
#   'country': 'United States',
#   'session': 'S97755065',
#   'session_length': 77080},
#  {'timestamp': '2019-08-22T00:00:20.575Z',
#   'city': '',
#   'country': 'South Korea',
#   'session': 'S21851906',
#   'session_length': 314563},
#  {'timestamp': '2019-08-22T00:00:21.969Z',
#   'city': 'Salem',
#   'country': 'United States',
#   'session': 'S09028644',
#   'session_length': 32254},
#  {'timestamp': '2019-08-22T00:00:22.540Z',
#   'city': 'Timoteo',
#   'country': 'Brazil',
#   'session': 'S72171998',
#   'session_length': 170840},
#  {'timestamp': '2019-08-22T00:00:22.582Z',
#   'city': 'San Jose',
#   'country': 'United States',
#   'session': 'S18064314',
#   'session_length': 31494},
#  {'timestamp': '2019-08-22T00:00:23.106Z',
#   'city': 'San Jose',
#   'country': 'United States',
#   'session': 'S18064314',
#   'session_length': 32005},
#  {'timestamp': '2019-08-22T00:00:23.943Z',
#   'city': 'Long Beach',
#   'country': 'United States',
#   'session': 'S57852521',
#   'session_length': 109},
#  {'timestamp': '2019-08-22T00:00:24.222Z',
#   'city': 'Arichuna',
#   'country': 'Venezuela',
#   'session': 'S57539178',
#   'session_length': 43337},
#  {'timestamp': '2019-08-22T00:00:24.605Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S31120098',
#   'session_length': 4324},
#  {'timestamp': '2019-08-22T00:00:24.685Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S31120098',
#   'session_length': 4318},
#  {'timestamp': '2019-08-22T00:00:25.084Z',
#   'city': 'Timoteo',
#   'country': 'Brazil',
#   'session': 'S72171998',
#   'session_length': 173639},
#  {'timestamp': '2019-08-22T00:00:25.415Z',
#   'city': 'Scarborough',
#   'country': 'Canada',
#   'session': 'S39721953',
#   'session_length': 935497},
#  {'timestamp': '2019-08-22T00:00:26.029Z',
#   'city': 'San Jose',
#   'country': 'United States',
#   'session': 'S18064314',
#   'session_length': 34911},
#  {'timestamp': '2019-08-22T00:00:26.175Z',
#   'city': 'Timoteo',
#   'country': 'Brazil',
#   'session': 'S72171998',
#   'session_length': 174727},
#  {'timestamp': '2019-08-22T00:00:26.343Z',
#   'city': 'Rowland Heights',
#   'country': 'United States',
#   'session': 'S07596243',
#   'session_length': 291},
#  {'timestamp': '2019-08-22T00:00:26.928Z',
#   'city': 'Neutral Bay',
#   'country': 'Australia',
#   'session': 'S38524549',
#   'session_length': 360},
#  {'timestamp': '2019-08-22T00:00:27.138Z',
#   'city': 'Long Beach',
#   'country': 'United States',
#   'session': 'S87627804',
#   'session_length': 383},
#  {'timestamp': '2019-08-22T00:00:27.230Z',
#   'city': 'Brasília',
#   'country': 'Brazil',
#   'session': 'S32580935',
#   'session_length': 45189},
#  {'timestamp': '2019-08-22T00:00:27.235Z',
#   'city': 'Oklahoma City',
#   'country': 'United States',
#   'session': 'S60897860',
#   'session_length': 160850},
#  {'timestamp': '2019-08-22T00:00:27.443Z',
#   'city': 'Portland',
#   'country': 'United States',
#   'session': 'S59897315',
#   'session_length': 64453},
#  {'timestamp': '2019-08-22T00:00:27.573Z',
#   'city': 'Neutral Bay',
#   'country': 'Australia',
#   'session': 'S38524549',
#   'session_length': 1808},
#  {'timestamp': '2019-08-22T00:00:27.575Z',
#   'city': 'Neutral Bay',
#   'country': 'Australia',
#   'session': 'S38524549',
#   'session_length': 1821},
#  {'timestamp': '2019-08-22T00:00:28.105Z',
#   'city': 'Istanbul',
#   'country': 'Turkey',
#   'session': 'S16418954',
#   'session_length': 48305},
#  {'timestamp': '2019-08-22T00:00:28.303Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S59079427',
#   'session_length': 106412},
#  {'timestamp': '2019-08-22T00:00:29.885Z',
#   'city': 'San Jose',
#   'country': 'United States',
#   'session': 'S18064314',
#   'session_length': 38776},
#  {'timestamp': '2019-08-22T00:00:29.915Z',
#   'city': 'Neutral Bay',
#   'country': 'Australia',
#   'session': 'S38524549',
#   'session_length': 4158},
#  {'timestamp': '2019-08-22T00:00:30.289Z',
#   'city': 'Martinsville',
#   'country': 'United States',
#   'session': 'S90738784',
#   'session_length': 261},
#  {'timestamp': '2019-08-22T00:00:30.298Z',
#   'city': 'Timoteo',
#   'country': 'Brazil',
#   'session': 'S72171998',
#   'session_length': 178552},
#  {'timestamp': '2019-08-22T00:00:30.306Z',
#   'city': 'Oklahoma City',
#   'country': 'United States',
#   'session': 'S60897860',
#   'session_length': 163940},
#  {'timestamp': '2019-08-22T00:00:30.414Z',
#   'city': 'Torrance',
#   'country': 'United States',
#   'session': 'S97755065',
#   'session_length': 87017},
#  {'timestamp': '2019-08-22T00:00:31.095Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S06906980',
#   'session_length': 38884},
#  {'timestamp': '2019-08-22T00:00:31.472Z',
#   'city': 'Gangnam-gu',
#   'country': 'South Korea',
#   'session': 'S63051490',
#   'session_length': 239},
#  {'timestamp': '2019-08-22T00:00:31.538Z',
#   'city': 'Roseville',
#   'country': 'United States',
#   'session': 'S89033666',
#   'session_length': 223},
#  {'timestamp': '2019-08-22T00:00:31.579Z',
#   'city': 'Martinsville',
#   'country': 'United States',
#   'session': 'S90738784',
#   'session_length': 1677},
#  {'timestamp': '2019-08-22T00:00:31.614Z',
#   'city': 'Martinsville',
#   'country': 'United States',
#   'session': 'S90738784',
#   'session_length': 1684},
#  {'timestamp': '2019-08-22T00:00:31.894Z',
#   'city': 'Portland',
#   'country': 'United States',
#   'session': 'S59897315',
#   'session_length': 68905},
#  {'timestamp': '2019-08-22T00:00:31.941Z',
#   'city': 'Gangnam-gu',
#   'country': 'South Korea',
#   'session': 'S63051490',
#   'session_length': 1572},
#  {'timestamp': '2019-08-22T00:00:31.968Z',
#   'city': 'Gangnam-gu',
#   'country': 'South Korea',
#   'session': 'S63051490',
#   'session_length': 1568},
#  {'timestamp': '2019-08-22T00:00:32.190Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S56854023',
#   'session_length': 1324175},
#  {'timestamp': '2019-08-22T00:00:32.244Z',
#   'city': 'Barberton',
#   'country': 'United States',
#   'session': 'S34787754',
#   'session_length': 26230},
#  {'timestamp': '2019-08-22T00:00:32.304Z',
#   'city': 'Barberton',
#   'country': 'United States',
#   'session': 'S34787754',
#   'session_length': 33178},
#  {'timestamp': '2019-08-22T00:00:32.390Z',
#   'city': 'Oklahoma City',
#   'country': 'United States',
#   'session': 'S60897860',
#   'session_length': 166025},
#  {'timestamp': '2019-08-22T00:00:33.077Z',
#   'city': 'Scarborough',
#   'country': 'Canada',
#   'session': 'S39721953',
#   'session_length': 943155},
#  {'timestamp': '2019-08-22T00:00:33.120Z',
#   'city': 'Martinsville',
#   'country': 'United States',
#   'session': 'S90738784',
#   'session_length': 3229},
#  {'timestamp': '2019-08-22T00:00:33.710Z',
#   'city': 'Kyiv',
#   'country': 'Ukraine',
#   'session': 'S80150727',
#   'session_length': 262},
#  {'timestamp': '2019-08-22T00:00:33.869Z',
#   'city': 'Portland',
#   'country': 'United States',
#   'session': 'S59897315',
#   'session_length': 70878},
#  {'timestamp': '2019-08-22T00:00:34.996Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S59079427',
#   'session_length': 113122},
#  {'timestamp': '2019-08-22T00:00:35.220Z',
#   'city': 'Salem',
#   'country': 'United States',
#   'session': 'S09028644',
#   'session_length': 45873},
#  {'timestamp': '2019-08-22T00:00:35.430Z',
#   'city': 'Neutral Bay',
#   'country': 'Australia',
#   'session': 'S38524549',
#   'session_length': 9659},
#  {'timestamp': '2019-08-22T00:00:35.576Z',
#   'city': 'Portland',
#   'country': 'United States',
#   'session': 'S59897315',
#   'session_length': 72584},
#  {'timestamp': '2019-08-22T00:00:36.382Z',
#   'city': 'Kansas City',
#   'country': 'United States',
#   'session': 'S19320789',
#   'session_length': 1524},
#  {'timestamp': '2019-08-22T00:00:36.894Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S59079427',
#   'session_length': 115021},
#  {'timestamp': '2019-08-22T00:00:37.165Z',
#   'city': 'Kansas City',
#   'country': 'United States',
#   'session': 'S19320789',
#   'session_length': 2789},
#  {'timestamp': '2019-08-22T00:00:37.294Z',
#   'city': 'Kansas City',
#   'country': 'United States',
#   'session': 'S19320789',
#   'session_length': 2920},
#  {'timestamp': '2019-08-22T00:00:37.772Z',
#   'city': 'Portland',
#   'country': 'United States',
#   'session': 'S59897315',
#   'session_length': 74783},
#  {'timestamp': '2019-08-22T00:00:38.119Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S61417830',
#   'session_length': 417},
#  {'timestamp': '2019-08-22T00:00:38.980Z',
#   'city': 'Philadelphia',
#   'country': 'United States',
#   'session': 'S86410961',
#   'session_length': 280},
#  {'timestamp': '2019-08-22T00:00:39.161Z',
#   'city': 'Oklahoma City',
#   'country': 'United States',
#   'session': 'S60897860',
#   'session_length': 172797},
#  {'timestamp': '2019-08-22T00:00:40.601Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S73360451',
#   'session_length': 84047},
#  {'timestamp': '2019-08-22T00:00:40.634Z',
#   'city': 'Barberton',
#   'country': 'United States',
#   'session': 'S34787754',
#   'session_length': 42588},
#  {'timestamp': '2019-08-22T00:00:40.795Z',
#   'city': 'Roseville',
#   'country': 'United States',
#   'session': 'S89033666',
#   'session_length': 9654},
#  {'timestamp': '2019-08-22T00:00:40.860Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S59079427',
#   'session_length': 118986},
#  {'timestamp': '2019-08-22T00:00:41.016Z',
#   'city': 'Roseville',
#   'country': 'United States',
#   'session': 'S89033666',
#   'session_length': 9661},
#  {'timestamp': '2019-08-22T00:00:42.068Z',
#   'city': 'Spokane',
#   'country': 'United States',
#   'session': 'S27517595',
#   'session_length': 506},
#  {'timestamp': '2019-08-22T00:00:43.028Z',
#   'city': 'Rowland Heights',
#   'country': 'United States',
#   'session': 'S07596243',
#   'session_length': 17215},
#  {'timestamp': '2019-08-22T00:00:43.115Z',
#   'city': 'Rowland Heights',
#   'country': 'United States',
#   'session': 'S07596243',
#   'session_length': 17234},
#  {'timestamp': '2019-08-22T00:00:43.303Z',
#   'city': 'Kansas City',
#   'country': 'United States',
#   'session': 'S19320789',
#   'session_length': 8863},
#  {'timestamp': '2019-08-22T00:00:43.321Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S15487383',
#   'session_length': 207},
#  {'timestamp': '2019-08-22T00:00:43.681Z',
#   'city': 'Spokane',
#   'country': 'United States',
#   'session': 'S27517595',
#   'session_length': 2490},
#  {'timestamp': '2019-08-22T00:00:43.784Z',
#   'city': 'Spokane',
#   'country': 'United States',
#   'session': 'S27517595',
#   'session_length': 2508},
#  {'timestamp': '2019-08-22T00:00:43.815Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S61417830',
#   'session_length': 6098},
#  {'timestamp': '2019-08-22T00:00:43.821Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S61417830',
#   'session_length': 6097},
#  {'timestamp': '2019-08-22T00:00:44.100Z',
#   'city': 'Rowland Heights',
#   'country': 'United States',
#   'session': 'S07596243',
#   'session_length': 18313},
#  {'timestamp': '2019-08-22T00:00:44.222Z',
#   'city': 'Torrance',
#   'country': 'United States',
#   'session': 'S97755065',
#   'session_length': 100821},
#  {'timestamp': '2019-08-22T00:00:44.706Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S15487383',
#   'session_length': 1592},
#  {'timestamp': '2019-08-22T00:00:44.737Z',
#   'city': 'Fort Smith',
#   'country': 'United States',
#   'session': 'S92000219',
#   'session_length': 350},
#  {'timestamp': '2019-08-22T00:00:44.917Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S15487383',
#   'session_length': 1592},
#  {'timestamp': '2019-08-22T00:00:45.179Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S73360451',
#   'session_length': 88047},
#  {'timestamp': '2019-08-22T00:00:45.494Z',
#   'city': 'Fort Worth',
#   'country': 'United States',
#   'session': 'S01690517',
#   'session_length': 252618},
#  {'timestamp': '2019-08-22T00:00:45.835Z',
#   'city': 'Alsip',
#   'country': 'United States',
#   'session': 'S81903990',
#   'session_length': 826791},
#  {'timestamp': '2019-08-22T00:00:46.573Z',
#   'city': 'Fort Smith',
#   'country': 'United States',
#   'session': 'S92000219',
#   'session_length': 2505},
#  {'timestamp': '2019-08-22T00:00:46.657Z',
#   'city': 'Fort Smith',
#   'country': 'United States',
#   'session': 'S92000219',
#   'session_length': 2515},
#  {'timestamp': '2019-08-22T00:00:47.183Z',
#   'city': 'Riverton',
#   'country': 'United States',
#   'session': 'S72554815',
#   'session_length': 2275},
#  {'timestamp': '2019-08-22T00:00:47.833Z',
#   'city': 'Roseville',
#   'country': 'United States',
#   'session': 'S89033666',
#   'session_length': 16503},
#  {'timestamp': '2019-08-22T00:00:48.141Z',
#   'city': 'Riverton',
#   'country': 'United States',
#   'session': 'S72554815',
#   'session_length': 3553},
#  {'timestamp': '2019-08-22T00:00:48.219Z',
#   'city': 'Riverton',
#   'country': 'United States',
#   'session': 'S72554815',
#   'session_length': 3570},
#  {'timestamp': '2019-08-22T00:00:48.240Z',
#   'city': 'Toronto',
#   'country': 'Canada',
#   'session': 'S38589272',
#   'session_length': 296},
#  {'timestamp': '2019-08-22T00:00:48.310Z',
#   'city': 'Fort Worth',
#   'country': 'United States',
#   'session': 'S01690517',
#   'session_length': 255700},
#  {'timestamp': '2019-08-22T00:00:48.386Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S00080598',
#   'session_length': 184},
#  {'timestamp': '2019-08-22T00:00:49.422Z',
#   'city': 'Oklahoma City',
#   'country': 'United States',
#   'session': 'S60897860',
#   'session_length': 183055},
#  {'timestamp': '2019-08-22T00:00:49.446Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S73360451',
#   'session_length': 92977},
#  {'timestamp': '2019-08-22T00:00:49.533Z',
#   'city': 'Arichuna',
#   'country': 'Venezuela',
#   'session': 'S57539178',
#   'session_length': 68631},
#  {'timestamp': '2019-08-22T00:00:49.788Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S15487383',
#   'session_length': 6670},
#  {'timestamp': '2019-08-22T00:00:50.015Z',
#   'city': 'Rowland Heights',
#   'country': 'United States',
#   'session': 'S07596243',
#   'session_length': 24222},
#  {'timestamp': '2019-08-22T00:00:50.089Z',
#   'city': 'Kansas City',
#   'country': 'United States',
#   'session': 'S19320789',
#   'session_length': 15740},
#  {'timestamp': '2019-08-22T00:00:50.852Z',
#   'city': 'Barberton',
#   'country': 'United States',
#   'session': 'S34787754',
#   'session_length': 52829},
#  {'timestamp': '2019-08-22T00:00:51.467Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S15487383',
#   'session_length': 8352},
#  {'timestamp': '2019-08-22T00:00:52.653Z',
#   'city': 'Riverton',
#   'country': 'United States',
#   'session': 'S72554815',
#   'session_length': 8085},
#  {'timestamp': '2019-08-22T00:00:53.151Z',
#   'city': 'San Pablo City',
#   'country': 'Philippines',
#   'session': 'S28259767',
#   'session_length': 277},
#  {'timestamp': '2019-08-22T00:00:53.642Z',
#   'city': 'Torrance',
#   'country': 'United States',
#   'session': 'S97755065',
#   'session_length': 110195},
#  {'timestamp': '2019-08-22T00:00:54.890Z',
#   'city': 'Toronto',
#   'country': 'Canada',
#   'session': 'S38589272',
#   'session_length': 7146},
#  {'timestamp': '2019-08-22T00:00:54.943Z',
#   'city': 'Toronto',
#   'country': 'Canada',
#   'session': 'S38589272',
#   'session_length': 7152},
#  {'timestamp': '2019-08-22T00:00:55.227Z',
#   'city': 'Salem',
#   'country': 'United States',
#   'session': 'S09028644',
#   'session_length': 65251},
#  {'timestamp': '2019-08-22T00:00:56.080Z',
#   'city': 'Ballwin',
#   'country': 'United States',
#   'session': 'S13557382',
#   'session_length': 318},
#  {'timestamp': '2019-08-22T00:00:56.387Z',
#   'city': 'Kansas City',
#   'country': 'United States',
#   'session': 'S19320789',
#   'session_length': 22043},
#  {'timestamp': '2019-08-22T00:00:56.434Z',
#   'city': 'Riverton',
#   'country': 'United States',
#   'session': 'S72554815',
#   'session_length': 11804},
#  {'timestamp': '2019-08-22T00:00:56.658Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S00080598',
#   'session_length': 8452},
#  {'timestamp': '2019-08-22T00:00:56.660Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S00080598',
#   'session_length': 8451},
#  {'timestamp': '2019-08-22T00:00:57.108Z',
#   'city': 'Neutral Bay',
#   'country': 'Australia',
#   'session': 'S38524549',
#   'session_length': 31351},
#  {'timestamp': '2019-08-22T00:00:58.838Z',
#   'city': 'Oklahoma City',
#   'country': 'United States',
#   'session': 'S60897860',
#   'session_length': 192477},
#  {'timestamp': '2019-08-22T00:00:58.897Z',
#   'city': 'Rowland Heights',
#   'country': 'United States',
#   'session': 'S07596243',
#   'session_length': 33092},
#  {'timestamp': '2019-08-22T00:00:58.909Z',
#   'city': 'Philadelphia',
#   'country': 'United States',
#   'session': 'S67803487',
#   'session_length': 291},
#  {'timestamp': '2019-08-22T00:00:59.182Z',
#   'city': 'Rowland Heights',
#   'country': 'United States',
#   'session': 'S07596243',
#   'session_length': 33387},
#  {'timestamp': '2019-08-22T00:00:59.427Z',
#   'city': 'Roseville',
#   'country': 'United States',
#   'session': 'S89033666',
#   'session_length': 28304},
#  {'timestamp': '2019-08-22T00:00:59.456Z',
#   'city': 'Torrance',
#   'country': 'United States',
#   'session': 'S97755065',
#   'session_length': 116057},
#  {'timestamp': '2019-08-22T00:00:59.691Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S96325958',
#   'session_length': 377},
#  {'timestamp': '2019-08-22T00:01:00.244Z',
#   'city': 'Decatur',
#   'country': 'United States',
#   'session': 'S52047478',
#   'session_length': 367},
#  {'timestamp': '2019-08-22T00:01:01.808Z',
#   'city': 'Oklahoma City',
#   'country': 'United States',
#   'session': 'S60897860',
#   'session_length': 195445},
#  {'timestamp': '2019-08-22T00:01:01.923Z',
#   'city': 'Killeen',
#   'country': 'United States',
#   'session': 'S94942125',
#   'session_length': 151},
#  {'timestamp': '2019-08-22T00:01:02.067Z',
#   'city': 'Timoteo',
#   'country': 'Brazil',
#   'session': 'S72171998',
#   'session_length': 210349},
#  {'timestamp': '2019-08-22T00:01:02.414Z',
#   'city': 'Riverton',
#   'country': 'United States',
#   'session': 'S72554815',
#   'session_length': 17837},
#  {'timestamp': '2019-08-22T00:01:02.511Z',
#   'city': 'Fort Worth',
#   'country': 'United States',
#   'session': 'S01690517',
#   'session_length': 269901},
#  {'timestamp': '2019-08-22T00:01:03.126Z',
#   'city': 'Istanbul',
#   'country': 'Turkey',
#   'session': 'S16418954',
#   'session_length': 83310},
#  {'timestamp': '2019-08-22T00:01:03.151Z',
#   'city': 'Killeen',
#   'country': 'United States',
#   'session': 'S87660992',
#   'session_length': 240123},
#  {'timestamp': '2019-08-22T00:01:03.591Z',
#   'city': 'Kansas City',
#   'country': 'United States',
#   'session': 'S19320789',
#   'session_length': 28488},
#  {'timestamp': '2019-08-22T00:01:04.045Z',
#   'city': 'Salem',
#   'country': 'United States',
#   'session': 'S09028644',
#   'session_length': 74524},
#  {'timestamp': '2019-08-22T00:01:04.243Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S00080598',
#   'session_length': 16040},
#  {'timestamp': '2019-08-22T00:01:04.496Z',
#   'city': 'Arichuna',
#   'country': 'Venezuela',
#   'session': 'S57539178',
#   'session_length': 83600},
#  {'timestamp': '2019-08-22T00:01:04.804Z',
#   'city': 'Barberton',
#   'country': 'United States',
#   'session': 'S34787754',
#   'session_length': 66647},
#  {'timestamp': '2019-08-22T00:01:04.889Z',
#   'city': 'Riverton',
#   'country': 'United States',
#   'session': 'S72554815',
#   'session_length': 20300},
#  {'timestamp': '2019-08-22T00:01:05.269Z',
#   'city': 'Santa Ana',
#   'country': 'United States',
#   'session': 'S08319347',
#   'session_length': 1705},
#  {'timestamp': '2019-08-22T00:01:05.647Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S07955765',
#   'session_length': 222},
#  {'timestamp': '2019-08-22T00:01:06.377Z',
#   'city': 'Kansas City',
#   'country': 'United States',
#   'session': 'S19320789',
#   'session_length': 31958},
#  {'timestamp': '2019-08-22T00:01:06.449Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S15487383',
#   'session_length': 23337},
#  {'timestamp': '2019-08-22T00:01:06.787Z',
#   'city': 'Oklahoma City',
#   'country': 'United States',
#   'session': 'S60897860',
#   'session_length': 200414},
#  {'timestamp': '2019-08-22T00:01:08.125Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S56854023',
#   'session_length': 1360971},
#  {'timestamp': '2019-08-22T00:01:08.176Z',
#   'city': 'Riverton',
#   'country': 'United States',
#   'session': 'S72554815',
#   'session_length': 23590},
#  {'timestamp': '2019-08-22T00:01:08.366Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S56854023',
#   'session_length': 1361086},
#  {'timestamp': '2019-08-22T00:01:08.606Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S18465989',
#   'session_length': 421},
#  {'timestamp': '2019-08-22T00:01:09.047Z',
#   'city': 'Riverton',
#   'country': 'United States',
#   'session': 'S72554815',
#   'session_length': 24465},
#  {'timestamp': '2019-08-22T00:01:09.381Z',
#   'city': 'Killeen',
#   'country': 'United States',
#   'session': 'S54769127',
#   'session_length': 224},
#  {'timestamp': '2019-08-22T00:01:09.451Z',
#   'city': 'Oklahoma City',
#   'country': 'United States',
#   'session': 'S60897860',
#   'session_length': 203084},
#  {'timestamp': '2019-08-22T00:01:09.508Z',
#   'city': 'Santa Ana',
#   'country': 'United States',
#   'session': 'S08319347',
#   'session_length': 6220},
#  {'timestamp': '2019-08-22T00:01:09.601Z',
#   'city': 'Santa Ana',
#   'country': 'United States',
#   'session': 'S08319347',
#   'session_length': 6239},
#  {'timestamp': '2019-08-22T00:01:10.249Z',
#   'city': 'Riverton',
#   'country': 'United States',
#   'session': 'S72554815',
#   'session_length': 25600},
#  {'timestamp': '2019-08-22T00:01:10.360Z',
#   'city': 'Halkirk',
#   'country': 'Canada',
#   'session': 'S99275049',
#   'session_length': 250},
#  {'timestamp': '2019-08-22T00:01:11.143Z',
#   'city': '',
#   'country': 'Albania',
#   'session': 'S44285930',
#   'session_length': 509},
#  {'timestamp': '2019-08-22T00:01:11.708Z',
#   'city': 'Halkirk',
#   'country': 'Canada',
#   'session': 'S99275049',
#   'session_length': 1966},
#  {'timestamp': '2019-08-22T00:01:11.802Z',
#   'city': 'Rowland Heights',
#   'country': 'United States',
#   'session': 'S07596243',
#   'session_length': 45853},
#  {'timestamp': '2019-08-22T00:01:11.820Z',
#   'city': 'Halkirk',
#   'country': 'Canada',
#   'session': 'S99275049',
#   'session_length': 1970},
#  {'timestamp': '2019-08-22T00:01:11.857Z',
#   'city': 'Santa Ana',
#   'country': 'United States',
#   'session': 'S08319347',
#   'session_length': 8585},
#  {'timestamp': '2019-08-22T00:01:12.124Z',
#   'city': 'Torrance',
#   'country': 'United States',
#   'session': 'S97755065',
#   'session_length': 128717},
#  {'timestamp': '2019-08-22T00:01:12.126Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S96325958',
#   'session_length': 12693},
#  {'timestamp': '2019-08-22T00:01:12.245Z',
#   'city': 'Riverton',
#   'country': 'United States',
#   'session': 'S72554815',
#   'session_length': 27659},
#  {'timestamp': '2019-08-22T00:01:12.353Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S96325958',
#   'session_length': 12706},
#  {'timestamp': '2019-08-22T00:01:12.516Z',
#   'city': 'Toronto',
#   'country': 'Canada',
#   'session': 'S38589272',
#   'session_length': 24778},
#  {'timestamp': '2019-08-22T00:01:13.175Z',
#   'city': 'Rowland Heights',
#   'country': 'United States',
#   'session': 'S07596243',
#   'session_length': 47373},
#  {'timestamp': '2019-08-22T00:01:13.765Z',
#   'city': 'Halkirk',
#   'country': 'Canada',
#   'session': 'S99275049',
#   'session_length': 3820},
#  {'timestamp': '2019-08-22T00:01:13.779Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S73360451',
#   'session_length': 117126},
#  {'timestamp': '2019-08-22T00:01:14.248Z',
#   'city': 'Kansas City',
#   'country': 'United States',
#   'session': 'S19320789',
#   'session_length': 39911},
#  {'timestamp': '2019-08-22T00:01:14.339Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S96325958',
#   'session_length': 15009},
#  {'timestamp': '2019-08-22T00:01:15.150Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S96325958',
#   'session_length': 15826},
#  {'timestamp': '2019-08-22T00:01:15.450Z',
#   'city': 'Arichuna',
#   'country': 'Venezuela',
#   'session': 'S57539178',
#   'session_length': 94492},
#  {'timestamp': '2019-08-22T00:01:16.313Z',
#   'city': 'San Pablo City',
#   'country': 'Philippines',
#   'session': 'S01973300',
#   'session_length': 234},
#  {'timestamp': '2019-08-22T00:01:16.447Z',
#   'city': 'Santa Ana',
#   'country': 'United States',
#   'session': 'S08319347',
#   'session_length': 13183},
#  {'timestamp': '2019-08-22T00:01:17.499Z',
#   'city': '',
#   'country': 'Albania',
#   'session': 'S44285930',
#   'session_length': 7403},
#  {'timestamp': '2019-08-22T00:01:17.638Z',
#   'city': 'Istanbul',
#   'country': 'Turkey',
#   'session': 'S16418954',
#   'session_length': 97837},
#  {'timestamp': '2019-08-22T00:01:17.738Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S18465989',
#   'session_length': 9527},
#  {'timestamp': '2019-08-22T00:01:17.740Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S18465989',
#   'session_length': 9526},
#  {'timestamp': '2019-08-22T00:01:17.789Z',
#   'city': '',
#   'country': 'Albania',
#   'session': 'S44285930',
#   'session_length': 7419},
#  {'timestamp': '2019-08-22T00:01:17.844Z',
#   'city': 'Malden',
#   'country': 'United States',
#   'session': 'S49573479',
#   'session_length': 144},
#  {'timestamp': '2019-08-22T00:01:18.306Z',
#   'city': 'Riverton',
#   'country': 'United States',
#   'session': 'S72554815',
#   'session_length': 33729},
#  {'timestamp': '2019-08-22T00:01:18.425Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S20944134',
#   'session_length': 71},
#  {'timestamp': '2019-08-22T00:01:18.877Z',
#   'city': 'Oklahoma City',
#   'country': 'United States',
#   'session': 'S60897860',
#   'session_length': 212422},
#  {'timestamp': '2019-08-22T00:01:19.107Z',
#   'city': 'Chico',
#   'country': 'United States',
#   'session': 'S51630809',
#   'session_length': 768},
#  {'timestamp': '2019-08-22T00:01:19.140Z',
#   'city': 'Kansas City',
#   'country': 'United States',
#   'session': 'S19320789',
#   'session_length': 44796},
#  {'timestamp': '2019-08-22T00:01:19.178Z',
#   'city': 'Rowland Heights',
#   'country': 'United States',
#   'session': 'S07596243',
#   'session_length': 53380},
#  {'timestamp': '2019-08-22T00:01:19.957Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S96325958',
#   'session_length': 20627},
#  {'timestamp': '2019-08-22T00:01:20.238Z',
#   'city': 'Roseville',
#   'country': 'United States',
#   'session': 'S89033666',
#   'session_length': 48889},
#  {'timestamp': '2019-08-22T00:01:20.432Z',
#   'city': 'San Pablo City',
#   'country': 'Philippines',
#   'session': 'S37761746',
#   'session_length': 53},
#  {'timestamp': '2019-08-22T00:01:20.548Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S20944134',
#   'session_length': 2214},
#  {'timestamp': '2019-08-22T00:01:20.551Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S20944134',
#   'session_length': 2215},
#  {'timestamp': '2019-08-22T00:01:21.375Z',
#   'city': 'Halkirk',
#   'country': 'Canada',
#   'session': 'S99275049',
#   'session_length': 11580},
#  {'timestamp': '2019-08-22T00:01:21.882Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S20944134',
#   'session_length': 3525},
#  {'timestamp': '2019-08-22T00:01:22.040Z',
#   'city': 'Chico',
#   'country': 'United States',
#   'session': 'S51630809',
#   'session_length': 4052},
#  {'timestamp': '2019-08-22T00:01:22.326Z',
#   'city': 'Chico',
#   'country': 'United States',
#   'session': 'S51630809',
#   'session_length': 4053},
#  {'timestamp': '2019-08-22T00:01:22.523Z',
#   'city': 'Rowland Heights',
#   'country': 'United States',
#   'session': 'S07596243',
#   'session_length': 56684},
#  {'timestamp': '2019-08-22T00:01:22.617Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S96325958',
#   'session_length': 23280},
#  {'timestamp': '2019-08-22T00:01:22.719Z',
#   'city': 'Toronto',
#   'country': 'Canada',
#   'session': 'S38589272',
#   'session_length': 34980},
#  {'timestamp': '2019-08-22T00:01:23.368Z',
#   'city': 'Halkirk',
#   'country': 'Canada',
#   'session': 'S99275049',
#   'session_length': 13636},
#  {'timestamp': '2019-08-22T00:01:23.659Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S73360451',
#   'session_length': 126550},
#  {'timestamp': '2019-08-22T00:01:23.767Z',
#   'city': 'Kansas City',
#   'country': 'United States',
#   'session': 'S19320789',
#   'session_length': 49349},
#  {'timestamp': '2019-08-22T00:01:25.036Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S20944134',
#   'session_length': 6707},
#  {'timestamp': '2019-08-22T00:01:25.290Z',
#   'city': 'Halkirk',
#   'country': 'Canada',
#   'session': 'S99275049',
#   'session_length': 15544},
#  {'timestamp': '2019-08-22T00:01:25.417Z',
#   'city': 'Riverton',
#   'country': 'United States',
#   'session': 'S72554815',
#   'session_length': 40829},
#  {'timestamp': '2019-08-22T00:01:25.599Z',
#   'city': 'Santa Ana',
#   'country': 'United States',
#   'session': 'S08319347',
#   'session_length': 22333},
#  {'timestamp': '2019-08-22T00:01:25.888Z',
#   'city': 'Chico',
#   'country': 'United States',
#   'session': 'S51630809',
#   'session_length': 7900},
#  {'timestamp': '2019-08-22T00:01:26.565Z',
#   'city': 'Halkirk',
#   'country': 'Canada',
#   'session': 'S99275049',
#   'session_length': 16826},
#  {'timestamp': '2019-08-22T00:01:26.589Z',
#   'city': 'Malden',
#   'country': 'United States',
#   'session': 'S49573479',
#   'session_length': 9236},
#  {'timestamp': '2019-08-22T00:01:26.593Z',
#   'city': 'Malden',
#   'country': 'United States',
#   'session': 'S49573479',
#   'session_length': 9242},
#  {'timestamp': '2019-08-22T00:01:26.597Z',
#   'city': 'Killeen',
#   'country': 'United States',
#   'session': 'S36550324',
#   'session_length': 51},
#  {'timestamp': '2019-08-22T00:01:26.692Z',
#   'city': '',
#   'country': 'Albania',
#   'session': 'S44285930',
#   'session_length': 16601},
#  {'timestamp': '2019-08-22T00:01:26.879Z',
#   'city': 'San Pablo City',
#   'country': 'Philippines',
#   'session': 'S98263360',
#   'session_length': 52},
#  {'timestamp': '2019-08-22T00:01:27.333Z',
#   'city': 'Rowland Heights',
#   'country': 'United States',
#   'session': 'S07596243',
#   'session_length': 61529},
#  {'timestamp': '2019-08-22T00:01:27.833Z',
#   'city': 'Halkirk',
#   'country': 'Canada',
#   'session': 'S99275049',
#   'session_length': 18098},
#  {'timestamp': '2019-08-22T00:01:27.882Z',
#   'city': 'Carrollton',
#   'country': 'United States',
#   'session': 'S45331791',
#   'session_length': 598353},
#  {'timestamp': '2019-08-22T00:01:27.918Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S98074199',
#   'session_length': 316},
#  {'timestamp': '2019-08-22T00:01:27.964Z',
#   'city': 'Toronto',
#   'country': 'Canada',
#   'session': 'S38589272',
#   'session_length': 40230},
#  {'timestamp': '2019-08-22T00:01:28.065Z',
#   'city': 'Riverton',
#   'country': 'United States',
#   'session': 'S72554815',
#   'session_length': 43493},
#  {'timestamp': '2019-08-22T00:01:28.306Z',
#   'city': 'Malden',
#   'country': 'United States',
#   'session': 'S49573479',
#   'session_length': 10951},
#  {'timestamp': '2019-08-22T00:01:28.361Z',
#   'city': 'Toronto',
#   'country': 'Canada',
#   'session': 'S38589272',
#   'session_length': 40628},
#  {'timestamp': '2019-08-22T00:01:28.587Z',
#   'city': 'San Antonio',
#   'country': 'United States',
#   'session': 'S93411400',
#   'session_length': 445},
#  {'timestamp': '2019-08-22T00:01:28.657Z',
#   'city': 'Timoteo',
#   'country': 'Brazil',
#   'session': 'S72171998',
#   'session_length': 236955},
#  {'timestamp': '2019-08-22T00:01:28.755Z',
#   'city': 'Halkirk',
#   'country': 'Canada',
#   'session': 'S99275049',
#   'session_length': 19009},
#  {'timestamp': '2019-08-22T00:01:28.894Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S96325958',
#   'session_length': 29552},
#  {'timestamp': '2019-08-22T00:01:29.015Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S96325958',
#   'session_length': 29678},
#  {'timestamp': '2019-08-22T00:01:29.248Z',
#   'city': 'Halkirk',
#   'country': 'Canada',
#   'session': 'S99275049',
#   'session_length': 19509},
#  {'timestamp': '2019-08-22T00:01:29.346Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S98074199',
#   'session_length': 1710},
#  {'timestamp': '2019-08-22T00:01:29.349Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S98074199',
#   'session_length': 1717},
#  {'timestamp': '2019-08-22T00:01:29.566Z',
#   'city': 'Toronto',
#   'country': 'Canada',
#   'session': 'S38589272',
#   'session_length': 41831},
#  {'timestamp': '2019-08-22T00:01:30.159Z',
#   'city': 'San Antonio',
#   'country': 'United States',
#   'session': 'S93411400',
#   'session_length': 1968},
#  {'timestamp': '2019-08-22T00:01:30.214Z',
#   'city': 'San Antonio',
#   'country': 'United States',
#   'session': 'S93411400',
#   'session_length': 1988},
#  {'timestamp': '2019-08-22T00:01:30.509Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S98074199',
#   'session_length': 4086},
#  {'timestamp': '2019-08-22T00:01:31.178Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S73360451',
#   'session_length': 134706},
#  {'timestamp': '2019-08-22T00:01:31.646Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S96325958',
#   'session_length': 32305},
#  {'timestamp': '2019-08-22T00:01:31.812Z',
#   'city': 'Chico',
#   'country': 'United States',
#   'session': 'S51630809',
#   'session_length': 13835},
#  {'timestamp': '2019-08-22T00:01:32.166Z',
#   'city': 'Toronto',
#   'country': 'Canada',
#   'session': 'S38589272',
#   'session_length': 44431},
#  {'timestamp': '2019-08-22T00:01:32.176Z',
#   'city': 'Halkirk',
#   'country': 'Canada',
#   'session': 'S99275049',
#   'session_length': 22434},
#  {'timestamp': '2019-08-22T00:01:32.563Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S18465989',
#   'session_length': 24345},
#  {'timestamp': '2019-08-22T00:01:32.572Z',
#   'city': 'Roseville',
#   'country': 'United States',
#   'session': 'S89033666',
#   'session_length': 61356},
#  {'timestamp': '2019-08-22T00:01:32.893Z',
#   'city': 'Killeen',
#   'country': 'United States',
#   'session': 'S83884533',
#   'session_length': 48},
#  {'timestamp': '2019-08-22T00:01:32.920Z',
#   'city': 'Malden',
#   'country': 'United States',
#   'session': 'S49573479',
#   'session_length': 15569},
#  {'timestamp': '2019-08-22T00:01:33.881Z',
#   'city': 'San Antonio',
#   'country': 'United States',
#   'session': 'S93411400',
#   'session_length': 5715},
#  {'timestamp': '2019-08-22T00:01:34.239Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S96325958',
#   'session_length': 34900},
#  {'timestamp': '2019-08-22T00:01:34.303Z',
#   'city': 'Santa Ana',
#   'country': 'United States',
#   'session': 'S08319347',
#   'session_length': 31043},
#  {'timestamp': '2019-08-22T00:01:34.733Z',
#   'city': 'Riverton',
#   'country': 'United States',
#   'session': 'S72554815',
#   'session_length': 50163},
#  {'timestamp': '2019-08-22T00:01:34.747Z',
#   'city': 'Carrollton',
#   'country': 'United States',
#   'session': 'S45331791',
#   'session_length': 605322},
#  {'timestamp': '2019-08-22T00:01:34.920Z',
#   'city': 'Malden',
#   'country': 'United States',
#   'session': 'S49573479',
#   'session_length': 17570},
#  {'timestamp': '2019-08-22T00:01:35.019Z',
#   'city': 'Rochester',
#   'country': 'United States',
#   'session': 'S47134034',
#   'session_length': 207},
#  {'timestamp': '2019-08-22T00:01:35.295Z',
#   'city': 'Rowland Heights',
#   'country': 'United States',
#   'session': 'S07596243',
#   'session_length': 69480},
#  {'timestamp': '2019-08-22T00:01:35.762Z',
#   'city': 'Toronto',
#   'country': 'Canada',
#   'session': 'S38589272',
#   'session_length': 48020},
#  {'timestamp': '2019-08-22T00:01:35.896Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S98074199',
#   'session_length': 9482},
#  {'timestamp': '2019-08-22T00:01:36.268Z',
#   'city': 'San Pablo City',
#   'country': 'Philippines',
#   'session': 'S47983021',
#   'session_length': 118},
#  {'timestamp': '2019-08-22T00:01:37.225Z',
#   'city': 'Ballwin',
#   'country': 'United States',
#   'session': 'S75505903',
#   'session_length': 290},
#  {'timestamp': '2019-08-22T00:01:37.542Z',
#   'city': 'Toronto',
#   'country': 'Canada',
#   'session': 'S38589272',
#   'session_length': 49807},
#  {'timestamp': '2019-08-22T00:01:37.569Z',
#   'city': 'Roseville',
#   'country': 'United States',
#   'session': 'S89033666',
#   'session_length': 66439},
#  {'timestamp': '2019-08-22T00:01:37.831Z',
#   'city': 'Toronto',
#   'country': 'Canada',
#   'session': 'S38589272',
#   'session_length': 50103},
#  {'timestamp': '2019-08-22T00:01:37.880Z',
#   'city': 'Malden',
#   'country': 'United States',
#   'session': 'S49573479',
#   'session_length': 20534},
#  {'timestamp': '2019-08-22T00:01:37.885Z',
#   'city': 'Halkirk',
#   'country': 'Canada',
#   'session': 'S99275049',
#   'session_length': 28148},
#  {'timestamp': '2019-08-22T00:01:38.015Z',
#   'city': 'Malden',
#   'country': 'United States',
#   'session': 'S49573479',
#   'session_length': 20671},
#  {'timestamp': '2019-08-22T00:01:38.182Z',
#   'city': 'Lutherville',
#   'country': 'United States',
#   'session': 'S96325958',
#   'session_length': 38852},
#  {'timestamp': '2019-08-22T00:01:38.669Z',
#   'city': 'Wanaka',
#   'country': 'New Zealand',
#   'session': 'S21378761',
#   'session_length': 611},
#  {'timestamp': '2019-08-22T00:01:38.739Z',
#   'city': 'Edinburg',
#   'country': 'United States',
#   'session': 'S10865721',
#   'session_length': 420},
#  {'timestamp': '2019-08-22T00:01:38.981Z',
#   'city': 'Santa Ana',
#   'country': 'United States',
#   'session': 'S08319347',
#   'session_length': 35709},
#  {'timestamp': '2019-08-22T00:01:39.055Z',
#   'city': 'Toronto',
#   'country': 'Canada',
#   'session': 'S38589272',
#   'session_length': 51320},
#  {'timestamp': '2019-08-22T00:01:39.587Z',
#   'city': 'Killeen',
#   'country': 'United States',
#   'session': 'S21599315',
#   'session_length': 170},
#  {'timestamp': '2019-08-22T00:01:40.216Z',
#   'city': 'Rochester',
#   'country': 'United States',
#   'session': 'S47134034',
#   'session_length': 5573},
#  {'timestamp': '2019-08-22T00:01:40.265Z',
#   'city': 'Rochester',
#   'country': 'United States',
#   'session': 'S47134034',
#   'session_length': 5581},
#  {'timestamp': '2019-08-22T00:01:40.320Z',
#   'city': 'Philadelphia',
#   'country': 'United States',
#   'session': 'S71557814',
#   'session_length': 607},
#  {'timestamp': '2019-08-22T00:01:40.379Z',
#   'city': 'Santa Ana',
#   'country': 'United States',
#   'session': 'S08319347',
#   'session_length': 37115},
#  {'timestamp': '2019-08-22T00:01:40.563Z',
#   'city': 'Halkirk',
#   'country': 'Canada',
#   'session': 'S99275049',
#   'session_length': 30832},
#  {'timestamp': '2019-08-22T00:01:40.732Z',
#   'city': 'Toronto',
#   'country': 'Canada',
#   'session': 'S38589272',
#   'session_length': 52989},
#  {'timestamp': '2019-08-22T00:01:40.758Z',
#   'city': 'Riverton',
#   'country': 'United States',
#   'session': 'S72554815',
#   'session_length': 56184},
#  {'timestamp': '2019-08-22T00:01:40.787Z',
#   'city': 'Calgary',
#   'country': 'Canada',
#   'session': 'S20587903',
#   'session_length': 652},
#  {'timestamp': '2019-08-22T00:01:40.863Z',
#   'city': 'Barberton',
#   'country': 'United States',
#   'session': 'S34787754',
#   'session_length': 102924},
#  {'timestamp': '2019-08-22T00:01:40.903Z',
#   'city': 'Chico',
#   'country': 'United States',
#   'session': 'S51630809',
#   'session_length': 22929},
#  {'timestamp': '2019-08-22T00:01:41.138Z',
#   'city': 'Edinburg',
#   'country': 'United States',
#   'session': 'S10865721',
#   'session_length': 2775},
# ...
#   'city': 'Yucca Valley',
#   'country': 'United States',
#   'session': 'S43762702',
#   'session_length': 9550},
#  {'timestamp': '2019-08-22T00:04:11.435Z',
#   'city': 'Yucca Valley',
#   'country': 'United States',
#   'session': 'S43762702',
#   'session_length': 9707},
#  {'timestamp': '2019-08-22T00:04:11.502Z',
#   'city': 'Pachuca',
#   'country': 'Mexico',
#   'session': 'S68240317',
#   'session_length': 3027327},
#  {'timestamp': '2019-08-22T00:04:11.508Z',
#   'city': 'Wanaka',
#   'country': 'New Zealand',
#   'session': 'S34052795',
#   'session_length': 88025},
#  {'timestamp': '2019-08-22T00:04:11.669Z',
#   'city': 'Pachuca',
#   'country': 'Mexico',
#   'session': 'S68240317',
#   'session_length': 3028777},
#  {'timestamp': '2019-08-22T00:04:11.672Z',
#   'city': 'Pachuca',
#   'country': 'Mexico',
#   'session': 'S68240317',
#   'session_length': 3030082},
#  {'timestamp': '2019-08-22T00:04:11.680Z',
#   'city': 'Pachuca',
#   'country': 'Mexico',
#   'session': 'S68240317',
#   'session_length': 3030873},
#  {'timestamp': '2019-08-22T00:04:11.695Z',
#   'city': 'Pachuca',
#   'country': 'Mexico',
#   'session': 'S68240317',
#   'session_length': 3031395},
#  {'timestamp': '2019-08-22T00:04:11.945Z',
#   'city': 'Spokane',
#   'country': 'United States',
#   'session': 'S27517595',
#   'session_length': 210766},
#  {'timestamp': '2019-08-22T00:04:11.964Z',
#   'city': 'Edinburg',
#   'country': 'United States',
#   'session': 'S16166311',
#   'session_length': 96444},
#  {'timestamp': '2019-08-22T00:04:12.022Z',
#   'city': 'Philadelphia',
#   'country': 'United States',
#   'session': 'S78588527',
#   'session_length': 57393},
#  {'timestamp': '2019-08-22T00:04:12.033Z',
#   'city': 'Budapest',
#   'country': 'Hungary',
#   'session': 'S45426867',
#   'session_length': 29443},
#  {'timestamp': '2019-08-22T00:04:12.116Z',
#   'city': 'Las Vegas',
#   'country': 'United States',
#   'session': 'S91348594',
#   'session_length': 2815127},
#  {'timestamp': '2019-08-22T00:04:12.256Z',
#   'city': 'San Leandro',
#   'country': 'United States',
#   'session': 'S83506060',
#   'session_length': 15096},
#  {'timestamp': '2019-08-22T00:04:12.977Z',
#   'city': 'Long Beach',
#   'country': 'United States',
#   'session': 'S68116058',
#   'session_length': 79279},
#  {'timestamp': '2019-08-22T00:04:13.122Z',
#   'city': 'Yucca Valley',
#   'country': 'United States',
#   'session': 'S43762702',
#   'session_length': 11423},
#  {'timestamp': '2019-08-22T00:04:13.354Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S15782543',
#   'session_length': 68904},
#  {'timestamp': '2019-08-22T00:04:13.367Z',
#   'city': 'Jilotepec de Molina Enriquez',
#   'country': 'Mexico',
#   'session': 'S09687192',
#   'session_length': 21539},
#  {'timestamp': '2019-08-22T00:04:13.746Z',
#   'city': 'San Leandro',
#   'country': 'United States',
#   'session': 'S83506060',
#   'session_length': 16593},
#  {'timestamp': '2019-08-22T00:04:13.890Z',
#   'city': '',
#   'country': 'United States',
#   'session': 'S40902382',
#   'session_length': 10302},
#  {'timestamp': '2019-08-22T00:04:14.641Z',
#   'city': 'Yucca Valley',
#   'country': 'United States',
#   'session': 'S43762702',
#   'session_length': 12945},
#  {'timestamp': '2019-08-22T00:04:14.663Z',
#   'city': 'Budapest',
#   'country': 'Hungary',
#   'session': 'S45426867',
#   'session_length': 32074},
#  {'timestamp': '2019-08-22T00:04:14.735Z',
#   'city': 'Cuiabá',
#   'country': 'Brazil',
#   'session': 'S40334680',
#   'session_length': 633},
#  {'timestamp': '2019-08-22T00:04:14.745Z',
#   'city': 'Wanaka',
#   'country': 'New Zealand',
#   'session': 'S21378761',
#   'session_length': 156699},
#  {'timestamp': '2019-08-22T00:04:14.924Z',
#   'city': 'Yucca Valley',
#   'country': 'United States',
#   'session': 'S43762702',
#   'session_length': 13240},
#  {'timestamp': '2019-08-22T00:04:15.027Z',
#   'city': 'Philadelphia',
#   'country': 'United States',
#   'session': 'S78588527',
#   'session_length': 60419},
#  {'timestamp': '2019-08-22T00:04:15.100Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S55731013',
#   'session_length': 332},
#  {'timestamp': '2019-08-22T00:04:15.275Z',
#   'city': 'San Leandro',
#   'country': 'United States',
#   'session': 'S83506060',
#   'session_length': 18118},
#  {'timestamp': '2019-08-22T00:04:15.360Z',
#   'city': 'Philadelphia',
#   'country': 'United States',
#   'session': 'S78588527',
#   'session_length': 60752},
#  {'timestamp': '2019-08-22T00:04:15.826Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S55731013',
#   'session_length': 2131},
#  {'timestamp': '2019-08-22T00:04:15.882Z',
#   'city': 'Budapest',
#   'country': 'Hungary',
#   'session': 'S45426867',
#   'session_length': 33296},
#  {'timestamp': '2019-08-22T00:04:16.324Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S55731013',
#   'session_length': 2152},
#  {'timestamp': '2019-08-22T00:04:16.622Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S88531759',
#   'session_length': 41243},
#  {'timestamp': '2019-08-22T00:04:16.741Z',
#   'city': 'San Leandro',
#   'country': 'United States',
#   'session': 'S83506060',
#   'session_length': 19588},
#  {'timestamp': '2019-08-22T00:04:16.771Z',
#   'city': 'Wellington',
#   'country': 'New Zealand',
#   'session': 'S80245558',
#   'session_length': 344},
#  {'timestamp': '2019-08-22T00:04:16.775Z',
#   'city': 'Wellington',
#   'country': 'New Zealand',
#   'session': 'S80245558',
#   'session_length': 1979},
#  {'timestamp': '2019-08-22T00:04:16.925Z',
#   'city': 'Pachuca',
#   'country': 'Mexico',
#   'session': 'S68240317',
#   'session_length': 3039170},
#  {'timestamp': '2019-08-22T00:04:17.031Z',
#   'city': 'Wellington',
#   'country': 'New Zealand',
#   'session': 'S80245558',
#   'session_length': 1997},
#  {'timestamp': '2019-08-22T00:04:17.841Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S15782543',
#   'session_length': 73485},
#  {'timestamp': '2019-08-22T00:04:17.905Z',
#   'city': 'Santa Ana',
#   'country': 'United States',
#   'session': 'S72525974',
#   'session_length': 591},
#  {'timestamp': '2019-08-22T00:04:17.938Z',
#   'city': 'San Leandro',
#   'country': 'United States',
#   'session': 'S83506060',
#   'session_length': 20747},
#  {'timestamp': '2019-08-22T00:04:18.011Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S86212457',
#   'session_length': 100272},
#  {'timestamp': '2019-08-22T00:04:18.052Z',
#   'city': '',
#   'country': 'United States',
#   'session': 'S40902382',
#   'session_length': 14431},
#  {'timestamp': '2019-08-22T00:04:18.267Z',
#   'city': 'San Leandro',
#   'country': 'United States',
#   'session': 'S83506060',
#   'session_length': 21111},
#  {'timestamp': '2019-08-22T00:04:18.918Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S88531759',
#   'session_length': 43553},
#  {'timestamp': '2019-08-22T00:04:19.140Z',
#   'city': 'Rowland Heights',
#   'country': 'United States',
#   'session': 'S07596243',
#   'session_length': 233350},
#  {'timestamp': '2019-08-22T00:04:19.168Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S86212457',
#   'session_length': 101587},
#  {'timestamp': '2019-08-22T00:04:19.250Z',
#   'city': 'Budapest',
#   'country': 'Hungary',
#   'session': 'S45426867',
#   'session_length': 36658},
#  {'timestamp': '2019-08-22T00:04:19.700Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S55731013',
#   'session_length': 6564},
#  {'timestamp': '2019-08-22T00:04:19.797Z',
#   'city': 'Santa Ana',
#   'country': 'United States',
#   'session': 'S72525974',
#   'session_length': 2453},
#  {'timestamp': '2019-08-22T00:04:19.884Z',
#   'city': 'Santa Ana',
#   'country': 'United States',
#   'session': 'S72525974',
#   'session_length': 2473},
#  {'timestamp': '2019-08-22T00:04:20.006Z',
#   'city': 'Pachuca',
#   'country': 'Mexico',
#   'session': 'S68240317',
#   'session_length': 3042611},
#  {'timestamp': '2019-08-22T00:04:20.114Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S15782543',
#   'session_length': 75758},
#  {'timestamp': '2019-08-22T00:04:20.407Z',
#   'city': '',
#   'country': 'United States',
#   'session': 'S40902382',
#   'session_length': 16762},
#  {'timestamp': '2019-08-22T00:04:20.484Z',
#   'city': 'Istanbul',
#   'country': 'Turkey',
#   'session': 'S16418954',
#   'session_length': 280684},
#  {'timestamp': '2019-08-22T00:04:20.734Z',
#   'city': 'San Leandro',
#   'country': 'United States',
#   'session': 'S83506060',
#   'session_length': 23578},
#  {'timestamp': '2019-08-22T00:04:21.076Z',
#   'city': 'Southampton',
#   'country': 'United Kingdom',
#   'session': 'S60176783',
#   'session_length': 16821},
#  {'timestamp': '2019-08-22T00:04:21.243Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S88531759',
#   'session_length': 45862},
#  {'timestamp': '2019-08-22T00:04:21.324Z',
#   'city': 'Santa Ana',
#   'country': 'United States',
#   'session': 'S72525974',
#   'session_length': 4018},
#  {'timestamp': '2019-08-22T00:04:21.349Z',
#   'city': 'Spokane',
#   'country': 'United States',
#   'session': 'S27517595',
#   'session_length': 220174},
#  {'timestamp': '2019-08-22T00:04:21.405Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S86212457',
#   'session_length': 103823},
#  {'timestamp': '2019-08-22T00:04:21.433Z',
#   'city': 'San Leandro',
#   'country': 'United States',
#   'session': 'S83506060',
#   'session_length': 24280},
#  {'timestamp': '2019-08-22T00:04:21.960Z',
#   'city': '',
#   'country': 'United States',
#   'session': 'S40902382',
#   'session_length': 18316},
#  {'timestamp': '2019-08-22T00:04:22.226Z',
#   'city': 'San Leandro',
#   'country': 'United States',
#   'session': 'S83506060',
#   'session_length': 25060},
#  {'timestamp': '2019-08-22T00:04:22.349Z',
#   'city': 'San Antonio',
#   'country': 'United States',
#   'session': 'S15861136',
#   'session_length': 389},
#  {'timestamp': '2019-08-22T00:04:22.786Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S86212457',
#   'session_length': 105204},
#  {'timestamp': '2019-08-22T00:04:22.939Z',
#   'city': '',
#   'country': 'United States',
#   'session': 'S40902382',
#   'session_length': 19345},
#  {'timestamp': '2019-08-22T00:04:23.008Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S15782543',
#   'session_length': 78652},
#  {'timestamp': '2019-08-22T00:04:23.100Z',
#   'city': '',
#   'country': 'United States',
#   'session': 'S40902382',
#   'session_length': 19503},
#  {'timestamp': '2019-08-22T00:04:23.379Z',
#   'city': 'San Leandro',
#   'country': 'United States',
#   'session': 'S83506060',
#   'session_length': 26206},
#  {'timestamp': '2019-08-22T00:04:24.470Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S88531759',
#   'session_length': 49078},
#  {'timestamp': '2019-08-22T00:04:24.698Z',
#   'city': 'Wanaka',
#   'country': 'New Zealand',
#   'session': 'S21378761',
#   'session_length': 166650},
#  {'timestamp': '2019-08-22T00:04:24.729Z',
#   'city': 'San Leandro',
#   'country': 'United States',
#   'session': 'S83506060',
#   'session_length': 27562},
#  {'timestamp': '2019-08-22T00:04:24.910Z',
#   'city': 'Jilotepec de Molina Enriquez',
#   'country': 'Mexico',
#   'session': 'S09687192',
#   'session_length': 33090},
#  {'timestamp': '2019-08-22T00:04:25.114Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S15782543',
#   'session_length': 80757},
#  {'timestamp': '2019-08-22T00:04:25.219Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S73360451',
#   'session_length': 308370},
#  {'timestamp': '2019-08-22T00:04:25.687Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S98074199',
#   'session_length': 178026},
#  {'timestamp': '2019-08-22T00:04:25.701Z',
#   'city': '',
#   'country': 'United States',
#   'session': 'S47177023',
#   'session_length': 269},
#  {'timestamp': '2019-08-22T00:04:25.897Z',
#   'city': 'Yucca Valley',
#   'country': 'United States',
#   'session': 'S43762702',
#   'session_length': 24163},
#  {'timestamp': '2019-08-22T00:04:25.897Z',
#   'city': 'Santa Ana',
#   'country': 'United States',
#   'session': 'S72525974',
#   'session_length': 8598},
#  {'timestamp': '2019-08-22T00:04:26.050Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S86212457',
#   'session_length': 108466},
#  {'timestamp': '2019-08-22T00:04:26.286Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S15782543',
#   'session_length': 81928},
#  {'timestamp': '2019-08-22T00:04:26.288Z',
#   'city': 'San Leandro',
#   'country': 'United States',
#   'session': 'S83506060',
#   'session_length': 29127},
#  {'timestamp': '2019-08-22T00:04:27.154Z',
#   'city': '',
#   'country': 'United States',
#   'session': 'S47177023',
#   'session_length': 1679},
#  {'timestamp': '2019-08-22T00:04:27.160Z',
#   'city': '',
#   'country': 'United States',
#   'session': 'S47177023',
#   'session_length': 1699},
#  {'timestamp': '2019-08-22T00:04:27.385Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S86212457',
#   'session_length': 109800},
#  {'timestamp': '2019-08-22T00:04:27.603Z',
#   'city': 'Yucca Valley',
#   'country': 'United States',
#   'session': 'S43762702',
#   'session_length': 25857},
#  {'timestamp': '2019-08-22T00:04:27.851Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S88531759',
#   'session_length': 52462},
#  {'timestamp': '2019-08-22T00:04:28.216Z',
#   'city': 'Santa Ana',
#   'country': 'United States',
#   'session': 'S72525974',
#   'session_length': 10860},
#  {'timestamp': '2019-08-22T00:04:28.304Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S55731013',
#   'session_length': 15129},
#  {'timestamp': '2019-08-22T00:04:28.429Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S86212457',
#   'session_length': 110845},
#  {'timestamp': '2019-08-22T00:04:28.608Z',
#   'city': 'Wanaka',
#   'country': 'New Zealand',
#   'session': 'S34052795',
#   'session_length': 104608},
#  {'timestamp': '2019-08-22T00:04:28.725Z',
#   'city': 'San Leandro',
#   'country': 'United States',
#   'session': 'S83506060',
#   'session_length': 31562},
#  {'timestamp': '2019-08-22T00:04:29.338Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S86212457',
#   'session_length': 111753},
#  {'timestamp': '2019-08-22T00:04:29.705Z',
#   'city': 'Roseville',
#   'country': 'United States',
#   'session': 'S89033666',
#   'session_length': 238470},
#  {'timestamp': '2019-08-22T00:04:30.740Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S88531759',
#   'session_length': 55344},
#  {'timestamp': '2019-08-22T00:04:30.852Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S86212457',
#   'session_length': 113267},
#  {'timestamp': '2019-08-22T00:04:30.998Z',
#   'city': 'Jilotepec de Molina Enriquez',
#   'country': 'Mexico',
#   'session': 'S09687192',
#   'session_length': 39179},
#  {'timestamp': '2019-08-22T00:04:31.421Z',
#   'city': 'Jilotepec de Molina Enriquez',
#   'country': 'Mexico',
#   'session': 'S09687192',
#   'session_length': 39607},
#  {'timestamp': '2019-08-22T00:04:31.604Z',
#   'city': 'Santa Ana',
#   'country': 'United States',
#   'session': 'S72525974',
#   'session_length': 14295},
#  {'timestamp': '2019-08-22T00:04:31.753Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S86212457',
#   'session_length': 114169},
#  {'timestamp': '2019-08-22T00:04:31.879Z',
#   'city': 'Carrollton',
#   'country': 'United States',
#   'session': 'S45331791',
#   'session_length': 782241},
#  {'timestamp': '2019-08-22T00:04:32.069Z',
#   'city': 'Wanaka',
#   'country': 'New Zealand',
#   'session': 'S34052795',
#   'session_length': 108095},
#  {'timestamp': '2019-08-22T00:04:32.153Z',
#   'city': 'Wanaka',
#   'country': 'New Zealand',
#   'session': 'S21378761',
#   'session_length': 174107},
#  {'timestamp': '2019-08-22T00:04:32.386Z',
#   'city': 'Balwyn North',
#   'country': 'Australia',
#   'session': 'S98074199',
#   'session_length': 185765},
#  {'timestamp': '2019-08-22T00:04:32.681Z',
#   'city': 'Auckland',
#   'country': 'New Zealand',
#   'session': 'S86212457',
#   'session_length': 115095},
#  {'timestamp': '2019-08-22T00:04:32.949Z',
#   'city': 'Makhachkala',
#   'country': 'Russia',
#   'session': 'S83381839',
#   'session_length': 165},
#  {'timestamp': '2019-08-22T00:04:33.343Z',
#   'city': 'Santa Ana',
#   'country': 'United States',
#   'session': 'S72525974',
#   'session_length': 16033},
#  ...]

# %%
# protobuf schema
message KTTM {
    string timestamp = 1;
    string city = 2;
    string country = 3;
    int32 session = 4;
    int32 session_length = 5;
}
# Out:
#   Input In [36]
#     message KTTM {
#             ^
# SyntaxError: invalid syntax

# %%
d = data[0]
d
# Out:
# {'timestamp': '2019-08-22T00:00:00.212Z',
#  'city': 'Christchurch',
#  'country': 'New Zealand',
#  'session': 'S97953932',
#  'session_length': 337}

# %%
message = ParseDict(d, Thing())
#message = Parse(json.dumps(d), Thing())    

print(message.first)  # "a string"
print(message.second) # True
print(message.third)  # 123456789
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 message = ParseDict(d, Thing())
#       2 #message = Parse(json.dumps(d), Thing())
#       4 print(message.first)  # "a string"
#
# NameError: name 'Thing' is not defined

# %%
ess
